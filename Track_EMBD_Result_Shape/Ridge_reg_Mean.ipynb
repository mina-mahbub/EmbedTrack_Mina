# %%
import phate
import scprep
import seaborn as sns
import os
import json
from PIL import Image, ImageDraw
import re
import numpy as np
import cv2
import imageio
import matplotlib.pyplot as plt
import tifffile as tiff
from tqdm import tqdm
from skimage.exposure import equalize_adapthist
from scipy.stats import stats
import matplotlib.animation as animation
import pandas as pd
import csv
import shutil
from skimage.morphology import dilation, erosion
import numpy as np
import matplotlib.pyplot as plt
import imageio
from skimage import measure
from skimage.measure import regionprops, label
from scipy.spatial import distance
import time
import datetime
from mpl_toolkits.mplot3d import Axes3D  # 3D Plotting
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import seaborn as sns
from sklearn.manifold import TSNE
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.stats.diagnostic import het_breuschpagan
from statsmodels.stats.stattools import durbin_watson
from sklearn.linear_model import Ridge, Lasso
from sklearn.preprocessing import StandardScaler, PowerTransformer
from sklearn.metrics import mean_squared_error, r2_score

from skimage.morphology import dilation, erosion
from skimage import measure
from scipy.ndimage import center_of_mass
from glob import glob
import random
from skimage.measure import regionprops, label
from scipy.spatial import distance

import imageio.v2 as imageio
from tifffile import imread

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score


from scipy import stats
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import RidgeCV, LassoCV, ElasticNetCV, LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Final Regression model

# %%
# === CONFIGURATION ===
input_path = "/home/MinaHossain/EmbedTrack/Track_EMBD_Result_Shape/Mean/Cells_Centroid_Velocity_TrueLabel_MA_Mean_5.csv"
output_root = "/home/MinaHossain/EmbedTrack/Track_EMBD_Result_Shape/Mean"
plot_dir = f"{output_root}/Ridge_Plots"
os.makedirs(plot_dir, exist_ok=True)

# === LOAD AND CLEAN DATA ===
df = pd.read_csv(input_path)
collinear_features = ['Area_MA', 'Perimeter_MA', 'Solidity_MA', 'Extent_MA',
                      'Circularity_MA', 'Convexity_MA', 'Elongation_MA', 'Compactness_MA']
spatial_features = ['Centroid_X_MA', 'Centroid_Y_MA', 'X_Centroid_Distance_MA', 'Y_Centroid_Distance_MA']
target_col = 'X_Centroid_Velocity_MA'

df_clean = df[collinear_features + spatial_features + [target_col]].dropna()
X_collinear = df_clean[collinear_features].values
X_spatial = df_clean[spatial_features].values
y = df_clean[target_col].values

# === SPLIT DATA ===
X_col_train, X_col_temp, X_spatial_train, X_spatial_temp, y_train, y_temp = train_test_split(
    X_collinear, X_spatial, y, test_size=0.4, random_state=42)
X_col_val, X_col_test, X_spatial_val, X_spatial_test, y_val, y_test = train_test_split(
    X_col_temp, X_spatial_temp, y_temp, test_size=0.5, random_state=42)

# === PCA ON TRAIN ===
scaler = StandardScaler()
X_col_train_scaled = scaler.fit_transform(X_col_train)
X_col_val_scaled = scaler.transform(X_col_val)
X_col_test_scaled = scaler.transform(X_col_test)

pca = PCA(n_components=3)
X_pca_train = pca.fit_transform(X_col_train_scaled)
X_pca_val = pca.transform(X_col_val_scaled)
X_pca_test = pca.transform(X_col_test_scaled)

X_train_final = np.hstack([X_pca_train, X_spatial_train])
X_val_final = np.hstack([X_pca_val, X_spatial_val])
X_test_final = np.hstack([X_pca_test, X_spatial_test])

# === DEFINE MODELS ===
models = {
    # "LinearRegression": LinearRegression(),
    # "Ridge": RidgeCV(alphas=np.logspace(-3, 3, 50), cv=5),
    # "Lasso": LassoCV(cv=5, random_state=42, max_iter=10000),
    # "ElasticNet": ElasticNetCV(cv=5, random_state=42, max_iter=10000),
    # "RandomForest": RandomForestRegressor(n_estimators=100, max_depth=6, random_state=42, n_jobs=-1),
    "XGBoost": XGBRegressor(n_estimators=200, max_depth=4, learning_rate=0.01, random_state=42, n_jobs=-1, verbosity=0)
}

# === EVALUATE MODELS ON VALIDATION SET ===
results = {}
for name, model in models.items():
    try:
        model.fit(X_train_final, y_train)
        y_val_pred = model.predict(X_val_final)
        r2 = r2_score(y_val, y_val_pred)
        results[name] = r2
    except Exception as e:
        results[name] = f"Failed: {str(e)}"

best_model_name = max(results, key=lambda k: results[k] if isinstance(results[k], float) else -np.inf)
best_model = models[best_model_name]
best_model.fit(X_train_final, y_train)
y_test_pred = best_model.predict(X_test_final)

# === SAVE COEFFICIENTS AND PERFORMANCE ===
coeff_labels = [f'PC{i+1}' for i in range(3)] + spatial_features
coef_df = pd.DataFrame({'Feature': coeff_labels, 'Coefficient': best_model.coef_}) if hasattr(best_model, 'coef_') else pd.DataFrame()
metrics_df = pd.DataFrame({
    'Metric': ['R-squared', 'MSE'],
    'Value': [r2_score(y_test, y_test_pred), mean_squared_error(y_test, y_test_pred)]
})
coef_df.to_csv(f"{plot_dir}/best_model_coefficients.csv", index=False)
metrics_df.to_csv(f"{plot_dir}/best_model_metrics.csv", index=False)

# === PLOTTING ===
def plot_results(y_true, y_pred):
    residuals = y_true - y_pred
    absolute_errors = np.abs(residuals)

    def save_plot(fig, name):
        fig.tight_layout()
        fig.savefig(f"{plot_dir}/{name}.png")
        plt.close(fig)

    fig, ax = plt.subplots(figsize=(8, 5))
    sns.scatterplot(x=y_pred, y=residuals, ax=ax)
    ax.axhline(0, linestyle='--', color='red')
    ax.set_title("Residuals vs Predicted")
    ax.set_xlabel("Predicted")
    ax.set_ylabel("Residuals")
    save_plot(fig, "residuals_vs_predicted")

    fig, ax = plt.subplots(figsize=(8, 5))
    sns.scatterplot(x=y_true, y=y_pred, ax=ax)
    ax.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], linestyle='--', color='red')
    ax.set_title("Predicted vs Actual")
    ax.set_xlabel("Actual")
    ax.set_ylabel("Predicted")
    save_plot(fig, "predicted_vs_actual")

    fig, ax = plt.subplots(figsize=(8, 5))
    sns.histplot(residuals, bins=30, kde=True, ax=ax)
    ax.set_title("Distribution of Residuals")
    ax.set_xlabel("Residuals")
    save_plot(fig, "residuals_distribution")

    fig, ax = plt.subplots(figsize=(8, 5))
    sorted_errors = np.sort(absolute_errors)
    cum_dist = np.arange(1, len(sorted_errors) + 1) / len(sorted_errors)
    ax.plot(sorted_errors, cum_dist)
    ax.set_title("Cumulative Distribution of Absolute Errors")
    ax.set_xlabel("Absolute Error")
    ax.set_ylabel("Cumulative Proportion")
    save_plot(fig, "cumulative_absolute_errors")

    fig = plt.figure(figsize=(6, 6))
    stats.probplot(residuals, dist="norm", plot=plt)
    plt.title("Q-Q Plot of Residuals")
    save_plot(fig, "qq_plot_residuals")

    fig, ax = plt.subplots(figsize=(8, 5))
    sns.scatterplot(x=y_true, y=absolute_errors, ax=ax)
    ax.set_title("Absolute Error vs Actual Value")
    ax.set_xlabel("Actual Values")
    ax.set_ylabel("Absolute Error")
    save_plot(fig, "absolute_error_vs_actual")

plot_results(y_test, y_test_pred)

# === REPORT ON SPLITS ===
y_train_pred = best_model.predict(X_train_final)
y_val_pred = best_model.predict(X_val_final)
y_test_pred = best_model.predict(X_test_final)

performance = pd.DataFrame({
    "Split": ["Train", "Validation", "Test"],
    "R-squared": [
        r2_score(y_train, y_train_pred),
        r2_score(y_val, y_val_pred),
        r2_score(y_test, y_test_pred)
    ],
    "MSE": [
        mean_squared_error(y_train, y_train_pred),
        mean_squared_error(y_val, y_val_pred),
        mean_squared_error(y_test, y_test_pred)
    ]
})

performance.to_csv(f"{plot_dir}/model_performance_by_split.csv", index=False)
print(f"Best model: {best_model_name}")
print(performance)


# Generate the code block for PCA + Clustering using validation data and applying to test data


# === PCA + KMeans CLUSTERING (Fit on Validation, Apply to Test) ===
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

output_directory = plot_dir
window_size = 5

# --- Fit PCA on Validation Set ---
X_scaled_val = X_col_val_scaled
pca_full = PCA()
pca_full.fit(X_scaled_val)
explained_variance = pca_full.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance)

optimal_components = np.argmax(cumulative_variance >= 0.95) + 1

# --- Plot PCA Cumulative Variance (Elbow Plot) ---
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker='s', linestyle='-', color='red', label="Cumulative Variance")
plt.axvline(x=optimal_components, color='green', linestyle='--', label=f"Optimal Components ({optimal_components})")
plt.scatter(optimal_components, cumulative_variance[optimal_components-1], color='black', s=50, label="Chosen Point")
plt.xlabel("Number of Principal Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("PCA Elbow Plot with Cumulative Variance")
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig(os.path.join(output_directory, f"PCA_Elbow_Plot_{window_size}.png"))
plt.close()

# --- Fit 2D PCA on Validation ---
pca_2d = PCA(n_components=2)
pca_val_2d = pca_2d.fit_transform(X_scaled_val)

# --- KMeans on 2D PCA space (Validation) ---
silhouette_scores = []
k_range = range(2, 15)
for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=0, n_init='auto').fit(pca_val_2d)
    score = silhouette_score(pca_val_2d, kmeans.labels_)
    silhouette_scores.append(score)

optimal_k = k_range[np.argmax(silhouette_scores)]
optimal_score = max(silhouette_scores)

# --- Plot Silhouette Scores ---
plt.figure(figsize=(8, 6))
plt.plot(k_range, silhouette_scores, marker='o', linestyle='-', color='purple', label="Silhouette Score")
plt.axvline(x=optimal_k, color='green', linestyle='--', label=f"Optimal k = {optimal_k}")
plt.scatter(optimal_k, optimal_score, color='red', s=100, zorder=5)
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score vs Number of Clusters (Validation)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig(os.path.join(output_directory, f"Silhouette_Score_vs_K_{window_size}.png"))
plt.close()

# --- Apply to Test Data ---
X_scaled_test = X_col_test_scaled
pca_test_2d = pca_2d.transform(X_scaled_test)
kmeans_final = KMeans(n_clusters=optimal_k, random_state=0, n_init='auto').fit(pca_val_2d)
test_clusters = kmeans_final.predict(pca_test_2d)

# --- Create Test DataFrame with PCA + Clusters ---
pca_test_df = pd.DataFrame(pca_test_2d, columns=["PCA1", "PCA2"])
pca_test_df["X_Centroid_Velocity_MA"] = X_col_test[:, 0]  # Area_MA is first collinear feature
pca_test_df["Cluster"] = test_clusters

# --- Clustered 2D PCA (Colored by Area) ---
vmin = np.percentile(pca_test_df["X_Centroid_Velocity_MA"], 5)
vmax = np.percentile(pca_test_df["X_Centroid_Velocity_MA"], 95)
plt.figure(figsize=(10, 7))
sc = plt.scatter(pca_test_df["PCA1"], pca_test_df["PCA2"], c=pca_test_df["X_Centroid_Velocity_MA"], cmap="plasma", alpha=0.8, vmin=vmin, vmax=vmax)
plt.colorbar(sc, label="X_Centroid Velocity (MA)")
plt.title("2D PCA Test Data Colored by X_Centroid Velocity(MA)")
plt.xlabel("PCA1")
plt.ylabel("PCA2")
plt.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(output_directory, f"PCA_2D_X_Centroid_Velocity_MA_{window_size}.png"))
plt.close()

# --- Cluster Plot with Centers ---
plt.figure(figsize=(10, 7))
plt.scatter(pca_test_df["PCA1"], pca_test_df["PCA2"], c=pca_test_df["Cluster"], cmap="tab10", alpha=0.8)
centers = kmeans_final.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, marker='o', label='Centers')
for idx, (x, y) in enumerate(centers):
    plt.text(x, y, str(idx), fontsize=12, fontweight='bold', ha='center', va='center', color='white',
             bbox=dict(facecolor='black', boxstyle='circle,pad=0.2'))
plt.title(f"Test Data PCA with KMeans Clusters (k={optimal_k})")
plt.xlabel("PCA1")
plt.ylabel("PCA2")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(output_directory, f"PCA_2D_Clusters_X_Centroid_Velocity_MA_{window_size}.png"))
plt.close()

# --- Boxplot: Area by Cluster (Test Data) ---
plt.figure(figsize=(10, 6))
sns.boxplot(data=pca_test_df, x="Cluster", y="X_Centroid_Velocity_MA", palette="Set2")
sns.stripplot(data=pca_test_df, x="Cluster", y="X_Centroid_Velocity_MA", color='gray', alpha=0.5, jitter=0.2, size=3)
plt.title("X_Centroid Velocity (MA) by Cluster (Test Data)", fontsize=14)
plt.xlabel("Cluster")
plt.ylabel("X_Centroid Velocity (MA)")
plt.tight_layout()
plt.savefig(os.path.join(output_directory, f"Boxplot_X_Centroid_Velocity_MA_By_Cluster_{window_size}.png"))
plt.close()

# --- Save clustered PCA test data and summary ---
pca_test_df.to_csv(os.path.join(output_directory, f"PCA_Cluster_Results_Test_{window_size}.csv"), index=False)

summary = pca_test_df.groupby("Cluster").agg({
    "PCA1": ["mean", "std"],
    "PCA2": ["mean", "std"],
    "X_Centroid_Velocity_MA": ["mean", "std"]
}).reset_index()
summary.columns = ["_".join(col).strip("_") for col in summary.columns.values]
summary.to_csv(os.path.join(output_directory, f"PCA_Cluster_Summary_Test_{window_size}.csv"), index=False)
# Out:
# Best model: XGBoost
#         Split  R-squared        MSE
# 0       Train   0.940458   1.062524
# 1  Validation   0.534023  21.342744
# 2        Test   0.857927   2.967489
# /tmp/ipykernel_4048482/1862329750.py:261: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=pca_test_df, x="Cluster", y="X_Centroid_Velocity_MA", palette="Set2")

# %% [markdown]
# # Create the updated FNN pipeline script content with PCA + spatial features + grid search

# %%
import os
import argparse
import datetime
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset
from itertools import product

# --- CONFIG ---
output_root = "/home/MinaHossain/EmbedTrack/Track_EMBD_Result_Shape/Mean/Reg_Analysis_FNN_PCA"
os.makedirs(f"{output_root}/models", exist_ok=True)
os.makedirs(f"{output_root}/results", exist_ok=True)
os.makedirs(f"{output_root}/plots", exist_ok=True)

# --- FNN Model ---
class FNN(nn.Module):
    def __init__(self, input_size, hidden_sizes):
        super(FNN, self).__init__()
        layers = [nn.Linear(input_size, hidden_sizes[0]), nn.ReLU()]
        for i in range(1, len(hidden_sizes)):
            layers.append(nn.Linear(hidden_sizes[i-1], hidden_sizes[i]))
            layers.append(nn.ReLU())
        layers.append(nn.Linear(hidden_sizes[-1], 1))
        self.model = nn.Sequential(*layers)

    def forward(self, x):
        return self.model(x)

# --- Evaluation ---
def evaluate_model(model, X_test_tensor, y_test_tensor):
    model.eval()
    with torch.no_grad():
        y_pred_tensor = model(X_test_tensor)
    y_pred = y_pred_tensor.cpu().numpy().flatten()
    y_true = y_test_tensor.cpu().numpy().flatten()
    mse = mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"✅ MSE: {mse:.4f} | R²: {r2:.4f}")
    return mse, r2, y_true, y_pred

# --- Plotting ---
def plot_results(y_true, y_pred, train_losses=None):
    residuals = y_true - y_pred
    if train_losses:
        plt.figure(); plt.plot(train_losses); plt.title("Training Loss"); plt.tight_layout()
        plt.savefig(f"{output_root}/plots/loss_curve.png"); plt.close()
    plt.figure(); sns.scatterplot(x=y_pred, y=residuals); plt.axhline(0, linestyle='--', color='red')
    plt.title("Residuals vs Predicted"); plt.tight_layout()
    plt.savefig(f"{output_root}/plots/residuals_vs_predicted.png"); plt.close()
    plt.figure(); sns.scatterplot(x=y_true, y=y_pred); plt.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], 'r--')
    plt.title("Predicted vs Actual"); plt.tight_layout()
    plt.savefig(f"{output_root}/plots/predicted_vs_actual.png"); plt.close()
    plt.figure(); sns.histplot(residuals, bins=30, kde=True)
    plt.title("Distribution of Residuals"); plt.tight_layout()
    plt.savefig(f"{output_root}/plots/residuals_distribution.png"); plt.close()
    plt.figure(); plt.plot(np.sort(np.abs(residuals)), np.linspace(0, 1, len(residuals)))
    plt.title("Cumulative Absolute Errors"); plt.tight_layout()
    plt.savefig(f"{output_root}/plots/cumulative_absolute_errors.png"); plt.close()
    plt.figure(); stats.probplot(residuals, dist="norm", plot=plt)
    plt.title("Q-Q Plot"); plt.tight_layout()
    plt.savefig(f"{output_root}/plots/qq_plot_residuals.png"); plt.close()
    plt.figure(); sns.scatterplot(x=y_true, y=np.abs(residuals))
    plt.title("Absolute Error vs Actual"); plt.tight_layout()
    plt.savefig(f"{output_root}/plots/absolute_error_vs_actual.png"); plt.close()

# --- Run FNN ---
def run_fnn(X_train, X_val, X_test, y_train, y_val, y_test, input_size, hidden_sizes, lr, batch_size, epochs):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = FNN(input_size=input_size, hidden_sizes=hidden_sizes).to(device)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)

    X_train_tensor = torch.tensor(X_train).float().to(device)
    y_train_tensor = torch.tensor(y_train).float().to(device)
    X_val_tensor = torch.tensor(X_val).float().to(device)
    y_val_tensor = torch.tensor(y_val).float().to(device)
    X_test_tensor = torch.tensor(X_test).float().to(device)
    y_test_tensor = torch.tensor(y_test).float().to(device)

    train_loader = DataLoader(TensorDataset(X_train_tensor, y_train_tensor), batch_size=batch_size, shuffle=True)

    train_losses = []
    for epoch in range(epochs):
        model.train()
        total_loss = 0
        for xb, yb in train_loader:
            optimizer.zero_grad()
            pred = model(xb)
            loss = criterion(pred, yb)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        train_losses.append(total_loss / len(train_loader))
        if (epoch + 1) % 10 == 0:
            print(f"Epoch {epoch+1}: Loss={train_losses[-1]:.4f}")

    return model, train_losses, X_test_tensor, y_test_tensor

# --- Grid Search ---
def grid_search_fnn(csv_path, param_grid):
    df = pd.read_csv(csv_path)
    shape_features = ['Area_MA', 'Perimeter_MA', 'Extent_MA', 'Solidity_MA', 'Compactness_MA', 'Elongation_MA', 'Circularity_MA', 'Convexity_MA']
    spatial_features = ['Centroid_X_MA', 'Centroid_Y_MA', 'X_Centroid_Distance_MA', 'Y_Centroid_Distance_MA']
    target = 'X_Centroid_Velocity_MA'
    df = df.dropna(subset=shape_features + spatial_features + [target])

    X_shape = df[shape_features].values
    X_spatial = df[spatial_features].values
    y = df[target].values.reshape(-1, 1)

    X_shape_scaled = StandardScaler().fit_transform(X_shape)
    X_train_s, X_temp_s, X_train_spatial, X_temp_spatial, y_train, y_temp = train_test_split(
        X_shape_scaled, X_spatial, y, test_size=0.4, random_state=42)
    X_val_s, X_test_s, X_val_spatial, X_test_spatial, y_val, y_test = train_test_split(
        X_temp_s, X_temp_spatial, y_temp, test_size=0.5, random_state=42)

    # PCA
    pca = PCA(n_components=0.95)
    X_train_pca = pca.fit_transform(X_train_s)
    X_val_pca = pca.transform(X_val_s)
    X_test_pca = pca.transform(X_test_s)

    # Combine PCA + spatial
    X_train_final = np.hstack([X_train_pca, X_train_spatial])
    X_val_final = np.hstack([X_val_pca, X_val_spatial])
    X_test_final = np.hstack([X_test_pca, X_test_spatial])

    results = []
    best_r2 = -np.inf
    best_model = None
    best_config = None
    best_losses = None
    best_test_tensors = None

    for lr, batch_size, hidden_sizes, epochs in product(param_grid["lr"], param_grid["batch_size"],
                                                        param_grid["hidden_sizes"], param_grid["epochs"]):
        print(f"▶ Training: lr={lr}, batch={batch_size}, hidden={hidden_sizes}, epochs={epochs}")
        model, train_losses, X_test_tensor, y_test_tensor = run_fnn(
            X_train_final, X_val_final, X_test_final,
            y_train, y_val, y_test,
            input_size=X_train_final.shape[1],
            hidden_sizes=hidden_sizes,
            lr=lr,
            batch_size=batch_size,
            epochs=epochs
        )
        mse, r2, y_true, y_pred = evaluate_model(model, X_test_tensor, y_test_tensor)

        results.append({
            "lr": lr, "batch_size": batch_size, "hidden_sizes": str(hidden_sizes),
            "epochs": epochs, "mse": mse, "r2": r2
        })

        if r2 > best_r2:
            best_r2 = r2
            best_model = model
            best_config = {
                "lr": lr, "batch_size": batch_size,
                "hidden_sizes": hidden_sizes, "epochs": epochs
            }
            best_losses = train_losses
            best_test_tensors = (X_test_tensor, y_test_tensor, y_true, y_pred)

    # Save best model
    model_path = f"{output_root}/models/fnn_best_model.pt"
    torch.save(best_model.state_dict(), model_path)

    pd.DataFrame(results).to_csv(f"{output_root}/results/grid_search_results.csv", index=False)
    print(f"🏆 Best config: {best_config}, R²={best_r2:.4f}")
    return best_model, best_config, best_losses, best_test_tensors

# --- Entry Point ---
if __name__ == "__main__":
    param_grid = {
      "lr": [0.001, 0.0005,0.00001],
        "batch_size": [16, 32],
        "hidden_sizes": [(128, 64, 32), (64, 32, 16),(64,32,16,8),(8,16,32,64,32,16,8)],
        "epochs": [100, 200,300]
    }
    csv_path = "/home/MinaHossain/EmbedTrack/Track_EMBD_Result_Shape/Mean/Cells_Centroid_Velocity_TrueLabel_MA_Mean_5.csv"
    best_model, best_config, best_losses, (X_test_tensor, y_test_tensor, y_true, y_pred) = grid_search_fnn(csv_path, param_grid)
    plot_results(y_true, y_pred, train_losses=best_losses)
# Out:
# ▶ Training: lr=0.001, batch=16, hidden=(128, 64, 32), epochs=100
# Epoch 10: Loss=19.3236
# Epoch 20: Loss=15.7820
# Epoch 30: Loss=5.6735
# Epoch 40: Loss=2.5864
# Epoch 50: Loss=0.2326
# Epoch 60: Loss=0.2003
# Epoch 70: Loss=0.2480
# Epoch 80: Loss=0.0595
# Epoch 90: Loss=0.0221
# Epoch 100: Loss=0.0613
# ✅ MSE: 0.2669 | R²: 0.9872
# ▶ Training: lr=0.001, batch=16, hidden=(128, 64, 32), epochs=200
# Epoch 10: Loss=18.1375
# Epoch 20: Loss=17.1893
# Epoch 30: Loss=16.1777
# Epoch 40: Loss=17.2946
# Epoch 50: Loss=13.9979
# Epoch 60: Loss=9.7618
# Epoch 70: Loss=3.8585
# Epoch 80: Loss=0.2989
# Epoch 90: Loss=0.0989
# Epoch 100: Loss=0.0944
# Epoch 110: Loss=0.0358
# Epoch 120: Loss=0.0311
# Epoch 130: Loss=0.1125
# Epoch 140: Loss=0.1155
# Epoch 150: Loss=0.0194
# Epoch 160: Loss=0.0235
# Epoch 170: Loss=0.0322
# Epoch 180: Loss=0.0781
# Epoch 190: Loss=0.1344
# Epoch 200: Loss=0.0817
# ✅ MSE: 0.1184 | R²: 0.9943
# ▶ Training: lr=0.001, batch=16, hidden=(128, 64, 32), epochs=300
# Epoch 10: Loss=18.1565
# Epoch 20: Loss=13.0976
# Epoch 30: Loss=3.6649
# Epoch 40: Loss=0.5444
# Epoch 50: Loss=0.9475
# Epoch 60: Loss=0.0930
# Epoch 70: Loss=0.0942
# Epoch 80: Loss=0.0613
# Epoch 90: Loss=1.0069
# Epoch 100: Loss=0.0687
# Epoch 110: Loss=0.1572
# Epoch 120: Loss=0.0993
# Epoch 130: Loss=0.1166
# Epoch 140: Loss=0.0167
# Epoch 150: Loss=0.0628
# Epoch 160: Loss=0.1115
# Epoch 170: Loss=0.2719
# Epoch 180: Loss=0.0142
# Epoch 190: Loss=0.1668
# Epoch 200: Loss=0.1273
# Epoch 210: Loss=0.1895
# Epoch 220: Loss=0.4673
# Epoch 230: Loss=0.0106
# Epoch 240: Loss=0.0412
# Epoch 250: Loss=0.2136
# Epoch 260: Loss=0.1330
# Epoch 270: Loss=0.0232
# Epoch 280: Loss=0.0222
# Epoch 290: Loss=0.2518
# Epoch 300: Loss=0.1311
# ✅ MSE: 0.4030 | R²: 0.9807
# ▶ Training: lr=0.001, batch=16, hidden=(64, 32, 16), epochs=100
# Epoch 10: Loss=18.2328
# Epoch 20: Loss=16.4464
# Epoch 30: Loss=15.6013
# Epoch 40: Loss=4.2905
# Epoch 50: Loss=0.8634
# Epoch 60: Loss=0.3112
# Epoch 70: Loss=0.1179
# Epoch 80: Loss=0.1142
# Epoch 90: Loss=0.0769
# Epoch 100: Loss=0.0850
# ✅ MSE: 0.1611 | R²: 0.9923
# ▶ Training: lr=0.001, batch=16, hidden=(64, 32, 16), epochs=200
# Epoch 10: Loss=16.9214
# Epoch 20: Loss=13.2869
# Epoch 30: Loss=8.0963
# Epoch 40: Loss=1.5306
# Epoch 50: Loss=0.3350
# Epoch 60: Loss=0.2377
# Epoch 70: Loss=0.1918
# Epoch 80: Loss=8.9783
# Epoch 90: Loss=0.0973
# Epoch 100: Loss=0.2241
# Epoch 110: Loss=0.0663
# Epoch 120: Loss=0.1835
# Epoch 130: Loss=0.0451
# Epoch 140: Loss=0.0941
# Epoch 150: Loss=0.0403
# Epoch 160: Loss=2.1980
# Epoch 170: Loss=0.0402
# Epoch 180: Loss=0.0516
# Epoch 190: Loss=0.2163
# Epoch 200: Loss=0.2685
# ✅ MSE: 0.4795 | R²: 0.9770
# ▶ Training: lr=0.001, batch=16, hidden=(64, 32, 16), epochs=300
# Epoch 10: Loss=17.9715
# Epoch 20: Loss=16.4949
# Epoch 30: Loss=9.8874
# Epoch 40: Loss=1.4905
# Epoch 50: Loss=0.2471
# Epoch 60: Loss=0.4703
# Epoch 70: Loss=0.1753
# Epoch 80: Loss=0.2131
# Epoch 90: Loss=0.3375
# Epoch 100: Loss=0.1500
# Epoch 110: Loss=0.4323
# Epoch 120: Loss=0.0609
# Epoch 130: Loss=8.0869
# Epoch 140: Loss=0.0275
# Epoch 150: Loss=0.0202
# Epoch 160: Loss=0.0352
# Epoch 170: Loss=0.0564
# Epoch 180: Loss=0.0327
# Epoch 190: Loss=0.2572
# Epoch 200: Loss=0.0470
# Epoch 210: Loss=0.0316
# Epoch 220: Loss=0.0570
# Epoch 230: Loss=0.0293
# Epoch 240: Loss=0.0257
# Epoch 250: Loss=0.0195
# Epoch 260: Loss=0.5072
# Epoch 270: Loss=0.0211
# Epoch 280: Loss=0.0117
# Epoch 290: Loss=0.0207
# Epoch 300: Loss=0.0318
# ✅ MSE: 0.2866 | R²: 0.9863
# ▶ Training: lr=0.001, batch=16, hidden=(64, 32, 16, 8), epochs=100
# Epoch 10: Loss=17.9062
# Epoch 20: Loss=16.6610
# Epoch 30: Loss=9.8870
# Epoch 40: Loss=1.0018
# Epoch 50: Loss=0.1850
# Epoch 60: Loss=0.1885
# Epoch 70: Loss=0.0554
# Epoch 80: Loss=0.0254
# Epoch 90: Loss=0.1583
# Epoch 100: Loss=0.2216
# ✅ MSE: 0.6255 | R²: 0.9701
# ▶ Training: lr=0.001, batch=16, hidden=(64, 32, 16, 8), epochs=200
# Epoch 10: Loss=18.1844
# Epoch 20: Loss=17.2523
# Epoch 30: Loss=15.8242
# Epoch 40: Loss=10.4252
# Epoch 50: Loss=12.2790
# Epoch 60: Loss=6.1938
# Epoch 70: Loss=5.2007
# Epoch 80: Loss=4.8010
# Epoch 90: Loss=4.4818
# Epoch 100: Loss=4.2276
# Epoch 110: Loss=4.7817
# Epoch 120: Loss=4.1048
# Epoch 130: Loss=3.2814
# Epoch 140: Loss=3.8702
# Epoch 150: Loss=0.4593
# Epoch 160: Loss=0.1531
# Epoch 170: Loss=0.2400
# Epoch 180: Loss=0.2025
# Epoch 190: Loss=0.4812
# Epoch 200: Loss=0.1091
# ✅ MSE: 0.2037 | R²: 0.9902
# ▶ Training: lr=0.001, batch=16, hidden=(64, 32, 16, 8), epochs=300
# Epoch 10: Loss=17.8818
# Epoch 20: Loss=16.7635
# Epoch 30: Loss=0.6837
# Epoch 40: Loss=0.1060
# Epoch 50: Loss=0.0660
# Epoch 60: Loss=0.0621
# Epoch 70: Loss=0.0378
# Epoch 80: Loss=0.0246
# Epoch 90: Loss=0.0306
# Epoch 100: Loss=0.0200
# Epoch 110: Loss=0.0145
# Epoch 120: Loss=0.1039
# Epoch 130: Loss=0.0182
# Epoch 140: Loss=0.2564
# Epoch 150: Loss=0.0480
# Epoch 160: Loss=0.0492
# Epoch 170: Loss=0.5773
# Epoch 180: Loss=0.0114
# Epoch 190: Loss=0.0433
# Epoch 200: Loss=0.0059
# Epoch 210: Loss=0.0342
# Epoch 220: Loss=0.2416
# Epoch 230: Loss=0.0078
# Epoch 240: Loss=0.0131
# Epoch 250: Loss=0.0063
# Epoch 260: Loss=0.0226
# Epoch 270: Loss=0.0072
# Epoch 280: Loss=0.0166
# Epoch 290: Loss=0.1309
# Epoch 300: Loss=0.0217
# ✅ MSE: 0.0619 | R²: 0.9970
# ▶ Training: lr=0.001, batch=16, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=100
# Epoch 10: Loss=17.9300
# Epoch 20: Loss=17.7899
# Epoch 30: Loss=17.7695
# Epoch 40: Loss=17.8454
# Epoch 50: Loss=17.7655
# Epoch 60: Loss=17.7422
# Epoch 70: Loss=17.4378
# Epoch 80: Loss=17.7920
# Epoch 90: Loss=17.6946
# Epoch 100: Loss=17.7396
# ✅ MSE: 21.0885 | R²: -0.0096
# ▶ Training: lr=0.001, batch=16, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=200
# Epoch 10: Loss=17.7197
# Epoch 20: Loss=16.0753
# Epoch 30: Loss=17.9001
# Epoch 40: Loss=18.0469
# Epoch 50: Loss=17.9142
# Epoch 60: Loss=17.4707
# Epoch 70: Loss=12.2521
# Epoch 80: Loss=10.2511
# Epoch 90: Loss=6.0769
# Epoch 100: Loss=0.6935
# Epoch 110: Loss=0.3537
# Epoch 120: Loss=0.0788
# Epoch 130: Loss=0.0552
# Epoch 140: Loss=0.0169
# Epoch 150: Loss=0.2969
# Epoch 160: Loss=0.0783
# Epoch 170: Loss=0.1045
# Epoch 180: Loss=0.0663
# Epoch 190: Loss=0.1088
# Epoch 200: Loss=0.1093
# ✅ MSE: 0.1945 | R²: 0.9907
# ▶ Training: lr=0.001, batch=16, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=300
# Epoch 10: Loss=18.0990
# Epoch 20: Loss=18.0209
# Epoch 30: Loss=11.4252
# Epoch 40: Loss=2.2384
# Epoch 50: Loss=0.2811
# Epoch 60: Loss=0.2132
# Epoch 70: Loss=0.0735
# Epoch 80: Loss=0.1369
# Epoch 90: Loss=0.0733
# Epoch 100: Loss=0.0680
# Epoch 110: Loss=0.1618
# Epoch 120: Loss=0.1046
# Epoch 130: Loss=0.0868
# Epoch 140: Loss=0.0301
# Epoch 150: Loss=0.0950
# Epoch 160: Loss=0.0415
# Epoch 170: Loss=0.0090
# Epoch 180: Loss=0.1716
# Epoch 190: Loss=0.0395
# Epoch 200: Loss=0.0818
# Epoch 210: Loss=0.0736
# Epoch 220: Loss=0.0156
# Epoch 230: Loss=0.0198
# Epoch 240: Loss=0.0344
# Epoch 250: Loss=0.0073
# Epoch 260: Loss=0.0689
# Epoch 270: Loss=0.0183
# Epoch 280: Loss=0.0295
# Epoch 290: Loss=0.0533
# Epoch 300: Loss=0.0147
# ✅ MSE: 0.0358 | R²: 0.9983
# ▶ Training: lr=0.001, batch=32, hidden=(128, 64, 32), epochs=100
# Epoch 10: Loss=17.1832
# Epoch 20: Loss=15.8785
# Epoch 30: Loss=11.7277
# Epoch 40: Loss=2.6369
# Epoch 50: Loss=0.4293
# Epoch 60: Loss=0.2140
# Epoch 70: Loss=0.1018
# Epoch 80: Loss=0.5459
# Epoch 90: Loss=0.1480
# Epoch 100: Loss=0.0766
# ✅ MSE: 0.1637 | R²: 0.9922
# ▶ Training: lr=0.001, batch=32, hidden=(128, 64, 32), epochs=200
# Epoch 10: Loss=17.3338
# Epoch 20: Loss=17.1553
# Epoch 30: Loss=13.6502
# Epoch 40: Loss=5.6853
# Epoch 50: Loss=0.8186
# Epoch 60: Loss=0.1229
# Epoch 70: Loss=0.2861
# Epoch 80: Loss=0.0612
# Epoch 90: Loss=0.1624
# Epoch 100: Loss=0.1843
# Epoch 110: Loss=0.0751
# Epoch 120: Loss=0.0204
# Epoch 130: Loss=0.9615
# Epoch 140: Loss=0.0207
# Epoch 150: Loss=0.0232
# Epoch 160: Loss=0.0642
# Epoch 170: Loss=0.0495
# Epoch 180: Loss=0.0279
# Epoch 190: Loss=0.7212
# Epoch 200: Loss=0.1078
# ✅ MSE: 0.2237 | R²: 0.9893
# ▶ Training: lr=0.001, batch=32, hidden=(128, 64, 32), epochs=300
# Epoch 10: Loss=18.5816
# Epoch 20: Loss=16.2719
# Epoch 30: Loss=11.6713
# Epoch 40: Loss=5.7231
# Epoch 50: Loss=3.2920
# Epoch 60: Loss=0.4713
# Epoch 70: Loss=0.2379
# Epoch 80: Loss=0.1066
# Epoch 90: Loss=0.6612
# Epoch 100: Loss=0.0809
# Epoch 110: Loss=0.1785
# Epoch 120: Loss=0.1866
# Epoch 130: Loss=0.0911
# Epoch 140: Loss=0.0390
# Epoch 150: Loss=0.2556
# Epoch 160: Loss=0.0427
# Epoch 170: Loss=0.2137
# Epoch 180: Loss=0.0097
# Epoch 190: Loss=0.1369
# Epoch 200: Loss=0.0945
# Epoch 210: Loss=0.0256
# Epoch 220: Loss=0.0286
# Epoch 230: Loss=0.0891
# Epoch 240: Loss=0.0966
# Epoch 250: Loss=0.0310
# Epoch 260: Loss=0.0064
# Epoch 270: Loss=0.0585
# Epoch 280: Loss=0.0054
# Epoch 290: Loss=0.0073
# Epoch 300: Loss=0.0433
# ✅ MSE: 0.2105 | R²: 0.9899
# ▶ Training: lr=0.001, batch=32, hidden=(64, 32, 16), epochs=100
# Epoch 10: Loss=17.3770
# Epoch 20: Loss=17.0411
# Epoch 30: Loss=15.5292
# Epoch 40: Loss=12.0254
# Epoch 50: Loss=4.2604
# Epoch 60: Loss=0.8215
# Epoch 70: Loss=0.3955
# Epoch 80: Loss=0.2119
# Epoch 90: Loss=0.1583
# Epoch 100: Loss=0.1217
# ✅ MSE: 0.6541 | R²: 0.9687
# ▶ Training: lr=0.001, batch=32, hidden=(64, 32, 16), epochs=200
# Epoch 10: Loss=16.6821
# Epoch 20: Loss=17.2302
# Epoch 30: Loss=13.5705
# Epoch 40: Loss=10.1157
# Epoch 50: Loss=5.7039
# Epoch 60: Loss=1.5935
# Epoch 70: Loss=0.7604
# Epoch 80: Loss=0.5367
# Epoch 90: Loss=0.7078
# Epoch 100: Loss=0.2000
# Epoch 110: Loss=0.8213
# Epoch 120: Loss=1.2072
# Epoch 130: Loss=0.5636
# Epoch 140: Loss=0.1053
# Epoch 150: Loss=0.2878
# Epoch 160: Loss=0.1847
# Epoch 170: Loss=0.0667
# Epoch 180: Loss=0.1104
# Epoch 190: Loss=1.0145
# Epoch 200: Loss=0.0711
# ✅ MSE: 0.1967 | R²: 0.9906
# ▶ Training: lr=0.001, batch=32, hidden=(64, 32, 16), epochs=300
# Epoch 10: Loss=16.0750
# Epoch 20: Loss=14.6242
# Epoch 30: Loss=10.3350
# Epoch 40: Loss=8.0728
# Epoch 50: Loss=0.8341
# Epoch 60: Loss=0.3381
# Epoch 70: Loss=0.1047
# Epoch 80: Loss=0.0811
# Epoch 90: Loss=0.0410
# Epoch 100: Loss=0.0998
# Epoch 110: Loss=0.0932
# Epoch 120: Loss=3.2856
# Epoch 130: Loss=0.0423
# Epoch 140: Loss=0.0572
# Epoch 150: Loss=0.0143
# Epoch 160: Loss=0.0204
# Epoch 170: Loss=0.1268
# Epoch 180: Loss=0.0654
# Epoch 190: Loss=0.0498
# Epoch 200: Loss=0.0249
# Epoch 210: Loss=0.0232
# Epoch 220: Loss=0.0861
# Epoch 230: Loss=0.1401
# Epoch 240: Loss=0.1152
# Epoch 250: Loss=0.0134
# Epoch 260: Loss=0.0196
# Epoch 270: Loss=0.0170
# Epoch 280: Loss=0.0763
# Epoch 290: Loss=0.0113
# Epoch 300: Loss=2.5757
# ✅ MSE: 0.8231 | R²: 0.9606
# ▶ Training: lr=0.001, batch=32, hidden=(64, 32, 16, 8), epochs=100
# Epoch 10: Loss=18.0521
# Epoch 20: Loss=18.2730
# Epoch 30: Loss=17.3488
# Epoch 40: Loss=16.0076
# Epoch 50: Loss=12.7596
# Epoch 60: Loss=11.0985
# Epoch 70: Loss=6.6325
# Epoch 80: Loss=0.7041
# Epoch 90: Loss=0.1463
# Epoch 100: Loss=0.1784
# ✅ MSE: 0.1760 | R²: 0.9916
# ▶ Training: lr=0.001, batch=32, hidden=(64, 32, 16, 8), epochs=200
# Epoch 10: Loss=18.0449
# Epoch 20: Loss=16.7542
# Epoch 30: Loss=14.5357
# Epoch 40: Loss=12.1319
# Epoch 50: Loss=2.4822
# Epoch 60: Loss=1.5531
# Epoch 70: Loss=0.3415
# Epoch 80: Loss=0.4721
# Epoch 90: Loss=0.1163
# Epoch 100: Loss=0.1109
# Epoch 110: Loss=0.0998
# Epoch 120: Loss=1.1145
# Epoch 130: Loss=0.0393
# Epoch 140: Loss=0.0408
# Epoch 150: Loss=0.0283
# Epoch 160: Loss=0.0409
# Epoch 170: Loss=0.0444
# Epoch 180: Loss=0.1119
# Epoch 190: Loss=0.1609
# Epoch 200: Loss=0.0991
# ✅ MSE: 0.4244 | R²: 0.9797
# ▶ Training: lr=0.001, batch=32, hidden=(64, 32, 16, 8), epochs=300
# Epoch 10: Loss=17.9967
# Epoch 20: Loss=16.2779
# Epoch 30: Loss=8.5305
# Epoch 40: Loss=1.3091
# Epoch 50: Loss=0.3335
# Epoch 60: Loss=0.1508
# Epoch 70: Loss=0.2145
# Epoch 80: Loss=0.1226
# Epoch 90: Loss=0.0821
# Epoch 100: Loss=0.0719
# Epoch 110: Loss=0.3436
# Epoch 120: Loss=0.0418
# Epoch 130: Loss=0.3588
# Epoch 140: Loss=0.0769
# Epoch 150: Loss=0.1408
# Epoch 160: Loss=0.0510
# Epoch 170: Loss=0.1866
# Epoch 180: Loss=0.1124
# Epoch 190: Loss=0.2162
# Epoch 200: Loss=0.0485
# Epoch 210: Loss=0.0389
# Epoch 220: Loss=0.2145
# Epoch 230: Loss=0.0572
# Epoch 240: Loss=0.1124
# Epoch 250: Loss=0.0813
# Epoch 260: Loss=0.0339
# Epoch 270: Loss=0.0839
# Epoch 280: Loss=0.3396
# Epoch 290: Loss=0.0770
# Epoch 300: Loss=0.0237
# ✅ MSE: 0.3322 | R²: 0.9841
# ▶ Training: lr=0.001, batch=32, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=100
# Epoch 10: Loss=18.0559
# Epoch 20: Loss=17.6924
# Epoch 30: Loss=15.7246
# Epoch 40: Loss=10.7559
# Epoch 50: Loss=4.0238
# Epoch 60: Loss=1.0749
# Epoch 70: Loss=0.4165
# Epoch 80: Loss=0.1369
# Epoch 90: Loss=0.1393
# Epoch 100: Loss=0.0701
# ✅ MSE: 0.2156 | R²: 0.9897
# ▶ Training: lr=0.001, batch=32, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=200
# Epoch 10: Loss=17.7554
# Epoch 20: Loss=17.2543
# Epoch 30: Loss=16.2127
# Epoch 40: Loss=14.7378
# Epoch 50: Loss=9.0112
# Epoch 60: Loss=4.6381
# Epoch 70: Loss=0.4317
# Epoch 80: Loss=0.4481
# Epoch 90: Loss=0.6447
# Epoch 100: Loss=0.2143
# Epoch 110: Loss=0.0792
# Epoch 120: Loss=0.1062
# Epoch 130: Loss=0.2168
# Epoch 140: Loss=0.1017
# Epoch 150: Loss=0.1665
# Epoch 160: Loss=0.0872
# Epoch 170: Loss=0.2619
# Epoch 180: Loss=0.2247
# Epoch 190: Loss=0.0213
# Epoch 200: Loss=0.0145
# ✅ MSE: 0.0803 | R²: 0.9962
# ▶ Training: lr=0.001, batch=32, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=300
# Epoch 10: Loss=18.2270
# Epoch 20: Loss=17.8272
# Epoch 30: Loss=17.4605
# Epoch 40: Loss=14.6086
# Epoch 50: Loss=13.5257
# Epoch 60: Loss=0.9656
# Epoch 70: Loss=0.2594
# Epoch 80: Loss=0.2122
# Epoch 90: Loss=0.2130
# Epoch 100: Loss=0.0917
# Epoch 110: Loss=0.0547
# Epoch 120: Loss=0.0355
# Epoch 130: Loss=0.0607
# Epoch 140: Loss=0.0238
# Epoch 150: Loss=0.0451
# Epoch 160: Loss=0.0463
# Epoch 170: Loss=0.0176
# Epoch 180: Loss=0.0236
# Epoch 190: Loss=0.0809
# Epoch 200: Loss=0.0214
# Epoch 210: Loss=0.0101
# Epoch 220: Loss=0.0045
# Epoch 230: Loss=0.0083
# Epoch 240: Loss=0.0836
# Epoch 250: Loss=0.0081
# Epoch 260: Loss=0.2205
# Epoch 270: Loss=0.0159
# Epoch 280: Loss=0.0199
# Epoch 290: Loss=0.2364
# Epoch 300: Loss=0.0751
# ✅ MSE: 0.3710 | R²: 0.9822
# ▶ Training: lr=0.0005, batch=16, hidden=(128, 64, 32), epochs=100
# Epoch 10: Loss=18.1996
# Epoch 20: Loss=17.3498
# Epoch 30: Loss=15.1911
# Epoch 40: Loss=12.2604
# Epoch 50: Loss=4.4418
# Epoch 60: Loss=2.1169
# Epoch 70: Loss=0.8105
# Epoch 80: Loss=0.7679
# Epoch 90: Loss=0.4038
# Epoch 100: Loss=0.2725
# ✅ MSE: 0.3287 | R²: 0.9843
# ▶ Training: lr=0.0005, batch=16, hidden=(128, 64, 32), epochs=200
# Epoch 10: Loss=17.8303
# Epoch 20: Loss=16.9396
# Epoch 30: Loss=14.4261
# Epoch 40: Loss=11.0813
# Epoch 50: Loss=2.6338
# Epoch 60: Loss=1.3210
# Epoch 70: Loss=0.4753
# Epoch 80: Loss=0.3596
# Epoch 90: Loss=0.4523
# Epoch 100: Loss=0.2265
# Epoch 110: Loss=0.1164
# Epoch 120: Loss=0.3934
# Epoch 130: Loss=0.0895
# Epoch 140: Loss=0.1345
# Epoch 150: Loss=0.0475
# Epoch 160: Loss=0.0775
# Epoch 170: Loss=0.0670
# Epoch 180: Loss=0.5729
# Epoch 190: Loss=0.0366
# Epoch 200: Loss=0.7699
# ✅ MSE: 1.0311 | R²: 0.9506
# ▶ Training: lr=0.0005, batch=16, hidden=(128, 64, 32), epochs=300
# Epoch 10: Loss=18.3639
# Epoch 20: Loss=16.3751
# Epoch 30: Loss=14.4771
# Epoch 40: Loss=11.6855
# Epoch 50: Loss=3.5534
# Epoch 60: Loss=1.2144
# Epoch 70: Loss=0.8372
# Epoch 80: Loss=0.1912
# Epoch 90: Loss=0.1177
# Epoch 100: Loss=0.2155
# Epoch 110: Loss=0.1947
# Epoch 120: Loss=0.2132
# Epoch 130: Loss=0.0872
# Epoch 140: Loss=0.4581
# Epoch 150: Loss=0.0538
# Epoch 160: Loss=1.4484
# Epoch 170: Loss=0.1737
# Epoch 180: Loss=0.0410
# Epoch 190: Loss=0.0529
# Epoch 200: Loss=0.0504
# Epoch 210: Loss=0.0490
# Epoch 220: Loss=0.1850
# Epoch 230: Loss=0.0221
# Epoch 240: Loss=0.2732
# Epoch 250: Loss=0.0574
# Epoch 260: Loss=0.0136
# Epoch 270: Loss=0.0077
# Epoch 280: Loss=0.3537
# Epoch 290: Loss=0.0239
# Epoch 300: Loss=0.0115
# ✅ MSE: 0.1206 | R²: 0.9942
# ▶ Training: lr=0.0005, batch=16, hidden=(64, 32, 16), epochs=100
# Epoch 10: Loss=18.0752
# Epoch 20: Loss=16.4036
# Epoch 30: Loss=11.0642
# Epoch 40: Loss=8.6104
# Epoch 50: Loss=4.1655
# Epoch 60: Loss=1.1865
# Epoch 70: Loss=0.4498
# Epoch 80: Loss=0.2907
# Epoch 90: Loss=0.3213
# Epoch 100: Loss=0.1193
# ✅ MSE: 0.1464 | R²: 0.9930
# ▶ Training: lr=0.0005, batch=16, hidden=(64, 32, 16), epochs=200
# Epoch 10: Loss=17.9120
# Epoch 20: Loss=17.5622
# Epoch 30: Loss=15.8085
# Epoch 40: Loss=13.3413
# Epoch 50: Loss=6.3140
# Epoch 60: Loss=0.4523
# Epoch 70: Loss=0.0764
# Epoch 80: Loss=0.0467
# Epoch 90: Loss=0.0428
# Epoch 100: Loss=0.0920
# Epoch 110: Loss=0.0445
# Epoch 120: Loss=0.0200
# Epoch 130: Loss=0.0331
# Epoch 140: Loss=0.0154
# Epoch 150: Loss=0.0650
# Epoch 160: Loss=0.0305
# Epoch 170: Loss=0.1179
# Epoch 180: Loss=0.0297
# Epoch 190: Loss=0.2141
# Epoch 200: Loss=0.4313
# ✅ MSE: 2.1409 | R²: 0.8975
# ▶ Training: lr=0.0005, batch=16, hidden=(64, 32, 16), epochs=300
# Epoch 10: Loss=17.7452
# Epoch 20: Loss=16.7444
# Epoch 30: Loss=15.1460
# Epoch 40: Loss=13.8448
# Epoch 50: Loss=8.9544
# Epoch 60: Loss=2.9895
# Epoch 70: Loss=1.3496
# Epoch 80: Loss=0.3860
# Epoch 90: Loss=0.5618
# Epoch 100: Loss=0.3928
# Epoch 110: Loss=0.1285
# Epoch 120: Loss=0.3450
# Epoch 130: Loss=0.2231
# Epoch 140: Loss=0.0894
# Epoch 150: Loss=0.7621
# Epoch 160: Loss=0.0968
# Epoch 170: Loss=0.5958
# Epoch 180: Loss=0.1121
# Epoch 190: Loss=0.0745
# Epoch 200: Loss=0.0612
# Epoch 210: Loss=0.0664
# Epoch 220: Loss=0.3255
# Epoch 230: Loss=0.0612
# Epoch 240: Loss=0.0306
# Epoch 250: Loss=0.0448
# Epoch 260: Loss=0.2945
# Epoch 270: Loss=0.0720
# Epoch 280: Loss=0.0903
# Epoch 290: Loss=0.0437
# Epoch 300: Loss=0.0275
# ✅ MSE: 0.3412 | R²: 0.9837
# ▶ Training: lr=0.0005, batch=16, hidden=(64, 32, 16, 8), epochs=100
# Epoch 10: Loss=17.9784
# Epoch 20: Loss=17.1585
# Epoch 30: Loss=16.3566
# Epoch 40: Loss=10.6877
# Epoch 50: Loss=1.6073
# Epoch 60: Loss=0.7311
# Epoch 70: Loss=0.4619
# Epoch 80: Loss=0.2056
# Epoch 90: Loss=0.1940
# Epoch 100: Loss=0.0953
# ✅ MSE: 0.7335 | R²: 0.9649
# ▶ Training: lr=0.0005, batch=16, hidden=(64, 32, 16, 8), epochs=200
# Epoch 10: Loss=17.5680
# Epoch 20: Loss=16.4886
# Epoch 30: Loss=13.9901
# Epoch 40: Loss=5.1861
# Epoch 50: Loss=1.5566
# Epoch 60: Loss=0.5324
# Epoch 70: Loss=0.3319
# Epoch 80: Loss=0.2139
# Epoch 90: Loss=0.1526
# Epoch 100: Loss=0.1293
# Epoch 110: Loss=0.1468
# Epoch 120: Loss=0.1389
# Epoch 130: Loss=0.2222
# Epoch 140: Loss=0.0947
# Epoch 150: Loss=0.1457
# Epoch 160: Loss=0.2001
# Epoch 170: Loss=0.0865
# Epoch 180: Loss=0.0794
# Epoch 190: Loss=0.1241
# Epoch 200: Loss=0.2330
# ✅ MSE: 0.2594 | R²: 0.9876
# ▶ Training: lr=0.0005, batch=16, hidden=(64, 32, 16, 8), epochs=300
# Epoch 10: Loss=18.0720
# Epoch 20: Loss=16.4779
# Epoch 30: Loss=14.8276
# Epoch 40: Loss=10.5463
# Epoch 50: Loss=2.4687
# Epoch 60: Loss=0.5275
# Epoch 70: Loss=0.4957
# Epoch 80: Loss=0.2989
# Epoch 90: Loss=0.4149
# Epoch 100: Loss=0.2121
# Epoch 110: Loss=0.1192
# Epoch 120: Loss=0.0635
# Epoch 130: Loss=0.1837
# Epoch 140: Loss=0.0568
# Epoch 150: Loss=0.0478
# Epoch 160: Loss=0.0704
# Epoch 170: Loss=0.1167
# Epoch 180: Loss=0.0430
# Epoch 190: Loss=0.3462
# Epoch 200: Loss=0.0278
# Epoch 210: Loss=0.2632
# Epoch 220: Loss=0.0420
# Epoch 230: Loss=0.0320
# Epoch 240: Loss=0.0805
# Epoch 250: Loss=0.0243
# Epoch 260: Loss=0.0125
# Epoch 270: Loss=0.0955
# Epoch 280: Loss=0.1159
# Epoch 290: Loss=0.0221
# Epoch 300: Loss=0.0896
# ✅ MSE: 0.2873 | R²: 0.9862
# ▶ Training: lr=0.0005, batch=16, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=100
# Epoch 10: Loss=18.1262
# Epoch 20: Loss=17.8499
# Epoch 30: Loss=17.6512
# Epoch 40: Loss=17.3398
# Epoch 50: Loss=16.8232
# Epoch 60: Loss=16.1365
# Epoch 70: Loss=5.8016
# Epoch 80: Loss=1.6144
# Epoch 90: Loss=0.5661
# Epoch 100: Loss=0.6467
# ✅ MSE: 1.3206 | R²: 0.9368
# ▶ Training: lr=0.0005, batch=16, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=200
# Epoch 10: Loss=17.9540
# Epoch 20: Loss=17.8814
# Epoch 30: Loss=17.6279
# Epoch 40: Loss=2.9224
# Epoch 50: Loss=0.8995
# Epoch 60: Loss=1.0248
# Epoch 70: Loss=0.2454
# Epoch 80: Loss=0.1463
# Epoch 90: Loss=0.4300
# Epoch 100: Loss=0.1450
# Epoch 110: Loss=0.0639
# Epoch 120: Loss=0.0413
# Epoch 130: Loss=0.0443
# Epoch 140: Loss=0.1447
# Epoch 150: Loss=0.0361
# Epoch 160: Loss=0.0584
# Epoch 170: Loss=0.0303
# Epoch 180: Loss=0.0206
# Epoch 190: Loss=0.0184
# Epoch 200: Loss=0.1452
# ✅ MSE: 0.1663 | R²: 0.9920
# ▶ Training: lr=0.0005, batch=16, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=300
# Epoch 10: Loss=17.5915
# Epoch 20: Loss=17.3801
# Epoch 30: Loss=17.2370
# Epoch 40: Loss=17.0886
# Epoch 50: Loss=16.8851
# Epoch 60: Loss=16.0735
# Epoch 70: Loss=4.7156
# Epoch 80: Loss=4.2982
# Epoch 90: Loss=3.8313
# Epoch 100: Loss=0.7966
# Epoch 110: Loss=0.3925
# Epoch 120: Loss=0.2427
# Epoch 130: Loss=0.1635
# Epoch 140: Loss=0.2388
# Epoch 150: Loss=0.1241
# Epoch 160: Loss=0.1668
# Epoch 170: Loss=0.1525
# Epoch 180: Loss=0.1614
# Epoch 190: Loss=0.1158
# Epoch 200: Loss=0.1296
# Epoch 210: Loss=0.1931
# Epoch 220: Loss=0.1631
# Epoch 230: Loss=0.1394
# Epoch 240: Loss=0.0884
# Epoch 250: Loss=0.0482
# Epoch 260: Loss=0.0294
# Epoch 270: Loss=0.0205
# Epoch 280: Loss=0.0247
# Epoch 290: Loss=0.0249
# Epoch 300: Loss=0.0338
# ✅ MSE: 0.1213 | R²: 0.9942
# ▶ Training: lr=0.0005, batch=32, hidden=(128, 64, 32), epochs=100
# Epoch 10: Loss=18.6600
# Epoch 20: Loss=17.7100
# Epoch 30: Loss=17.9866
# Epoch 40: Loss=18.7423
# Epoch 50: Loss=11.0406
# Epoch 60: Loss=7.7353
# Epoch 70: Loss=7.6156
# Epoch 80: Loss=1.9534
# Epoch 90: Loss=0.7926
# Epoch 100: Loss=0.1491
# ✅ MSE: 0.1493 | R²: 0.9929
# ▶ Training: lr=0.0005, batch=32, hidden=(128, 64, 32), epochs=200
# Epoch 10: Loss=17.3021
# Epoch 20: Loss=17.3365
# Epoch 30: Loss=16.2575
# Epoch 40: Loss=15.9893
# Epoch 50: Loss=15.1419
# Epoch 60: Loss=12.0334
# Epoch 70: Loss=8.9536
# Epoch 80: Loss=4.0723
# Epoch 90: Loss=1.8641
# Epoch 100: Loss=1.1587
# Epoch 110: Loss=0.3263
# Epoch 120: Loss=0.1739
# Epoch 130: Loss=0.1688
# Epoch 140: Loss=0.1115
# Epoch 150: Loss=0.2490
# Epoch 160: Loss=0.1330
# Epoch 170: Loss=0.3121
# Epoch 180: Loss=0.2118
# Epoch 190: Loss=1.1836
# Epoch 200: Loss=0.6999
# ✅ MSE: 0.2382 | R²: 0.9886
# ▶ Training: lr=0.0005, batch=32, hidden=(128, 64, 32), epochs=300
# Epoch 10: Loss=17.0779
# Epoch 20: Loss=16.6274
# Epoch 30: Loss=16.1005
# Epoch 40: Loss=14.6464
# Epoch 50: Loss=16.2061
# Epoch 60: Loss=10.7064
# Epoch 70: Loss=5.2791
# Epoch 80: Loss=1.6859
# Epoch 90: Loss=1.1337
# Epoch 100: Loss=0.4017
# Epoch 110: Loss=0.2774
# Epoch 120: Loss=0.1142
# Epoch 130: Loss=0.1108
# Epoch 140: Loss=0.1378
# Epoch 150: Loss=0.1114
# Epoch 160: Loss=0.1921
# Epoch 170: Loss=0.1139
# Epoch 180: Loss=0.0679
# Epoch 190: Loss=0.4756
# Epoch 200: Loss=0.1759
# Epoch 210: Loss=0.0355
# Epoch 220: Loss=0.0582
# Epoch 230: Loss=0.7190
# Epoch 240: Loss=0.0855
# Epoch 250: Loss=0.0742
# Epoch 260: Loss=0.1294
# Epoch 270: Loss=0.1026
# Epoch 280: Loss=0.0226
# Epoch 290: Loss=0.1921
# Epoch 300: Loss=0.0314
# ✅ MSE: 0.3314 | R²: 0.9841
# ▶ Training: lr=0.0005, batch=32, hidden=(64, 32, 16), epochs=100
# Epoch 10: Loss=17.4978
# Epoch 20: Loss=17.8001
# Epoch 30: Loss=14.1724
# Epoch 40: Loss=12.5992
# Epoch 50: Loss=10.1001
# Epoch 60: Loss=3.2902
# Epoch 70: Loss=1.0652
# Epoch 80: Loss=0.9642
# Epoch 90: Loss=0.4947
# Epoch 100: Loss=0.2340
# ✅ MSE: 0.1950 | R²: 0.9907
# ▶ Training: lr=0.0005, batch=32, hidden=(64, 32, 16), epochs=200
# Epoch 10: Loss=17.6361
# Epoch 20: Loss=17.2535
# Epoch 30: Loss=16.6975
# Epoch 40: Loss=16.3984
# Epoch 50: Loss=16.0130
# Epoch 60: Loss=14.4700
# Epoch 70: Loss=13.3758
# Epoch 80: Loss=10.2335
# Epoch 90: Loss=6.1153
# Epoch 100: Loss=1.7374
# Epoch 110: Loss=0.4454
# Epoch 120: Loss=0.2062
# Epoch 130: Loss=0.1715
# Epoch 140: Loss=0.1034
# Epoch 150: Loss=0.0865
# Epoch 160: Loss=0.0913
# Epoch 170: Loss=0.0717
# Epoch 180: Loss=0.0592
# Epoch 190: Loss=0.0589
# Epoch 200: Loss=0.1119
# ✅ MSE: 0.1468 | R²: 0.9930
# ▶ Training: lr=0.0005, batch=32, hidden=(64, 32, 16), epochs=300
# Epoch 10: Loss=17.4744
# Epoch 20: Loss=17.3377
# Epoch 30: Loss=16.6665
# Epoch 40: Loss=15.9790
# Epoch 50: Loss=14.6264
# Epoch 60: Loss=12.0309
# Epoch 70: Loss=6.5919
# Epoch 80: Loss=2.3296
# Epoch 90: Loss=1.1709
# Epoch 100: Loss=0.3639
# Epoch 110: Loss=0.1914
# Epoch 120: Loss=0.1777
# Epoch 130: Loss=0.1701
# Epoch 140: Loss=0.0717
# Epoch 150: Loss=0.0726
# Epoch 160: Loss=0.0505
# Epoch 170: Loss=0.0450
# Epoch 180: Loss=0.0344
# Epoch 190: Loss=0.0281
# Epoch 200: Loss=0.0518
# Epoch 210: Loss=0.0187
# Epoch 220: Loss=0.0299
# Epoch 230: Loss=0.0538
# Epoch 240: Loss=0.1498
# Epoch 250: Loss=0.0181
# Epoch 260: Loss=0.0638
# Epoch 270: Loss=0.0935
# Epoch 280: Loss=0.0832
# Epoch 290: Loss=0.0223
# Epoch 300: Loss=0.0892
# ✅ MSE: 0.1560 | R²: 0.9925
# ▶ Training: lr=0.0005, batch=32, hidden=(64, 32, 16, 8), epochs=100
# Epoch 10: Loss=17.6253
# Epoch 20: Loss=17.1684
# Epoch 30: Loss=15.9887
# Epoch 40: Loss=17.1033
# Epoch 50: Loss=12.5765
# Epoch 60: Loss=8.2113
# Epoch 70: Loss=3.5017
# Epoch 80: Loss=0.9426
# Epoch 90: Loss=1.9336
# Epoch 100: Loss=0.2453
# ✅ MSE: 0.5896 | R²: 0.9718
# ▶ Training: lr=0.0005, batch=32, hidden=(64, 32, 16, 8), epochs=200
# Epoch 10: Loss=18.2268
# Epoch 20: Loss=17.6313
# Epoch 30: Loss=17.2603
# Epoch 40: Loss=17.1599
# Epoch 50: Loss=16.5632
# Epoch 60: Loss=13.6467
# Epoch 70: Loss=2.9881
# Epoch 80: Loss=1.7996
# Epoch 90: Loss=0.8056
# Epoch 100: Loss=0.4385
# Epoch 110: Loss=0.2288
# Epoch 120: Loss=0.1628
# Epoch 130: Loss=0.1237
# Epoch 140: Loss=0.1006
# Epoch 150: Loss=0.0673
# Epoch 160: Loss=0.0682
# Epoch 170: Loss=0.0362
# Epoch 180: Loss=0.0312
# Epoch 190: Loss=0.0628
# Epoch 200: Loss=0.1101
# ✅ MSE: 0.3463 | R²: 0.9834
# ▶ Training: lr=0.0005, batch=32, hidden=(64, 32, 16, 8), epochs=300
# Epoch 10: Loss=17.6304
# Epoch 20: Loss=18.3250
# Epoch 30: Loss=16.4108
# Epoch 40: Loss=15.0196
# Epoch 50: Loss=12.3440
# Epoch 60: Loss=10.8541
# Epoch 70: Loss=2.9992
# Epoch 80: Loss=1.3963
# Epoch 90: Loss=0.6354
# Epoch 100: Loss=0.2583
# Epoch 110: Loss=0.1473
# Epoch 120: Loss=0.1718
# Epoch 130: Loss=0.1597
# Epoch 140: Loss=0.1079
# Epoch 150: Loss=0.0440
# Epoch 160: Loss=0.0548
# Epoch 170: Loss=0.0828
# Epoch 180: Loss=0.0590
# Epoch 190: Loss=0.0536
# Epoch 200: Loss=0.0552
# Epoch 210: Loss=0.1004
# Epoch 220: Loss=0.1890
# Epoch 230: Loss=0.0246
# Epoch 240: Loss=0.1252
# Epoch 250: Loss=0.2824
# Epoch 260: Loss=0.0217
# Epoch 270: Loss=0.0218
# Epoch 280: Loss=0.0132
# Epoch 290: Loss=0.0587
# Epoch 300: Loss=0.0406
# ✅ MSE: 0.0350 | R²: 0.9983
# ▶ Training: lr=0.0005, batch=32, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=100
# Epoch 10: Loss=17.9981
# Epoch 20: Loss=17.7353
# Epoch 30: Loss=17.5702
# Epoch 40: Loss=17.1931
# Epoch 50: Loss=16.9281
# Epoch 60: Loss=17.1014
# Epoch 70: Loss=16.8926
# Epoch 80: Loss=16.4560
# Epoch 90: Loss=15.4338
# Epoch 100: Loss=11.0751
# ✅ MSE: 16.2641 | R²: 0.2213
# ▶ Training: lr=0.0005, batch=32, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=200
# Epoch 10: Loss=17.6201
# Epoch 20: Loss=17.3917
# Epoch 30: Loss=16.9216
# Epoch 40: Loss=16.7269
# Epoch 50: Loss=16.8673
# Epoch 60: Loss=16.4354
# Epoch 70: Loss=16.1606
# Epoch 80: Loss=16.0908
# Epoch 90: Loss=16.1202
# Epoch 100: Loss=15.6086
# Epoch 110: Loss=15.4672
# Epoch 120: Loss=14.8562
# Epoch 130: Loss=14.5064
# Epoch 140: Loss=13.9236
# Epoch 150: Loss=13.8663
# Epoch 160: Loss=13.5216
# Epoch 170: Loss=10.6936
# Epoch 180: Loss=10.0319
# Epoch 190: Loss=9.8799
# Epoch 200: Loss=9.8427
# ✅ MSE: 6.8747 | R²: 0.6709
# ▶ Training: lr=0.0005, batch=32, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=300
# Epoch 10: Loss=18.1153
# Epoch 20: Loss=18.0297
# Epoch 30: Loss=17.9341
# Epoch 40: Loss=18.0060
# Epoch 50: Loss=16.6721
# Epoch 60: Loss=15.2868
# Epoch 70: Loss=14.0646
# Epoch 80: Loss=17.1458
# Epoch 90: Loss=3.1928
# Epoch 100: Loss=2.0081
# Epoch 110: Loss=0.4445
# Epoch 120: Loss=0.1751
# Epoch 130: Loss=0.1050
# Epoch 140: Loss=0.2678
# Epoch 150: Loss=0.0415
# Epoch 160: Loss=0.0766
# Epoch 170: Loss=0.1380
# Epoch 180: Loss=0.0577
# Epoch 190: Loss=0.2581
# Epoch 200: Loss=0.0818
# Epoch 210: Loss=0.1403
# Epoch 220: Loss=0.0307
# Epoch 230: Loss=0.0159
# Epoch 240: Loss=0.0125
# Epoch 250: Loss=0.0190
# Epoch 260: Loss=0.0157
# Epoch 270: Loss=0.0488
# Epoch 280: Loss=0.0519
# Epoch 290: Loss=0.0347
# Epoch 300: Loss=0.0272
# ✅ MSE: 0.0659 | R²: 0.9968
# ▶ Training: lr=1e-05, batch=16, hidden=(128, 64, 32), epochs=100
# Epoch 10: Loss=19.8991
# Epoch 20: Loss=18.1558
# Epoch 30: Loss=17.9242
# Epoch 40: Loss=17.6475
# Epoch 50: Loss=17.5166
# Epoch 60: Loss=17.4014
# Epoch 70: Loss=17.3854
# Epoch 80: Loss=17.1733
# Epoch 90: Loss=17.0768
# Epoch 100: Loss=17.0242
# ✅ MSE: 20.8622 | R²: 0.0012
# ▶ Training: lr=1e-05, batch=16, hidden=(128, 64, 32), epochs=200
# Epoch 10: Loss=19.6002
# Epoch 20: Loss=18.3078
# Epoch 30: Loss=17.7732
# Epoch 40: Loss=17.4888
# Epoch 50: Loss=17.2847
# Epoch 60: Loss=17.0810
# Epoch 70: Loss=16.9099
# Epoch 80: Loss=16.8193
# Epoch 90: Loss=16.6591
# Epoch 100: Loss=16.4580
# Epoch 110: Loss=16.5041
# Epoch 120: Loss=16.3827
# Epoch 130: Loss=16.2829
# Epoch 140: Loss=16.3424
# Epoch 150: Loss=16.0852
# Epoch 160: Loss=16.1209
# Epoch 170: Loss=15.9313
# Epoch 180: Loss=15.8005
# Epoch 190: Loss=15.7053
# Epoch 200: Loss=15.6239
# ✅ MSE: 19.4335 | R²: 0.0696
# ▶ Training: lr=1e-05, batch=16, hidden=(128, 64, 32), epochs=300
# Epoch 10: Loss=17.9139
# Epoch 20: Loss=17.6277
# Epoch 30: Loss=17.4174
# Epoch 40: Loss=17.2238
# Epoch 50: Loss=17.0611
# Epoch 60: Loss=17.0602
# Epoch 70: Loss=16.7438
# Epoch 80: Loss=16.8246
# Epoch 90: Loss=16.4835
# Epoch 100: Loss=16.5005
# Epoch 110: Loss=16.2364
# Epoch 120: Loss=16.4307
# Epoch 130: Loss=16.1310
# Epoch 140: Loss=16.0951
# Epoch 150: Loss=16.0127
# Epoch 160: Loss=15.8694
# Epoch 170: Loss=15.7653
# Epoch 180: Loss=15.6691
# Epoch 190: Loss=15.9238
# Epoch 200: Loss=15.5609
# Epoch 210: Loss=15.5124
# Epoch 220: Loss=15.3351
# Epoch 230: Loss=15.3220
# Epoch 240: Loss=15.1976
# Epoch 250: Loss=15.1222
# Epoch 260: Loss=14.9871
# Epoch 270: Loss=14.8297
# Epoch 280: Loss=14.9706
# Epoch 290: Loss=14.8876
# Epoch 300: Loss=14.6734
# ✅ MSE: 17.7200 | R²: 0.1516
# ▶ Training: lr=1e-05, batch=16, hidden=(64, 32, 16), epochs=100
# Epoch 10: Loss=43.9456
# Epoch 20: Loss=20.3502
# Epoch 30: Loss=17.9505
# Epoch 40: Loss=17.4325
# Epoch 50: Loss=17.3027
# Epoch 60: Loss=17.2159
# Epoch 70: Loss=17.1518
# Epoch 80: Loss=17.0240
# Epoch 90: Loss=16.9468
# Epoch 100: Loss=16.9054
# ✅ MSE: 19.9515 | R²: 0.0448
# ▶ Training: lr=1e-05, batch=16, hidden=(64, 32, 16), epochs=200
# Epoch 10: Loss=20.2559
# Epoch 20: Loss=18.0871
# Epoch 30: Loss=17.7561
# Epoch 40: Loss=17.6330
# Epoch 50: Loss=17.5631
# Epoch 60: Loss=17.6186
# Epoch 70: Loss=17.4015
# Epoch 80: Loss=17.3465
# Epoch 90: Loss=17.3114
# Epoch 100: Loss=17.1822
# Epoch 110: Loss=17.1263
# Epoch 120: Loss=17.0674
# Epoch 130: Loss=17.0158
# Epoch 140: Loss=16.9793
# Epoch 150: Loss=16.9540
# Epoch 160: Loss=16.8742
# Epoch 170: Loss=16.7953
# Epoch 180: Loss=16.7422
# Epoch 190: Loss=16.7024
# Epoch 200: Loss=16.6334
# ✅ MSE: 19.3752 | R²: 0.0724
# ▶ Training: lr=1e-05, batch=16, hidden=(64, 32, 16), epochs=300
# Epoch 10: Loss=312.3544
# Epoch 20: Loss=92.2239
# Epoch 30: Loss=34.4734
# Epoch 40: Loss=22.0123
# Epoch 50: Loss=19.5191
# Epoch 60: Loss=18.5145
# Epoch 70: Loss=17.9854
# Epoch 80: Loss=17.6648
# Epoch 90: Loss=17.4020
# Epoch 100: Loss=17.3953
# Epoch 110: Loss=17.1158
# Epoch 120: Loss=17.0211
# Epoch 130: Loss=16.9416
# Epoch 140: Loss=16.8950
# Epoch 150: Loss=16.8095
# Epoch 160: Loss=16.7975
# Epoch 170: Loss=16.7152
# Epoch 180: Loss=16.6619
# Epoch 190: Loss=16.6401
# Epoch 200: Loss=16.5755
# Epoch 210: Loss=16.5069
# Epoch 220: Loss=16.4820
# Epoch 230: Loss=16.4456
# Epoch 240: Loss=16.3926
# Epoch 250: Loss=16.3964
# Epoch 260: Loss=16.3112
# Epoch 270: Loss=16.3006
# Epoch 280: Loss=16.2791
# Epoch 290: Loss=16.3443
# Epoch 300: Loss=16.1877
# ✅ MSE: 19.5235 | R²: 0.0653
# ▶ Training: lr=1e-05, batch=16, hidden=(64, 32, 16, 8), epochs=100
# Epoch 10: Loss=62.4413
# Epoch 20: Loss=23.0476
# Epoch 30: Loss=19.8168
# Epoch 40: Loss=19.1304
# Epoch 50: Loss=18.7657
# Epoch 60: Loss=18.4641
# Epoch 70: Loss=18.2651
# Epoch 80: Loss=18.0741
# Epoch 90: Loss=18.1062
# Epoch 100: Loss=17.9249
# ✅ MSE: 21.4342 | R²: -0.0262
# ▶ Training: lr=1e-05, batch=16, hidden=(64, 32, 16, 8), epochs=200
# Epoch 10: Loss=113.4295
# Epoch 20: Loss=38.5629
# Epoch 30: Loss=27.3854
# Epoch 40: Loss=23.2340
# Epoch 50: Loss=20.8868
# Epoch 60: Loss=19.5006
# Epoch 70: Loss=18.6909
# Epoch 80: Loss=18.2097
# Epoch 90: Loss=17.9683
# Epoch 100: Loss=17.7906
# Epoch 110: Loss=17.6901
# Epoch 120: Loss=17.5788
# Epoch 130: Loss=17.5188
# Epoch 140: Loss=17.4706
# Epoch 150: Loss=17.4409
# Epoch 160: Loss=17.3292
# Epoch 170: Loss=17.2858
# Epoch 180: Loss=17.2371
# Epoch 190: Loss=17.2026
# Epoch 200: Loss=17.1519
# ✅ MSE: 20.0980 | R²: 0.0378
# ▶ Training: lr=1e-05, batch=16, hidden=(64, 32, 16, 8), epochs=300
# Epoch 10: Loss=18.8783
# Epoch 20: Loss=18.3494
# Epoch 30: Loss=17.9677
# Epoch 40: Loss=17.8961
# Epoch 50: Loss=17.7977
# Epoch 60: Loss=17.7517
# Epoch 70: Loss=17.7718
# Epoch 80: Loss=17.6788
# Epoch 90: Loss=17.6417
# Epoch 100: Loss=17.5901
# Epoch 110: Loss=17.5697
# Epoch 120: Loss=17.5653
# Epoch 130: Loss=17.5092
# Epoch 140: Loss=17.4940
# Epoch 150: Loss=17.4574
# Epoch 160: Loss=17.4188
# Epoch 170: Loss=17.3848
# Epoch 180: Loss=17.3668
# Epoch 190: Loss=17.3637
# Epoch 200: Loss=17.3114
# Epoch 210: Loss=17.2506
# Epoch 220: Loss=17.2443
# Epoch 230: Loss=17.2114
# Epoch 240: Loss=17.1976
# Epoch 250: Loss=17.1520
# Epoch 260: Loss=17.1718
# Epoch 270: Loss=17.1181
# Epoch 280: Loss=17.0903
# Epoch 290: Loss=17.1338
# Epoch 300: Loss=17.0566
# ✅ MSE: 20.4979 | R²: 0.0186
# ▶ Training: lr=1e-05, batch=16, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=100
# Epoch 10: Loss=18.1959
# Epoch 20: Loss=18.1629
# Epoch 30: Loss=18.1093
# Epoch 40: Loss=18.0834
# Epoch 50: Loss=18.0598
# Epoch 60: Loss=18.1822
# Epoch 70: Loss=18.1258
# Epoch 80: Loss=18.0411
# Epoch 90: Loss=18.0302
# Epoch 100: Loss=18.0345
# ✅ MSE: 21.3617 | R²: -0.0227
# ▶ Training: lr=1e-05, batch=16, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=200
# Epoch 10: Loss=18.2743
# Epoch 20: Loss=18.1771
# Epoch 30: Loss=18.1460
# Epoch 40: Loss=18.1137
# Epoch 50: Loss=18.0556
# Epoch 60: Loss=18.1404
# Epoch 70: Loss=18.0301
# Epoch 80: Loss=18.0296
# Epoch 90: Loss=17.9955
# Epoch 100: Loss=17.9925
# Epoch 110: Loss=17.9925
# Epoch 120: Loss=17.9769
# Epoch 130: Loss=17.9699
# Epoch 140: Loss=17.9711
# Epoch 150: Loss=17.9528
# Epoch 160: Loss=17.9541
# Epoch 170: Loss=17.9598
# Epoch 180: Loss=17.9273
# Epoch 190: Loss=17.9290
# Epoch 200: Loss=17.9230
# ✅ MSE: 21.1579 | R²: -0.0130
# ▶ Training: lr=1e-05, batch=16, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=300
# Epoch 10: Loss=19.1128
# Epoch 20: Loss=18.5283
# Epoch 30: Loss=18.4344
# Epoch 40: Loss=18.4185
# Epoch 50: Loss=18.3857
# Epoch 60: Loss=18.3675
# Epoch 70: Loss=18.3650
# Epoch 80: Loss=18.3244
# Epoch 90: Loss=18.3270
# Epoch 100: Loss=18.3033
# Epoch 110: Loss=18.3070
# Epoch 120: Loss=18.2808
# Epoch 130: Loss=18.2704
# Epoch 140: Loss=18.2563
# Epoch 150: Loss=18.2480
# Epoch 160: Loss=18.2373
# Epoch 170: Loss=18.2400
# Epoch 180: Loss=18.2099
# Epoch 190: Loss=18.1950
# Epoch 200: Loss=18.2018
# Epoch 210: Loss=18.1843
# Epoch 220: Loss=18.1876
# Epoch 230: Loss=18.1986
# Epoch 240: Loss=18.1559
# Epoch 250: Loss=18.1437
# Epoch 260: Loss=18.1267
# Epoch 270: Loss=18.1179
# Epoch 280: Loss=18.1316
# Epoch 290: Loss=18.0935
# Epoch 300: Loss=18.0865
# ✅ MSE: 21.4176 | R²: -0.0254
# ▶ Training: lr=1e-05, batch=32, hidden=(128, 64, 32), epochs=100
# Epoch 10: Loss=33.1389
# Epoch 20: Loss=19.6548
# Epoch 30: Loss=18.8291
# Epoch 40: Loss=18.3720
# Epoch 50: Loss=18.1976
# Epoch 60: Loss=18.0047
# Epoch 70: Loss=17.8457
# Epoch 80: Loss=17.8115
# Epoch 90: Loss=17.6769
# Epoch 100: Loss=17.6095
# ✅ MSE: 21.2145 | R²: -0.0157
# ▶ Training: lr=1e-05, batch=32, hidden=(128, 64, 32), epochs=200
# Epoch 10: Loss=18.7281
# Epoch 20: Loss=18.2264
# Epoch 30: Loss=17.9256
# Epoch 40: Loss=17.6393
# Epoch 50: Loss=17.4812
# Epoch 60: Loss=17.3824
# Epoch 70: Loss=17.3929
# Epoch 80: Loss=17.1496
# Epoch 90: Loss=16.9856
# Epoch 100: Loss=16.9051
# Epoch 110: Loss=16.7979
# Epoch 120: Loss=16.8034
# Epoch 130: Loss=16.6215
# Epoch 140: Loss=16.4504
# Epoch 150: Loss=16.3624
# Epoch 160: Loss=16.3080
# Epoch 170: Loss=16.2037
# Epoch 180: Loss=16.1689
# Epoch 190: Loss=16.1465
# Epoch 200: Loss=16.1013
# ✅ MSE: 19.5930 | R²: 0.0620
# ▶ Training: lr=1e-05, batch=32, hidden=(128, 64, 32), epochs=300
# Epoch 10: Loss=20.8778
# Epoch 20: Loss=18.3379
# Epoch 30: Loss=17.9660
# Epoch 40: Loss=17.7896
# Epoch 50: Loss=17.4712
# Epoch 60: Loss=17.3447
# Epoch 70: Loss=17.3227
# Epoch 80: Loss=17.1293
# Epoch 90: Loss=17.0302
# Epoch 100: Loss=16.9385
# Epoch 110: Loss=16.8989
# Epoch 120: Loss=16.8137
# Epoch 130: Loss=16.7409
# Epoch 140: Loss=16.6905
# Epoch 150: Loss=16.6754
# Epoch 160: Loss=16.5098
# Epoch 170: Loss=16.4569
# Epoch 180: Loss=16.4813
# Epoch 190: Loss=16.3575
# Epoch 200: Loss=16.3149
# Epoch 210: Loss=16.2630
# Epoch 220: Loss=16.1692
# Epoch 230: Loss=16.1642
# Epoch 240: Loss=16.0245
# Epoch 250: Loss=15.9655
# Epoch 260: Loss=15.9335
# Epoch 270: Loss=15.8555
# Epoch 280: Loss=15.7952
# Epoch 290: Loss=15.7719
# Epoch 300: Loss=15.7078
# ✅ MSE: 18.8551 | R²: 0.0973
# ▶ Training: lr=1e-05, batch=32, hidden=(64, 32, 16), epochs=100
# Epoch 10: Loss=21.3826
# Epoch 20: Loss=19.1879
# Epoch 30: Loss=18.9450
# Epoch 40: Loss=18.8117
# Epoch 50: Loss=18.6501
# Epoch 60: Loss=18.4135
# Epoch 70: Loss=18.2803
# Epoch 80: Loss=18.2136
# Epoch 90: Loss=18.1397
# Epoch 100: Loss=18.0903
# ✅ MSE: 21.2148 | R²: -0.0157
# ▶ Training: lr=1e-05, batch=32, hidden=(64, 32, 16), epochs=200
# Epoch 10: Loss=768.0199
# Epoch 20: Loss=279.4100
# Epoch 30: Loss=105.6410
# Epoch 40: Loss=49.8545
# Epoch 50: Loss=31.3705
# Epoch 60: Loss=24.1475
# Epoch 70: Loss=21.6844
# Epoch 80: Loss=20.4020
# Epoch 90: Loss=19.3882
# Epoch 100: Loss=18.8079
# Epoch 110: Loss=18.1929
# Epoch 120: Loss=17.8976
# Epoch 130: Loss=17.6322
# Epoch 140: Loss=17.4936
# Epoch 150: Loss=17.4078
# Epoch 160: Loss=17.3253
# Epoch 170: Loss=17.2921
# Epoch 180: Loss=17.2539
# Epoch 190: Loss=17.2059
# Epoch 200: Loss=17.1928
# ✅ MSE: 20.5299 | R²: 0.0171
# ▶ Training: lr=1e-05, batch=32, hidden=(64, 32, 16), epochs=300
# Epoch 10: Loss=18.3322
# Epoch 20: Loss=17.9249
# Epoch 30: Loss=17.7088
# Epoch 40: Loss=17.6089
# Epoch 50: Loss=17.5275
# Epoch 60: Loss=17.4613
# Epoch 70: Loss=17.3630
# Epoch 80: Loss=17.3640
# Epoch 90: Loss=17.3023
# Epoch 100: Loss=17.1998
# Epoch 110: Loss=17.1663
# Epoch 120: Loss=17.1162
# Epoch 130: Loss=17.0740
# Epoch 140: Loss=16.9713
# Epoch 150: Loss=17.0346
# Epoch 160: Loss=16.9486
# Epoch 170: Loss=16.9304
# Epoch 180: Loss=16.8326
# Epoch 190: Loss=16.8206
# Epoch 200: Loss=16.7432
# Epoch 210: Loss=16.7053
# Epoch 220: Loss=16.7121
# Epoch 230: Loss=16.6284
# Epoch 240: Loss=16.5971
# Epoch 250: Loss=16.5463
# Epoch 260: Loss=16.5158
# Epoch 270: Loss=16.5913
# Epoch 280: Loss=16.4122
# Epoch 290: Loss=16.4210
# Epoch 300: Loss=16.3878
# ✅ MSE: 19.6365 | R²: 0.0599
# ▶ Training: lr=1e-05, batch=32, hidden=(64, 32, 16, 8), epochs=100
# Epoch 10: Loss=152.8737
# Epoch 20: Loss=77.1163
# Epoch 30: Loss=42.1458
# Epoch 40: Loss=29.5987
# Epoch 50: Loss=23.6796
# Epoch 60: Loss=21.4351
# Epoch 70: Loss=20.2490
# Epoch 80: Loss=19.3997
# Epoch 90: Loss=18.7814
# Epoch 100: Loss=18.4493
# ✅ MSE: 20.8632 | R²: 0.0011
# ▶ Training: lr=1e-05, batch=32, hidden=(64, 32, 16, 8), epochs=200
# Epoch 10: Loss=18.8003
# Epoch 20: Loss=18.0581
# Epoch 30: Loss=17.9919
# Epoch 40: Loss=17.9193
# Epoch 50: Loss=17.9188
# Epoch 60: Loss=17.8716
# Epoch 70: Loss=17.8099
# Epoch 80: Loss=17.7818
# Epoch 90: Loss=17.7782
# Epoch 100: Loss=17.7583
# Epoch 110: Loss=17.7132
# Epoch 120: Loss=17.7066
# Epoch 130: Loss=17.6745
# Epoch 140: Loss=17.6534
# Epoch 150: Loss=17.6519
# Epoch 160: Loss=17.6305
# Epoch 170: Loss=17.6186
# Epoch 180: Loss=17.5725
# Epoch 190: Loss=17.5948
# Epoch 200: Loss=17.5356
# ✅ MSE: 20.7568 | R²: 0.0062
# ▶ Training: lr=1e-05, batch=32, hidden=(64, 32, 16, 8), epochs=300
# Epoch 10: Loss=120.9234
# Epoch 20: Loss=52.5778
# Epoch 30: Loss=27.7142
# Epoch 40: Loss=20.6775
# Epoch 50: Loss=19.0783
# Epoch 60: Loss=18.7320
# Epoch 70: Loss=18.6261
# Epoch 80: Loss=18.5794
# Epoch 90: Loss=18.4280
# Epoch 100: Loss=18.3432
# Epoch 110: Loss=18.1140
# Epoch 120: Loss=18.0185
# Epoch 130: Loss=17.9401
# Epoch 140: Loss=17.8793
# Epoch 150: Loss=17.7873
# Epoch 160: Loss=17.7485
# Epoch 170: Loss=17.7041
# Epoch 180: Loss=17.6800
# Epoch 190: Loss=17.6398
# Epoch 200: Loss=17.6087
# Epoch 210: Loss=17.6126
# Epoch 220: Loss=17.5758
# Epoch 230: Loss=17.5662
# Epoch 240: Loss=17.5545
# Epoch 250: Loss=17.5129
# Epoch 260: Loss=17.5292
# Epoch 270: Loss=17.5636
# Epoch 280: Loss=17.4836
# Epoch 290: Loss=17.4397
# Epoch 300: Loss=17.4384
# ✅ MSE: 20.6459 | R²: 0.0115
# ▶ Training: lr=1e-05, batch=32, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=100
# Epoch 10: Loss=18.0273
# Epoch 20: Loss=18.0131
# Epoch 30: Loss=18.0013
# Epoch 40: Loss=17.9978
# Epoch 50: Loss=17.9734
# Epoch 60: Loss=17.9881
# Epoch 70: Loss=17.9666
# Epoch 80: Loss=17.9547
# Epoch 90: Loss=17.9865
# Epoch 100: Loss=17.9553
# ✅ MSE: 21.2729 | R²: -0.0185
# ▶ Training: lr=1e-05, batch=32, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=200
# Epoch 10: Loss=18.1298
# Epoch 20: Loss=18.1056
# Epoch 30: Loss=18.0818
# Epoch 40: Loss=18.0636
# Epoch 50: Loss=18.0423
# Epoch 60: Loss=18.0236
# Epoch 70: Loss=18.0390
# Epoch 80: Loss=18.0115
# Epoch 90: Loss=18.0124
# Epoch 100: Loss=17.9845
# Epoch 110: Loss=17.9797
# Epoch 120: Loss=17.9810
# Epoch 130: Loss=17.9710
# Epoch 140: Loss=17.9536
# Epoch 150: Loss=17.9571
# Epoch 160: Loss=17.9472
# Epoch 170: Loss=17.9415
# Epoch 180: Loss=17.9366
# Epoch 190: Loss=17.9327
# Epoch 200: Loss=17.9604
# ✅ MSE: 21.2254 | R²: -0.0162
# ▶ Training: lr=1e-05, batch=32, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=300
# Epoch 10: Loss=18.0960
# Epoch 20: Loss=18.1060
# Epoch 30: Loss=18.0728
# Epoch 40: Loss=18.0724
# Epoch 50: Loss=18.0854
# Epoch 60: Loss=18.0784
# Epoch 70: Loss=18.0640
# Epoch 80: Loss=18.0887
# Epoch 90: Loss=18.1270
# Epoch 100: Loss=18.0557
# Epoch 110: Loss=18.0563
# Epoch 120: Loss=18.1030
# Epoch 130: Loss=18.0547
# Epoch 140: Loss=18.0525
# Epoch 150: Loss=18.0561
# Epoch 160: Loss=18.1142
# Epoch 170: Loss=18.0461
# Epoch 180: Loss=18.0422
# Epoch 190: Loss=18.0366
# Epoch 200: Loss=18.0338
# Epoch 210: Loss=18.0525
# Epoch 220: Loss=18.0311
# Epoch 230: Loss=18.0547
# Epoch 240: Loss=18.0333
# Epoch 250: Loss=18.0964
# Epoch 260: Loss=18.0368
# Epoch 270: Loss=18.0352
# Epoch 280: Loss=18.0279
# Epoch 290: Loss=18.0170
# Epoch 300: Loss=18.0141
# ✅ MSE: 21.3181 | R²: -0.0206
# 🏆 Best config: {'lr': 0.0005, 'batch_size': 32, 'hidden_sizes': (64, 32, 16, 8), 'epochs': 300}, R²=0.9983
