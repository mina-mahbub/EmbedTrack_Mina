# %%
import phate
import scprep
import seaborn as sns
import os
import json
from PIL import Image, ImageDraw
import re
import numpy as np
import cv2
import imageio
import matplotlib.pyplot as plt
import tifffile as tiff
from tqdm import tqdm
from skimage.exposure import equalize_adapthist
from scipy.stats import stats
import matplotlib.animation as animation
import pandas as pd
import csv
import shutil
from skimage.morphology import dilation, erosion
import numpy as np
import matplotlib.pyplot as plt
import imageio
from skimage import measure
from skimage.measure import regionprops, label
from scipy.spatial import distance
import time
import datetime
from mpl_toolkits.mplot3d import Axes3D  # 3D Plotting
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import seaborn as sns
from sklearn.manifold import TSNE
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.stats.diagnostic import het_breuschpagan
from statsmodels.stats.stattools import durbin_watson
from sklearn.linear_model import Ridge, Lasso
from sklearn.preprocessing import StandardScaler, PowerTransformer
from sklearn.metrics import mean_squared_error, r2_score

from skimage.morphology import dilation, erosion
from skimage import measure
from scipy.ndimage import center_of_mass
from glob import glob
import random
from skimage.measure import regionprops, label
from scipy.spatial import distance

import imageio.v2 as imageio
from tifffile import imread

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score


from scipy import stats
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import RidgeCV, LassoCV, ElasticNetCV, LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Final Regression model

# %%
# === CONFIGURATION ===
input_path = "/home/MinaHossain/EmbedTrack/Track_EMBD_Result_Shape/Median/Cells_Centroid_Velocity_TrueLabel_MA_Median_5.csv"
output_root = "/home/MinaHossain/EmbedTrack/Track_EMBD_Result_Shape/Median"
plot_dir = f"{output_root}/Ridge_Plots"
os.makedirs(plot_dir, exist_ok=True)

# === LOAD AND CLEAN DATA ===
df = pd.read_csv(input_path)
collinear_features = ['Area_MA', 'Perimeter_MA', 'Solidity_MA', 'Extent_MA',
                      'Circularity_MA', 'Convexity_MA', 'Elongation_MA', 'Compactness_MA']
spatial_features = ['Centroid_X_MA', 'Centroid_Y_MA', 'X_Centroid_Distance_MA', 'Y_Centroid_Distance_MA']
target_col = 'X_Centroid_Velocity_MA'

df_clean = df[collinear_features + spatial_features + [target_col]].dropna()
X_collinear = df_clean[collinear_features].values
X_spatial = df_clean[spatial_features].values
y = df_clean[target_col].values

# === SPLIT DATA ===
X_col_train, X_col_temp, X_spatial_train, X_spatial_temp, y_train, y_temp = train_test_split(
    X_collinear, X_spatial, y, test_size=0.4, random_state=42)
X_col_val, X_col_test, X_spatial_val, X_spatial_test, y_val, y_test = train_test_split(
    X_col_temp, X_spatial_temp, y_temp, test_size=0.5, random_state=42)

# === PCA ON TRAIN ===
scaler = StandardScaler()
X_col_train_scaled = scaler.fit_transform(X_col_train)
X_col_val_scaled = scaler.transform(X_col_val)
X_col_test_scaled = scaler.transform(X_col_test)

pca = PCA(n_components=3)
X_pca_train = pca.fit_transform(X_col_train_scaled)
X_pca_val = pca.transform(X_col_val_scaled)
X_pca_test = pca.transform(X_col_test_scaled)

X_train_final = np.hstack([X_pca_train, X_spatial_train])
X_val_final = np.hstack([X_pca_val, X_spatial_val])
X_test_final = np.hstack([X_pca_test, X_spatial_test])

# === DEFINE MODELS ===
models = {
    # "LinearRegression": LinearRegression(),
    # "Ridge": RidgeCV(alphas=np.logspace(-3, 3, 50), cv=5),
    # "Lasso": LassoCV(cv=5, random_state=42, max_iter=10000),
    # "ElasticNet": ElasticNetCV(cv=5, random_state=42, max_iter=10000),
    # "RandomForest": RandomForestRegressor(n_estimators=100, max_depth=6, random_state=42, n_jobs=-1),
    "XGBoost": XGBRegressor(n_estimators=50, max_depth=4, learning_rate=0.1, random_state=42, n_jobs=-1, verbosity=0)
}

# === EVALUATE MODELS ON VALIDATION SET ===
results = {}
for name, model in models.items():
    try:
        model.fit(X_train_final, y_train)
        y_val_pred = model.predict(X_val_final)
        r2 = r2_score(y_val, y_val_pred)
        results[name] = r2
    except Exception as e:
        results[name] = f"Failed: {str(e)}"

best_model_name = max(results, key=lambda k: results[k] if isinstance(results[k], float) else -np.inf)
best_model = models[best_model_name]
best_model.fit(X_train_final, y_train)
y_test_pred = best_model.predict(X_test_final)

# === SAVE COEFFICIENTS AND PERFORMANCE ===
coeff_labels = [f'PC{i+1}' for i in range(3)] + spatial_features
coef_df = pd.DataFrame({'Feature': coeff_labels, 'Coefficient': best_model.coef_}) if hasattr(best_model, 'coef_') else pd.DataFrame()
metrics_df = pd.DataFrame({
    'Metric': ['R-squared', 'MSE'],
    'Value': [r2_score(y_test, y_test_pred), mean_squared_error(y_test, y_test_pred)]
})
coef_df.to_csv(f"{plot_dir}/best_model_coefficients.csv", index=False)
metrics_df.to_csv(f"{plot_dir}/best_model_metrics.csv", index=False)

# === PLOTTING ===
def plot_results(y_true, y_pred):
    residuals = y_true - y_pred
    absolute_errors = np.abs(residuals)

    def save_plot(fig, name):
        fig.tight_layout()
        fig.savefig(f"{plot_dir}/{name}.png")
        plt.close(fig)

    fig, ax = plt.subplots(figsize=(8, 5))
    sns.scatterplot(x=y_pred, y=residuals, ax=ax)
    ax.axhline(0, linestyle='--', color='red')
    ax.set_title("Residuals vs Predicted")
    ax.set_xlabel("Predicted")
    ax.set_ylabel("Residuals")
    save_plot(fig, "residuals_vs_predicted")

    fig, ax = plt.subplots(figsize=(8, 5))
    sns.scatterplot(x=y_true, y=y_pred, ax=ax)
    ax.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], linestyle='--', color='red')
    ax.set_title("Predicted vs Actual")
    ax.set_xlabel("Actual")
    ax.set_ylabel("Predicted")
    save_plot(fig, "predicted_vs_actual")

    fig, ax = plt.subplots(figsize=(8, 5))
    sns.histplot(residuals, bins=30, kde=True, ax=ax)
    ax.set_title("Distribution of Residuals")
    ax.set_xlabel("Residuals")
    save_plot(fig, "residuals_distribution")

    fig, ax = plt.subplots(figsize=(8, 5))
    sorted_errors = np.sort(absolute_errors)
    cum_dist = np.arange(1, len(sorted_errors) + 1) / len(sorted_errors)
    ax.plot(sorted_errors, cum_dist)
    ax.set_title("Cumulative Distribution of Absolute Errors")
    ax.set_xlabel("Absolute Error")
    ax.set_ylabel("Cumulative Proportion")
    save_plot(fig, "cumulative_absolute_errors")

    fig = plt.figure(figsize=(6, 6))
    stats.probplot(residuals, dist="norm", plot=plt)
    plt.title("Q-Q Plot of Residuals")
    save_plot(fig, "qq_plot_residuals")

    fig, ax = plt.subplots(figsize=(8, 5))
    sns.scatterplot(x=y_true, y=absolute_errors, ax=ax)
    ax.set_title("Absolute Error vs Actual Value")
    ax.set_xlabel("Actual Values")
    ax.set_ylabel("Absolute Error")
    save_plot(fig, "absolute_error_vs_actual")

plot_results(y_test, y_test_pred)

# === REPORT ON SPLITS ===
y_train_pred = best_model.predict(X_train_final)
y_val_pred = best_model.predict(X_val_final)
y_test_pred = best_model.predict(X_test_final)

performance = pd.DataFrame({
    "Split": ["Train", "Validation", "Test"],
    "R-squared": [
        r2_score(y_train, y_train_pred),
        r2_score(y_val, y_val_pred),
        r2_score(y_test, y_test_pred)
    ],
    "MSE": [
        mean_squared_error(y_train, y_train_pred),
        mean_squared_error(y_val, y_val_pred),
        mean_squared_error(y_test, y_test_pred)
    ]
})

performance.to_csv(f"{plot_dir}/model_performance_by_split.csv", index=False)
print(f"Best model: {best_model_name}")
print(performance)


# Generate the code block for PCA + Clustering using validation data and applying to test data


# === PCA + KMeans CLUSTERING (Fit on Validation, Apply to Test) ===
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

output_directory = plot_dir
window_size = 5

# --- Fit PCA on Validation Set ---
X_scaled_val = X_col_val_scaled
pca_full = PCA()
pca_full.fit(X_scaled_val)
explained_variance = pca_full.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance)

optimal_components = np.argmax(cumulative_variance >= 0.95) + 1

# --- Plot PCA Cumulative Variance (Elbow Plot) ---
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker='s', linestyle='-', color='red', label="Cumulative Variance")
plt.axvline(x=optimal_components, color='green', linestyle='--', label=f"Optimal Components ({optimal_components})")
plt.scatter(optimal_components, cumulative_variance[optimal_components-1], color='black', s=50, label="Chosen Point")
plt.xlabel("Number of Principal Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("PCA Elbow Plot with Cumulative Variance")
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig(os.path.join(output_directory, f"PCA_Elbow_Plot_{window_size}.png"))
plt.close()

# --- Fit 2D PCA on Validation ---
pca_2d = PCA(n_components=2)
pca_val_2d = pca_2d.fit_transform(X_scaled_val)

# --- KMeans on 2D PCA space (Validation) ---
silhouette_scores = []
k_range = range(2, 15)
for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=0, n_init='auto').fit(pca_val_2d)
    score = silhouette_score(pca_val_2d, kmeans.labels_)
    silhouette_scores.append(score)

optimal_k = k_range[np.argmax(silhouette_scores)]
optimal_score = max(silhouette_scores)

# --- Plot Silhouette Scores ---
plt.figure(figsize=(8, 6))
plt.plot(k_range, silhouette_scores, marker='o', linestyle='-', color='purple', label="Silhouette Score")
plt.axvline(x=optimal_k, color='green', linestyle='--', label=f"Optimal k = {optimal_k}")
plt.scatter(optimal_k, optimal_score, color='red', s=100, zorder=5)
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score vs Number of Clusters (Validation)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig(os.path.join(output_directory, f"Silhouette_Score_vs_K_{window_size}.png"))
plt.close()

# --- Apply to Test Data ---
X_scaled_test = X_col_test_scaled
pca_test_2d = pca_2d.transform(X_scaled_test)
kmeans_final = KMeans(n_clusters=optimal_k, random_state=0, n_init='auto').fit(pca_val_2d)
test_clusters = kmeans_final.predict(pca_test_2d)

# --- Create Test DataFrame with PCA + Clusters ---
pca_test_df = pd.DataFrame(pca_test_2d, columns=["PCA1", "PCA2"])
pca_test_df["X_Centroid_Velocity_MA"] = X_col_test[:, 0]  # Area_MA is first collinear feature
pca_test_df["Cluster"] = test_clusters

# --- Clustered 2D PCA (Colored by Area) ---
vmin = np.percentile(pca_test_df["X_Centroid_Velocity_MA"], 5)
vmax = np.percentile(pca_test_df["X_Centroid_Velocity_MA"], 95)
plt.figure(figsize=(10, 7))
sc = plt.scatter(pca_test_df["PCA1"], pca_test_df["PCA2"], c=pca_test_df["X_Centroid_Velocity_MA"], cmap="plasma", alpha=0.8, vmin=vmin, vmax=vmax)
plt.colorbar(sc, label="X_Centroid Velocity (MA)")
plt.title("2D PCA Test Data Colored by X_Centroid Velocity(MA)")
plt.xlabel("PCA1")
plt.ylabel("PCA2")
plt.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(output_directory, f"PCA_2D_X_Centroid_Velocity_MA_{window_size}.png"))
plt.close()

# --- Cluster Plot with Centers ---
plt.figure(figsize=(10, 7))
plt.scatter(pca_test_df["PCA1"], pca_test_df["PCA2"], c=pca_test_df["Cluster"], cmap="tab10", alpha=0.8)
centers = kmeans_final.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, marker='o', label='Centers')
for idx, (x, y) in enumerate(centers):
    plt.text(x, y, str(idx), fontsize=12, fontweight='bold', ha='center', va='center', color='white',
             bbox=dict(facecolor='black', boxstyle='circle,pad=0.2'))
plt.title(f"Test Data PCA with KMeans Clusters (k={optimal_k})")
plt.xlabel("PCA1")
plt.ylabel("PCA2")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(output_directory, f"PCA_2D_Clusters_X_Centroid_Velocity_MA_{window_size}.png"))
plt.close()

# --- Boxplot: Area by Cluster (Test Data) ---
plt.figure(figsize=(10, 6))
sns.boxplot(data=pca_test_df, x="Cluster", y="X_Centroid_Velocity_MA", palette="Set2")
sns.stripplot(data=pca_test_df, x="Cluster", y="X_Centroid_Velocity_MA", color='gray', alpha=0.5, jitter=0.2, size=3)
plt.title("X_Centroid Velocity (MA) by Cluster (Test Data)", fontsize=14)
plt.xlabel("Cluster")
plt.ylabel("X_Centroid Velocity (MA)")
plt.tight_layout()
plt.savefig(os.path.join(output_directory, f"Boxplot_X_Centroid_Velocity_MA_By_Cluster_{window_size}.png"))
plt.close()

# --- Save clustered PCA test data and summary ---
pca_test_df.to_csv(os.path.join(output_directory, f"PCA_Cluster_Results_Test_{window_size}.csv"), index=False)

summary = pca_test_df.groupby("Cluster").agg({
    "PCA1": ["mean", "std"],
    "PCA2": ["mean", "std"],
    "X_Centroid_Velocity_MA": ["mean", "std"]
}).reset_index()
summary.columns = ["_".join(col).strip("_") for col in summary.columns.values]
summary.to_csv(os.path.join(output_directory, f"PCA_Cluster_Summary_Test_{window_size}.csv"), index=False)
# Out:
# Best model: XGBoost
#         Split  R-squared       MSE
# 0       Train   0.996728  0.108611
# 1  Validation   0.996059  0.045663
# 2        Test   0.916845  0.964100
# /tmp/ipykernel_3074577/345542730.py:261: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=pca_test_df, x="Cluster", y="X_Centroid_Velocity_MA", palette="Set2")

# %% [markdown]
# # Create the updated FNN pipeline script content with PCA + spatial features + grid search

# %%
import os
import argparse
import datetime
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset
from itertools import product

# --- CONFIG ---
output_root = "/home/MinaHossain/EmbedTrack/Track_EMBD_Result_Shape/Median/Reg_Analysis_FNN_PCA"
os.makedirs(f"{output_root}/models", exist_ok=True)
os.makedirs(f"{output_root}/results", exist_ok=True)
os.makedirs(f"{output_root}/plots", exist_ok=True)

# --- FNN Model ---
class FNN(nn.Module):
    def __init__(self, input_size, hidden_sizes):
        super(FNN, self).__init__()
        layers = [nn.Linear(input_size, hidden_sizes[0]), nn.ReLU()]
        for i in range(1, len(hidden_sizes)):
            layers.append(nn.Linear(hidden_sizes[i-1], hidden_sizes[i]))
            layers.append(nn.ReLU())
        layers.append(nn.Linear(hidden_sizes[-1], 1))
        self.model = nn.Sequential(*layers)

    def forward(self, x):
        return self.model(x)

# --- Evaluation ---
def evaluate_model(model, X_test_tensor, y_test_tensor):
    model.eval()
    with torch.no_grad():
        y_pred_tensor = model(X_test_tensor)
    y_pred = y_pred_tensor.cpu().numpy().flatten()
    y_true = y_test_tensor.cpu().numpy().flatten()
    mse = mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"✅ MSE: {mse:.4f} | R²: {r2:.4f}")
    return mse, r2, y_true, y_pred

# --- Plotting ---
def plot_results(y_true, y_pred, train_losses=None):
    residuals = y_true - y_pred
    if train_losses:
        plt.figure(); plt.plot(train_losses); plt.title("Training Loss"); plt.tight_layout()
        plt.savefig(f"{output_root}/plots/loss_curve.png"); plt.close()
    plt.figure(); sns.scatterplot(x=y_pred, y=residuals); plt.axhline(0, linestyle='--', color='red')
    plt.title("Residuals vs Predicted"); plt.tight_layout()
    plt.savefig(f"{output_root}/plots/residuals_vs_predicted.png"); plt.close()
    plt.figure(); sns.scatterplot(x=y_true, y=y_pred); plt.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], 'r--')
    plt.title("Predicted vs Actual"); plt.tight_layout()
    plt.savefig(f"{output_root}/plots/predicted_vs_actual.png"); plt.close()
    plt.figure(); sns.histplot(residuals, bins=30, kde=True)
    plt.title("Distribution of Residuals"); plt.tight_layout()
    plt.savefig(f"{output_root}/plots/residuals_distribution.png"); plt.close()
    plt.figure(); plt.plot(np.sort(np.abs(residuals)), np.linspace(0, 1, len(residuals)))
    plt.title("Cumulative Absolute Errors"); plt.tight_layout()
    plt.savefig(f"{output_root}/plots/cumulative_absolute_errors.png"); plt.close()
    plt.figure(); stats.probplot(residuals, dist="norm", plot=plt)
    plt.title("Q-Q Plot"); plt.tight_layout()
    plt.savefig(f"{output_root}/plots/qq_plot_residuals.png"); plt.close()
    plt.figure(); sns.scatterplot(x=y_true, y=np.abs(residuals))
    plt.title("Absolute Error vs Actual"); plt.tight_layout()
    plt.savefig(f"{output_root}/plots/absolute_error_vs_actual.png"); plt.close()

# --- Run FNN ---
def run_fnn(X_train, X_val, X_test, y_train, y_val, y_test, input_size, hidden_sizes, lr, batch_size, epochs):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = FNN(input_size=input_size, hidden_sizes=hidden_sizes).to(device)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)

    X_train_tensor = torch.tensor(X_train).float().to(device)
    y_train_tensor = torch.tensor(y_train).float().to(device)
    X_val_tensor = torch.tensor(X_val).float().to(device)
    y_val_tensor = torch.tensor(y_val).float().to(device)
    X_test_tensor = torch.tensor(X_test).float().to(device)
    y_test_tensor = torch.tensor(y_test).float().to(device)

    train_loader = DataLoader(TensorDataset(X_train_tensor, y_train_tensor), batch_size=batch_size, shuffle=True)

    train_losses = []
    for epoch in range(epochs):
        model.train()
        total_loss = 0
        for xb, yb in train_loader:
            optimizer.zero_grad()
            pred = model(xb)
            loss = criterion(pred, yb)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        train_losses.append(total_loss / len(train_loader))
        if (epoch + 1) % 10 == 0:
            print(f"Epoch {epoch+1}: Loss={train_losses[-1]:.4f}")

    return model, train_losses, X_test_tensor, y_test_tensor

# --- Grid Search ---
def grid_search_fnn(csv_path, param_grid):
    df = pd.read_csv(csv_path)
    shape_features = ['Area_MA', 'Perimeter_MA', 'Extent_MA', 'Solidity_MA', 'Compactness_MA', 'Elongation_MA', 'Circularity_MA', 'Convexity_MA']
    spatial_features = ['Centroid_X_MA', 'Centroid_Y_MA', 'X_Centroid_Distance_MA', 'Y_Centroid_Distance_MA']
    target = 'X_Centroid_Velocity_MA'
    df = df.dropna(subset=shape_features + spatial_features + [target])

    X_shape = df[shape_features].values
    X_spatial = df[spatial_features].values
    y = df[target].values.reshape(-1, 1)

    X_shape_scaled = StandardScaler().fit_transform(X_shape)
    X_train_s, X_temp_s, X_train_spatial, X_temp_spatial, y_train, y_temp = train_test_split(
        X_shape_scaled, X_spatial, y, test_size=0.4, random_state=42)
    X_val_s, X_test_s, X_val_spatial, X_test_spatial, y_val, y_test = train_test_split(
        X_temp_s, X_temp_spatial, y_temp, test_size=0.5, random_state=42)

    # PCA
    pca = PCA(n_components=0.95)
    X_train_pca = pca.fit_transform(X_train_s)
    X_val_pca = pca.transform(X_val_s)
    X_test_pca = pca.transform(X_test_s)

    # Combine PCA + spatial
    X_train_final = np.hstack([X_train_pca, X_train_spatial])
    X_val_final = np.hstack([X_val_pca, X_val_spatial])
    X_test_final = np.hstack([X_test_pca, X_test_spatial])

    results = []
    best_r2 = -np.inf
    best_model = None
    best_config = None
    best_losses = None
    best_test_tensors = None

    for lr, batch_size, hidden_sizes, epochs in product(param_grid["lr"], param_grid["batch_size"],
                                                        param_grid["hidden_sizes"], param_grid["epochs"]):
        print(f"▶ Training: lr={lr}, batch={batch_size}, hidden={hidden_sizes}, epochs={epochs}")
        model, train_losses, X_test_tensor, y_test_tensor = run_fnn(
            X_train_final, X_val_final, X_test_final,
            y_train, y_val, y_test,
            input_size=X_train_final.shape[1],
            hidden_sizes=hidden_sizes,
            lr=lr,
            batch_size=batch_size,
            epochs=epochs
        )
        mse, r2, y_true, y_pred = evaluate_model(model, X_test_tensor, y_test_tensor)

        results.append({
            "lr": lr, "batch_size": batch_size, "hidden_sizes": str(hidden_sizes),
            "epochs": epochs, "mse": mse, "r2": r2
        })

        if r2 > best_r2:
            best_r2 = r2
            best_model = model
            best_config = {
                "lr": lr, "batch_size": batch_size,
                "hidden_sizes": hidden_sizes, "epochs": epochs
            }
            best_losses = train_losses
            best_test_tensors = (X_test_tensor, y_test_tensor, y_true, y_pred)

    # Save best model
    model_path = f"{output_root}/models/fnn_best_model.pt"
    torch.save(best_model.state_dict(), model_path)

    pd.DataFrame(results).to_csv(f"{output_root}/results/grid_search_results.csv", index=False)
    print(f"🏆 Best config: {best_config}, R²={best_r2:.4f}")
    return best_model, best_config, best_losses, best_test_tensors

# --- Entry Point ---
if __name__ == "__main__":
    param_grid = {
        "lr": [0.001, 0.0005,0.00001],
        "batch_size": [16, 32],
        "hidden_sizes": [(128, 64, 32), (64, 32, 16),(64,32,16,8),(8,16,32,64,32,16,8)],
        "epochs": [100, 200,300]
    }
    csv_path = "/home/MinaHossain/EmbedTrack/Track_New_Result_Shape/Median/Cells_Centroid_Velocity_TrueLabel_MA_Median_5.csv"
    best_model, best_config, best_losses, (X_test_tensor, y_test_tensor, y_true, y_pred) = grid_search_fnn(csv_path, param_grid)
    plot_results(y_true, y_pred, train_losses=best_losses)
# Out:
# ▶ Training: lr=0.001, batch=16, hidden=(128, 64, 32), epochs=100
# Epoch 10: Loss=36.3944
# Epoch 20: Loss=31.2367
# Epoch 30: Loss=11.3344
# Epoch 40: Loss=9.9017
# Epoch 50: Loss=9.4405
# Epoch 60: Loss=4.4220
# Epoch 70: Loss=5.4241
# Epoch 80: Loss=3.9423
# Epoch 90: Loss=5.2508
# Epoch 100: Loss=5.2816
# ✅ MSE: 13.0347 | R²: 0.6386
# ▶ Training: lr=0.001, batch=16, hidden=(128, 64, 32), epochs=200
# Epoch 10: Loss=37.7422
# Epoch 20: Loss=29.1949
# Epoch 30: Loss=15.7549
# Epoch 40: Loss=6.3029
# Epoch 50: Loss=4.5938
# Epoch 60: Loss=6.4549
# Epoch 70: Loss=5.0735
# Epoch 80: Loss=6.2158
# Epoch 90: Loss=5.0749
# Epoch 100: Loss=6.1349
# Epoch 110: Loss=4.2883
# Epoch 120: Loss=4.1000
# Epoch 130: Loss=9.2812
# Epoch 140: Loss=3.1869
# Epoch 150: Loss=2.7398
# Epoch 160: Loss=2.6845
# Epoch 170: Loss=15.1445
# Epoch 180: Loss=1.8563
# Epoch 190: Loss=19.8593
# Epoch 200: Loss=2.0967
# ✅ MSE: 17.2162 | R²: 0.5227
# ▶ Training: lr=0.001, batch=16, hidden=(128, 64, 32), epochs=300
# Epoch 10: Loss=41.2870
# Epoch 20: Loss=35.8674
# Epoch 30: Loss=30.3807
# Epoch 40: Loss=15.9991
# Epoch 50: Loss=4.8247
# Epoch 60: Loss=5.1953
# Epoch 70: Loss=4.4761
# Epoch 80: Loss=4.7253
# Epoch 90: Loss=5.8481
# Epoch 100: Loss=3.9100
# Epoch 110: Loss=5.8412
# Epoch 120: Loss=5.2017
# Epoch 130: Loss=4.9362
# Epoch 140: Loss=4.2384
# Epoch 150: Loss=4.9607
# Epoch 160: Loss=4.3281
# Epoch 170: Loss=4.3589
# Epoch 180: Loss=5.5408
# Epoch 190: Loss=4.0239
# Epoch 200: Loss=3.5861
# Epoch 210: Loss=5.5540
# Epoch 220: Loss=3.5586
# Epoch 230: Loss=3.3235
# Epoch 240: Loss=2.7230
# Epoch 250: Loss=2.5694
# Epoch 260: Loss=2.5806
# Epoch 270: Loss=1.9556
# Epoch 280: Loss=2.4947
# Epoch 290: Loss=1.6856
# Epoch 300: Loss=1.4690
# ✅ MSE: 28.3513 | R²: 0.2139
# ▶ Training: lr=0.001, batch=16, hidden=(64, 32, 16), epochs=100
# Epoch 10: Loss=37.8900
# Epoch 20: Loss=37.1904
# Epoch 30: Loss=35.9327
# Epoch 40: Loss=37.1788
# Epoch 50: Loss=19.7605
# Epoch 60: Loss=4.8579
# Epoch 70: Loss=4.8204
# Epoch 80: Loss=4.1987
# Epoch 90: Loss=3.9767
# Epoch 100: Loss=3.7409
# ✅ MSE: 10.6945 | R²: 0.7035
# ▶ Training: lr=0.001, batch=16, hidden=(64, 32, 16), epochs=200
# Epoch 10: Loss=37.0646
# Epoch 20: Loss=29.1946
# Epoch 30: Loss=7.6634
# Epoch 40: Loss=5.1619
# Epoch 50: Loss=10.0556
# Epoch 60: Loss=4.5530
# Epoch 70: Loss=16.1566
# Epoch 80: Loss=4.8074
# Epoch 90: Loss=4.8540
# Epoch 100: Loss=3.9852
# Epoch 110: Loss=3.7481
# Epoch 120: Loss=4.1183
# Epoch 130: Loss=3.2004
# Epoch 140: Loss=3.2443
# Epoch 150: Loss=3.1594
# Epoch 160: Loss=3.2483
# Epoch 170: Loss=2.0778
# Epoch 180: Loss=1.8250
# Epoch 190: Loss=2.1940
# Epoch 200: Loss=2.6795
# ✅ MSE: 11.4699 | R²: 0.6820
# ▶ Training: lr=0.001, batch=16, hidden=(64, 32, 16), epochs=300
# Epoch 10: Loss=38.0869
# Epoch 20: Loss=36.6236
# Epoch 30: Loss=37.0843
# Epoch 40: Loss=35.2826
# Epoch 50: Loss=27.8899
# Epoch 60: Loss=16.5576
# Epoch 70: Loss=5.9224
# Epoch 80: Loss=5.3902
# Epoch 90: Loss=4.5798
# Epoch 100: Loss=4.3264
# Epoch 110: Loss=5.7744
# Epoch 120: Loss=4.6491
# Epoch 130: Loss=4.6457
# Epoch 140: Loss=6.0002
# Epoch 150: Loss=4.1687
# Epoch 160: Loss=4.7074
# Epoch 170: Loss=4.5020
# Epoch 180: Loss=4.4505
# Epoch 190: Loss=4.6895
# Epoch 200: Loss=4.0303
# Epoch 210: Loss=4.7289
# Epoch 220: Loss=4.4917
# Epoch 230: Loss=4.2672
# Epoch 240: Loss=4.2581
# Epoch 250: Loss=5.0047
# Epoch 260: Loss=3.9038
# Epoch 270: Loss=3.9775
# Epoch 280: Loss=3.9524
# Epoch 290: Loss=4.2041
# Epoch 300: Loss=4.0295
# ✅ MSE: 6.9838 | R²: 0.8064
# ▶ Training: lr=0.001, batch=16, hidden=(64, 32, 16, 8), epochs=100
# Epoch 10: Loss=37.7186
# Epoch 20: Loss=37.3446
# Epoch 30: Loss=29.6362
# Epoch 40: Loss=5.9829
# Epoch 50: Loss=5.1855
# Epoch 60: Loss=6.6525
# Epoch 70: Loss=5.5076
# Epoch 80: Loss=4.5106
# Epoch 90: Loss=4.5900
# Epoch 100: Loss=4.5096
# ✅ MSE: 4.7177 | R²: 0.8692
# ▶ Training: lr=0.001, batch=16, hidden=(64, 32, 16, 8), epochs=200
# Epoch 10: Loss=39.2997
# Epoch 20: Loss=37.5563
# Epoch 30: Loss=37.2650
# Epoch 40: Loss=35.7634
# Epoch 50: Loss=17.2211
# Epoch 60: Loss=11.8889
# Epoch 70: Loss=11.0039
# Epoch 80: Loss=12.1756
# Epoch 90: Loss=10.5220
# Epoch 100: Loss=10.0723
# Epoch 110: Loss=9.5940
# Epoch 120: Loss=9.6870
# Epoch 130: Loss=9.0074
# Epoch 140: Loss=10.6870
# Epoch 150: Loss=8.1251
# Epoch 160: Loss=7.9244
# Epoch 170: Loss=19.6946
# Epoch 180: Loss=8.0800
# Epoch 190: Loss=7.4351
# Epoch 200: Loss=7.0066
# ✅ MSE: 34.9925 | R²: 0.0298
# ▶ Training: lr=0.001, batch=16, hidden=(64, 32, 16, 8), epochs=300
# Epoch 10: Loss=39.0585
# Epoch 20: Loss=36.3934
# Epoch 30: Loss=39.6465
# Epoch 40: Loss=38.8215
# Epoch 50: Loss=38.8091
# Epoch 60: Loss=33.0539
# Epoch 70: Loss=29.9650
# Epoch 80: Loss=25.0657
# Epoch 90: Loss=27.2142
# Epoch 100: Loss=24.1458
# Epoch 110: Loss=28.1724
# Epoch 120: Loss=28.7668
# Epoch 130: Loss=19.4172
# Epoch 140: Loss=25.4954
# Epoch 150: Loss=23.8917
# Epoch 160: Loss=17.9760
# Epoch 170: Loss=10.9802
# Epoch 180: Loss=25.3096
# Epoch 190: Loss=24.2147
# Epoch 200: Loss=23.6047
# Epoch 210: Loss=25.5601
# Epoch 220: Loss=11.4079
# Epoch 230: Loss=16.7644
# Epoch 240: Loss=4.8594
# Epoch 250: Loss=4.1478
# Epoch 260: Loss=3.5409
# Epoch 270: Loss=3.7212
# Epoch 280: Loss=33.7684
# Epoch 290: Loss=3.7710
# Epoch 300: Loss=3.0955
# ✅ MSE: 7.6861 | R²: 0.7869
# ▶ Training: lr=0.001, batch=16, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=100
# Epoch 10: Loss=43.9986
# Epoch 20: Loss=37.4857
# Epoch 30: Loss=43.1958
# Epoch 40: Loss=6.6634
# Epoch 50: Loss=4.8239
# Epoch 60: Loss=4.6960
# Epoch 70: Loss=4.6762
# Epoch 80: Loss=4.2315
# Epoch 90: Loss=4.2317
# Epoch 100: Loss=4.2195
# ✅ MSE: 5.6108 | R²: 0.8444
# ▶ Training: lr=0.001, batch=16, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=200
# Epoch 10: Loss=38.5816
# Epoch 20: Loss=37.8251
# Epoch 30: Loss=37.7447
# Epoch 40: Loss=37.6853
# Epoch 50: Loss=37.3889
# Epoch 60: Loss=35.9381
# Epoch 70: Loss=19.6154
# Epoch 80: Loss=5.7354
# Epoch 90: Loss=5.9603
# Epoch 100: Loss=4.6495
# Epoch 110: Loss=5.0424
# Epoch 120: Loss=4.5470
# Epoch 130: Loss=5.2556
# Epoch 140: Loss=4.4505
# Epoch 150: Loss=3.7644
# Epoch 160: Loss=4.4708
# Epoch 170: Loss=17.7614
# Epoch 180: Loss=3.9375
# Epoch 190: Loss=3.4926
# Epoch 200: Loss=3.9527
# ✅ MSE: 6.8520 | R²: 0.8100
# ▶ Training: lr=0.001, batch=16, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=300
# Epoch 10: Loss=37.7070
# Epoch 20: Loss=37.8155
# Epoch 30: Loss=30.3001
# Epoch 40: Loss=5.6174
# Epoch 50: Loss=4.8817
# Epoch 60: Loss=5.0791
# Epoch 70: Loss=6.9836
# Epoch 80: Loss=5.6512
# Epoch 90: Loss=5.6607
# Epoch 100: Loss=4.5818
# Epoch 110: Loss=8.0893
# Epoch 120: Loss=4.6191
# Epoch 130: Loss=4.9542
# Epoch 140: Loss=6.6576
# Epoch 150: Loss=3.8300
# Epoch 160: Loss=4.7786
# Epoch 170: Loss=7.8388
# Epoch 180: Loss=3.8081
# Epoch 190: Loss=4.5120
# Epoch 200: Loss=3.1557
# Epoch 210: Loss=4.3907
# Epoch 220: Loss=4.1853
# Epoch 230: Loss=3.0299
# Epoch 240: Loss=2.7199
# Epoch 250: Loss=2.1006
# Epoch 260: Loss=3.1580
# Epoch 270: Loss=2.3576
# Epoch 280: Loss=5.1132
# Epoch 290: Loss=1.7681
# Epoch 300: Loss=1.6731
# ✅ MSE: 26.8827 | R²: 0.2547
# ▶ Training: lr=0.001, batch=32, hidden=(128, 64, 32), epochs=100
# Epoch 10: Loss=38.4763
# Epoch 20: Loss=34.3383
# Epoch 30: Loss=26.1173
# Epoch 40: Loss=22.0483
# Epoch 50: Loss=16.0929
# Epoch 60: Loss=8.8196
# Epoch 70: Loss=6.7028
# Epoch 80: Loss=5.7211
# Epoch 90: Loss=5.4563
# Epoch 100: Loss=6.3390
# ✅ MSE: 10.3189 | R²: 0.7139
# ▶ Training: lr=0.001, batch=32, hidden=(128, 64, 32), epochs=200
# Epoch 10: Loss=40.0762
# Epoch 20: Loss=38.3549
# Epoch 30: Loss=33.9076
# Epoch 40: Loss=31.1431
# Epoch 50: Loss=22.9433
# Epoch 60: Loss=14.0833
# Epoch 70: Loss=8.1248
# Epoch 80: Loss=5.6328
# Epoch 90: Loss=6.0725
# Epoch 100: Loss=5.4170
# Epoch 110: Loss=4.1241
# Epoch 120: Loss=5.0900
# Epoch 130: Loss=4.6628
# Epoch 140: Loss=5.4959
# Epoch 150: Loss=5.0472
# Epoch 160: Loss=3.9981
# Epoch 170: Loss=3.5039
# Epoch 180: Loss=4.5832
# Epoch 190: Loss=5.1637
# Epoch 200: Loss=3.6462
# ✅ MSE: 12.0730 | R²: 0.6653
# ▶ Training: lr=0.001, batch=32, hidden=(128, 64, 32), epochs=300
# Epoch 10: Loss=38.1282
# Epoch 20: Loss=32.1068
# Epoch 30: Loss=21.5859
# Epoch 40: Loss=12.6563
# Epoch 50: Loss=7.4395
# Epoch 60: Loss=5.8000
# Epoch 70: Loss=6.3197
# Epoch 80: Loss=6.1917
# Epoch 90: Loss=4.2767
# Epoch 100: Loss=4.3296
# Epoch 110: Loss=5.1306
# Epoch 120: Loss=5.8356
# Epoch 130: Loss=4.9599
# Epoch 140: Loss=4.5101
# Epoch 150: Loss=4.8859
# Epoch 160: Loss=4.4170
# Epoch 170: Loss=6.0298
# Epoch 180: Loss=3.3459
# Epoch 190: Loss=2.7218
# Epoch 200: Loss=3.2740
# Epoch 210: Loss=2.2646
# Epoch 220: Loss=2.2985
# Epoch 230: Loss=5.2425
# Epoch 240: Loss=2.2484
# Epoch 250: Loss=1.7839
# Epoch 260: Loss=1.8440
# Epoch 270: Loss=1.8825
# Epoch 280: Loss=1.7986
# Epoch 290: Loss=2.1912
# Epoch 300: Loss=2.2297
# ✅ MSE: 11.3518 | R²: 0.6853
# ▶ Training: lr=0.001, batch=32, hidden=(64, 32, 16), epochs=100
# Epoch 10: Loss=37.1828
# Epoch 20: Loss=33.5506
# Epoch 30: Loss=26.9991
# Epoch 40: Loss=19.0866
# Epoch 50: Loss=11.4883
# Epoch 60: Loss=5.3180
# Epoch 70: Loss=5.7635
# Epoch 80: Loss=5.2028
# Epoch 90: Loss=4.8672
# Epoch 100: Loss=4.5851
# ✅ MSE: 4.5607 | R²: 0.8736
# ▶ Training: lr=0.001, batch=32, hidden=(64, 32, 16), epochs=200
# Epoch 10: Loss=39.0020
# Epoch 20: Loss=39.4899
# Epoch 30: Loss=34.8494
# Epoch 40: Loss=32.3584
# Epoch 50: Loss=22.4999
# Epoch 60: Loss=9.1980
# Epoch 70: Loss=5.2049
# Epoch 80: Loss=4.4300
# Epoch 90: Loss=5.2655
# Epoch 100: Loss=4.4304
# Epoch 110: Loss=4.8025
# Epoch 120: Loss=4.7070
# Epoch 130: Loss=5.9277
# Epoch 140: Loss=4.5127
# Epoch 150: Loss=4.3027
# Epoch 160: Loss=4.3797
# Epoch 170: Loss=4.4901
# Epoch 180: Loss=4.0341
# Epoch 190: Loss=4.0203
# Epoch 200: Loss=4.7184
# ✅ MSE: 5.7526 | R²: 0.8405
# ▶ Training: lr=0.001, batch=32, hidden=(64, 32, 16), epochs=300
# Epoch 10: Loss=37.9911
# Epoch 20: Loss=35.5338
# Epoch 30: Loss=34.0054
# Epoch 40: Loss=22.5277
# Epoch 50: Loss=9.2089
# Epoch 60: Loss=5.9966
# Epoch 70: Loss=4.8902
# Epoch 80: Loss=4.9087
# Epoch 90: Loss=4.8887
# Epoch 100: Loss=5.2429
# Epoch 110: Loss=4.8962
# Epoch 120: Loss=5.0665
# Epoch 130: Loss=4.3890
# Epoch 140: Loss=5.4405
# Epoch 150: Loss=5.8637
# Epoch 160: Loss=5.4826
# Epoch 170: Loss=4.1747
# Epoch 180: Loss=4.3388
# Epoch 190: Loss=5.2042
# Epoch 200: Loss=4.7747
# Epoch 210: Loss=4.5493
# Epoch 220: Loss=4.2507
# Epoch 230: Loss=4.0575
# Epoch 240: Loss=4.2488
# Epoch 250: Loss=4.1277
# Epoch 260: Loss=4.1352
# Epoch 270: Loss=4.0077
# Epoch 280: Loss=3.7952
# Epoch 290: Loss=3.9083
# Epoch 300: Loss=4.0648
# ✅ MSE: 5.5710 | R²: 0.8455
# ▶ Training: lr=0.001, batch=32, hidden=(64, 32, 16, 8), epochs=100
# Epoch 10: Loss=38.1026
# Epoch 20: Loss=38.8701
# Epoch 30: Loss=36.3771
# Epoch 40: Loss=32.4720
# Epoch 50: Loss=16.7964
# Epoch 60: Loss=7.4477
# Epoch 70: Loss=6.3013
# Epoch 80: Loss=4.8161
# Epoch 90: Loss=4.6935
# Epoch 100: Loss=4.8301
# ✅ MSE: 4.3995 | R²: 0.8780
# ▶ Training: lr=0.001, batch=32, hidden=(64, 32, 16, 8), epochs=200
# Epoch 10: Loss=42.5591
# Epoch 20: Loss=37.8784
# Epoch 30: Loss=40.1958
# Epoch 40: Loss=41.0149
# Epoch 50: Loss=36.3656
# Epoch 60: Loss=34.7359
# Epoch 70: Loss=27.6996
# Epoch 80: Loss=19.8701
# Epoch 90: Loss=12.2223
# Epoch 100: Loss=12.2319
# Epoch 110: Loss=10.7553
# Epoch 120: Loss=11.0334
# Epoch 130: Loss=11.2836
# Epoch 140: Loss=9.8653
# Epoch 150: Loss=9.1851
# Epoch 160: Loss=8.1481
# Epoch 170: Loss=7.8355
# Epoch 180: Loss=7.7176
# Epoch 190: Loss=7.3998
# Epoch 200: Loss=7.2806
# ✅ MSE: 47.5089 | R²: -0.3172
# ▶ Training: lr=0.001, batch=32, hidden=(64, 32, 16, 8), epochs=300
# Epoch 10: Loss=39.8338
# Epoch 20: Loss=38.8437
# Epoch 30: Loss=36.7937
# Epoch 40: Loss=33.9656
# Epoch 50: Loss=24.5184
# Epoch 60: Loss=5.9604
# Epoch 70: Loss=4.5001
# Epoch 80: Loss=4.7701
# Epoch 90: Loss=4.8388
# Epoch 100: Loss=4.5145
# Epoch 110: Loss=5.3786
# Epoch 120: Loss=4.6379
# Epoch 130: Loss=4.9004
# Epoch 140: Loss=3.9896
# Epoch 150: Loss=4.3259
# Epoch 160: Loss=4.1725
# Epoch 170: Loss=4.2115
# Epoch 180: Loss=5.3521
# Epoch 190: Loss=5.5626
# Epoch 200: Loss=3.7688
# Epoch 210: Loss=3.9588
# Epoch 220: Loss=3.8607
# Epoch 230: Loss=4.2089
# Epoch 240: Loss=3.9273
# Epoch 250: Loss=3.5145
# Epoch 260: Loss=3.8873
# Epoch 270: Loss=4.1291
# Epoch 280: Loss=4.0848
# Epoch 290: Loss=3.5447
# Epoch 300: Loss=3.7264
# ✅ MSE: 4.8840 | R²: 0.8646
# ▶ Training: lr=0.001, batch=32, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=100
# Epoch 10: Loss=39.7538
# Epoch 20: Loss=39.1135
# Epoch 30: Loss=40.6825
# Epoch 40: Loss=37.3950
# Epoch 50: Loss=7.6238
# Epoch 60: Loss=5.8867
# Epoch 70: Loss=5.5806
# Epoch 80: Loss=4.8978
# Epoch 90: Loss=4.2186
# Epoch 100: Loss=4.6694
# ✅ MSE: 11.2284 | R²: 0.6887
# ▶ Training: lr=0.001, batch=32, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=200
# Epoch 10: Loss=38.9066
# Epoch 20: Loss=39.1154
# Epoch 30: Loss=39.3329
# Epoch 40: Loss=38.0494
# Epoch 50: Loss=32.7248
# Epoch 60: Loss=5.4703
# Epoch 70: Loss=5.7616
# Epoch 80: Loss=5.0904
# Epoch 90: Loss=4.7603
# Epoch 100: Loss=4.8950
# Epoch 110: Loss=4.5259
# Epoch 120: Loss=4.6422
# Epoch 130: Loss=5.0923
# Epoch 140: Loss=5.3207
# Epoch 150: Loss=4.2469
# Epoch 160: Loss=4.9997
# Epoch 170: Loss=4.5449
# Epoch 180: Loss=4.7234
# Epoch 190: Loss=4.4532
# Epoch 200: Loss=4.3406
# ✅ MSE: 4.0258 | R²: 0.8884
# ▶ Training: lr=0.001, batch=32, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=300
# Epoch 10: Loss=38.4390
# Epoch 20: Loss=38.4773
# Epoch 30: Loss=37.2947
# Epoch 40: Loss=24.9650
# Epoch 50: Loss=10.1551
# Epoch 60: Loss=8.4536
# Epoch 70: Loss=6.1785
# Epoch 80: Loss=6.5099
# Epoch 90: Loss=4.9005
# Epoch 100: Loss=5.4075
# Epoch 110: Loss=4.9751
# Epoch 120: Loss=4.5746
# Epoch 130: Loss=4.3228
# Epoch 140: Loss=5.5147
# Epoch 150: Loss=4.0492
# Epoch 160: Loss=3.9347
# Epoch 170: Loss=4.1004
# Epoch 180: Loss=3.8147
# Epoch 190: Loss=4.2925
# Epoch 200: Loss=3.7529
# Epoch 210: Loss=3.0323
# Epoch 220: Loss=9.0228
# Epoch 230: Loss=1.9994
# Epoch 240: Loss=2.5175
# Epoch 250: Loss=2.4096
# Epoch 260: Loss=3.9597
# Epoch 270: Loss=2.3166
# Epoch 280: Loss=1.6471
# Epoch 290: Loss=2.4610
# Epoch 300: Loss=1.3184
# ✅ MSE: 37.1876 | R²: -0.0311
# ▶ Training: lr=0.0005, batch=16, hidden=(128, 64, 32), epochs=100
# Epoch 10: Loss=40.7022
# Epoch 20: Loss=36.3691
# Epoch 30: Loss=23.6470
# Epoch 40: Loss=12.5543
# Epoch 50: Loss=6.5623
# Epoch 60: Loss=5.1532
# Epoch 70: Loss=5.3338
# Epoch 80: Loss=5.8837
# Epoch 90: Loss=5.7820
# Epoch 100: Loss=5.4031
# ✅ MSE: 4.9773 | R²: 0.8620
# ▶ Training: lr=0.0005, batch=16, hidden=(128, 64, 32), epochs=200
# Epoch 10: Loss=43.0390
# Epoch 20: Loss=40.7127
# Epoch 30: Loss=32.4675
# Epoch 40: Loss=30.5292
# Epoch 50: Loss=22.1447
# Epoch 60: Loss=12.8694
# Epoch 70: Loss=8.3772
# Epoch 80: Loss=6.5244
# Epoch 90: Loss=5.1283
# Epoch 100: Loss=4.6767
# Epoch 110: Loss=4.7199
# Epoch 120: Loss=4.9179
# Epoch 130: Loss=4.2172
# Epoch 140: Loss=4.4031
# Epoch 150: Loss=4.7555
# Epoch 160: Loss=4.4683
# Epoch 170: Loss=4.2083
# Epoch 180: Loss=4.8928
# Epoch 190: Loss=4.0530
# Epoch 200: Loss=4.5904
# ✅ MSE: 9.6230 | R²: 0.7332
# ▶ Training: lr=0.0005, batch=16, hidden=(128, 64, 32), epochs=300
# Epoch 10: Loss=38.4031
# Epoch 20: Loss=34.3639
# Epoch 30: Loss=33.4174
# Epoch 40: Loss=31.3941
# Epoch 50: Loss=33.6383
# Epoch 60: Loss=18.5047
# Epoch 70: Loss=11.2568
# Epoch 80: Loss=6.0464
# Epoch 90: Loss=6.0358
# Epoch 100: Loss=5.3060
# Epoch 110: Loss=6.1612
# Epoch 120: Loss=5.0279
# Epoch 130: Loss=4.6635
# Epoch 140: Loss=4.7403
# Epoch 150: Loss=4.7842
# Epoch 160: Loss=4.8150
# Epoch 170: Loss=4.5415
# Epoch 180: Loss=4.4870
# Epoch 190: Loss=5.5349
# Epoch 200: Loss=3.9808
# Epoch 210: Loss=3.9351
# Epoch 220: Loss=3.5765
# Epoch 230: Loss=4.2714
# Epoch 240: Loss=4.4923
# Epoch 250: Loss=4.4586
# Epoch 260: Loss=4.0307
# Epoch 270: Loss=4.1531
# Epoch 280: Loss=3.9634
# Epoch 290: Loss=3.4726
# Epoch 300: Loss=3.8221
# ✅ MSE: 36.5486 | R²: -0.0133
# ▶ Training: lr=0.0005, batch=16, hidden=(64, 32, 16), epochs=100
# Epoch 10: Loss=37.8623
# Epoch 20: Loss=38.2552
# Epoch 30: Loss=37.4902
# Epoch 40: Loss=32.0291
# Epoch 50: Loss=23.7016
# Epoch 60: Loss=16.4290
# Epoch 70: Loss=13.6451
# Epoch 80: Loss=5.3970
# Epoch 90: Loss=20.7637
# Epoch 100: Loss=5.1172
# ✅ MSE: 7.9208 | R²: 0.7804
# ▶ Training: lr=0.0005, batch=16, hidden=(64, 32, 16), epochs=200
# Epoch 10: Loss=36.6839
# Epoch 20: Loss=39.1422
# Epoch 30: Loss=33.1989
# Epoch 40: Loss=43.7212
# Epoch 50: Loss=22.7403
# Epoch 60: Loss=17.9001
# Epoch 70: Loss=10.8349
# Epoch 80: Loss=6.7482
# Epoch 90: Loss=5.7008
# Epoch 100: Loss=5.4756
# Epoch 110: Loss=4.9724
# Epoch 120: Loss=4.3079
# Epoch 130: Loss=4.3455
# Epoch 140: Loss=4.3305
# Epoch 150: Loss=4.5278
# Epoch 160: Loss=4.0934
# Epoch 170: Loss=3.8782
# Epoch 180: Loss=4.3195
# Epoch 190: Loss=4.2125
# Epoch 200: Loss=4.1759
# ✅ MSE: 6.5138 | R²: 0.8194
# ▶ Training: lr=0.0005, batch=16, hidden=(64, 32, 16), epochs=300
# Epoch 10: Loss=47.1058
# Epoch 20: Loss=36.9011
# Epoch 30: Loss=34.1798
# Epoch 40: Loss=29.9147
# Epoch 50: Loss=20.6565
# Epoch 60: Loss=7.0749
# Epoch 70: Loss=5.9737
# Epoch 80: Loss=5.9394
# Epoch 90: Loss=32.2026
# Epoch 100: Loss=5.5181
# Epoch 110: Loss=4.5532
# Epoch 120: Loss=4.8262
# Epoch 130: Loss=5.3150
# Epoch 140: Loss=4.8535
# Epoch 150: Loss=4.4974
# Epoch 160: Loss=4.5057
# Epoch 170: Loss=5.8716
# Epoch 180: Loss=4.3278
# Epoch 190: Loss=5.4724
# Epoch 200: Loss=4.7664
# Epoch 210: Loss=4.4490
# Epoch 220: Loss=4.2947
# Epoch 230: Loss=4.3409
# Epoch 240: Loss=5.2689
# Epoch 250: Loss=4.2668
# Epoch 260: Loss=4.0139
# Epoch 270: Loss=3.7874
# Epoch 280: Loss=4.7279
# Epoch 290: Loss=3.8499
# Epoch 300: Loss=3.8655
# ✅ MSE: 4.5014 | R²: 0.8752
# ▶ Training: lr=0.0005, batch=16, hidden=(64, 32, 16, 8), epochs=100
# Epoch 10: Loss=43.2754
# Epoch 20: Loss=39.8722
# Epoch 30: Loss=38.6774
# Epoch 40: Loss=35.5659
# Epoch 50: Loss=25.1829
# Epoch 60: Loss=11.2577
# Epoch 70: Loss=5.4310
# Epoch 80: Loss=5.7552
# Epoch 90: Loss=4.9583
# Epoch 100: Loss=5.1130
# ✅ MSE: 5.4067 | R²: 0.8501
# ▶ Training: lr=0.0005, batch=16, hidden=(64, 32, 16, 8), epochs=200
# Epoch 10: Loss=39.9273
# Epoch 20: Loss=38.5538
# Epoch 30: Loss=37.1895
# Epoch 40: Loss=35.4787
# Epoch 50: Loss=28.5368
# Epoch 60: Loss=14.1129
# Epoch 70: Loss=13.1864
# Epoch 80: Loss=12.7987
# Epoch 90: Loss=11.4085
# Epoch 100: Loss=10.9987
# Epoch 110: Loss=10.6730
# Epoch 120: Loss=10.9826
# Epoch 130: Loss=10.4438
# Epoch 140: Loss=10.2755
# Epoch 150: Loss=10.0592
# Epoch 160: Loss=10.2301
# Epoch 170: Loss=9.8160
# Epoch 180: Loss=9.2427
# Epoch 190: Loss=9.4496
# Epoch 200: Loss=8.7203
# ✅ MSE: 11.8339 | R²: 0.6719
# ▶ Training: lr=0.0005, batch=16, hidden=(64, 32, 16, 8), epochs=300
# Epoch 10: Loss=41.3540
# Epoch 20: Loss=35.9846
# Epoch 30: Loss=34.5786
# Epoch 40: Loss=26.2451
# Epoch 50: Loss=10.5118
# Epoch 60: Loss=6.3392
# Epoch 70: Loss=5.4237
# Epoch 80: Loss=5.4529
# Epoch 90: Loss=4.6646
# Epoch 100: Loss=5.6392
# Epoch 110: Loss=5.0825
# Epoch 120: Loss=4.9545
# Epoch 130: Loss=4.4759
# Epoch 140: Loss=4.4462
# Epoch 150: Loss=4.7475
# Epoch 160: Loss=4.8255
# Epoch 170: Loss=7.5789
# Epoch 180: Loss=5.6242
# Epoch 190: Loss=4.5521
# Epoch 200: Loss=3.7990
# Epoch 210: Loss=3.7762
# Epoch 220: Loss=3.4019
# Epoch 230: Loss=2.5640
# Epoch 240: Loss=2.1244
# Epoch 250: Loss=2.8797
# Epoch 260: Loss=2.1573
# Epoch 270: Loss=2.0261
# Epoch 280: Loss=2.0443
# Epoch 290: Loss=2.4083
# Epoch 300: Loss=2.1648
# ✅ MSE: 17.6078 | R²: 0.5118
# ▶ Training: lr=0.0005, batch=16, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=100
# Epoch 10: Loss=38.6544
# Epoch 20: Loss=37.3231
# Epoch 30: Loss=37.6379
# Epoch 40: Loss=36.0971
# Epoch 50: Loss=29.8618
# Epoch 60: Loss=25.8334
# Epoch 70: Loss=12.5085
# Epoch 80: Loss=6.7306
# Epoch 90: Loss=5.4005
# Epoch 100: Loss=4.6402
# ✅ MSE: 6.0214 | R²: 0.8331
# ▶ Training: lr=0.0005, batch=16, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=200
# Epoch 10: Loss=38.1135
# Epoch 20: Loss=37.6977
# Epoch 30: Loss=37.3344
# Epoch 40: Loss=37.8756
# Epoch 50: Loss=7.2808
# Epoch 60: Loss=5.3419
# Epoch 70: Loss=4.8694
# Epoch 80: Loss=4.9432
# Epoch 90: Loss=5.0725
# Epoch 100: Loss=4.5698
# Epoch 110: Loss=4.6213
# Epoch 120: Loss=4.5386
# Epoch 130: Loss=4.8462
# Epoch 140: Loss=4.3557
# Epoch 150: Loss=4.5500
# Epoch 160: Loss=4.2172
# Epoch 170: Loss=4.6896
# Epoch 180: Loss=4.3152
# Epoch 190: Loss=6.3962
# Epoch 200: Loss=4.4045
# ✅ MSE: 4.8976 | R²: 0.8642
# ▶ Training: lr=0.0005, batch=16, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=300
# Epoch 10: Loss=38.0333
# Epoch 20: Loss=37.7394
# Epoch 30: Loss=37.8653
# Epoch 40: Loss=38.4461
# Epoch 50: Loss=37.1172
# Epoch 60: Loss=35.7726
# Epoch 70: Loss=7.5654
# Epoch 80: Loss=4.8005
# Epoch 90: Loss=4.5582
# Epoch 100: Loss=6.8427
# Epoch 110: Loss=4.4265
# Epoch 120: Loss=4.2555
# Epoch 130: Loss=4.4503
# Epoch 140: Loss=4.3176
# Epoch 150: Loss=3.9112
# Epoch 160: Loss=4.0470
# Epoch 170: Loss=4.5423
# Epoch 180: Loss=4.7765
# Epoch 190: Loss=3.9074
# Epoch 200: Loss=4.0395
# Epoch 210: Loss=4.0385
# Epoch 220: Loss=3.7766
# Epoch 230: Loss=4.1607
# Epoch 240: Loss=3.7751
# Epoch 250: Loss=3.6754
# Epoch 260: Loss=3.9892
# Epoch 270: Loss=3.5581
# Epoch 280: Loss=3.9225
# Epoch 290: Loss=3.6205
# Epoch 300: Loss=3.2355
# ✅ MSE: 9.6475 | R²: 0.7325
# ▶ Training: lr=0.0005, batch=32, hidden=(128, 64, 32), epochs=100
# Epoch 10: Loss=37.9317
# Epoch 20: Loss=34.4412
# Epoch 30: Loss=31.3878
# Epoch 40: Loss=28.3603
# Epoch 50: Loss=19.8557
# Epoch 60: Loss=15.1171
# Epoch 70: Loss=11.5694
# Epoch 80: Loss=7.8054
# Epoch 90: Loss=4.9497
# Epoch 100: Loss=4.6712
# ✅ MSE: 4.1655 | R²: 0.8845
# ▶ Training: lr=0.0005, batch=32, hidden=(128, 64, 32), epochs=200
# Epoch 10: Loss=40.9493
# Epoch 20: Loss=38.2937
# Epoch 30: Loss=33.9954
# Epoch 40: Loss=33.5290
# Epoch 50: Loss=29.0561
# Epoch 60: Loss=23.6526
# Epoch 70: Loss=19.5009
# Epoch 80: Loss=15.6571
# Epoch 90: Loss=12.6842
# Epoch 100: Loss=7.0644
# Epoch 110: Loss=6.3437
# Epoch 120: Loss=5.8055
# Epoch 130: Loss=4.9137
# Epoch 140: Loss=5.0094
# Epoch 150: Loss=5.7771
# Epoch 160: Loss=4.7329
# Epoch 170: Loss=5.0155
# Epoch 180: Loss=4.4337
# Epoch 190: Loss=4.9968
# Epoch 200: Loss=4.3897
# ✅ MSE: 6.0005 | R²: 0.8336
# ▶ Training: lr=0.0005, batch=32, hidden=(128, 64, 32), epochs=300
# Epoch 10: Loss=42.7626
# Epoch 20: Loss=38.6635
# Epoch 30: Loss=34.4033
# Epoch 40: Loss=28.9593
# Epoch 50: Loss=27.3871
# Epoch 60: Loss=17.3807
# Epoch 70: Loss=18.7780
# Epoch 80: Loss=8.7248
# Epoch 90: Loss=7.2578
# Epoch 100: Loss=5.4868
# Epoch 110: Loss=6.0227
# Epoch 120: Loss=4.8556
# Epoch 130: Loss=7.1894
# Epoch 140: Loss=4.9085
# Epoch 150: Loss=4.9801
# Epoch 160: Loss=4.3299
# Epoch 170: Loss=6.5961
# Epoch 180: Loss=5.1008
# Epoch 190: Loss=4.5469
# Epoch 200: Loss=7.2897
# Epoch 210: Loss=4.8018
# Epoch 220: Loss=4.1703
# Epoch 230: Loss=7.4231
# Epoch 240: Loss=5.2873
# Epoch 250: Loss=3.9909
# Epoch 260: Loss=5.2518
# Epoch 270: Loss=5.7787
# Epoch 280: Loss=4.2819
# Epoch 290: Loss=4.0973
# Epoch 300: Loss=4.1365
# ✅ MSE: 5.5866 | R²: 0.8451
# ▶ Training: lr=0.0005, batch=32, hidden=(64, 32, 16), epochs=100
# Epoch 10: Loss=37.7717
# Epoch 20: Loss=36.9314
# Epoch 30: Loss=36.6217
# Epoch 40: Loss=34.0460
# Epoch 50: Loss=31.7547
# Epoch 60: Loss=29.6625
# Epoch 70: Loss=31.0757
# Epoch 80: Loss=18.7814
# Epoch 90: Loss=13.5030
# Epoch 100: Loss=9.3029
# ✅ MSE: 6.9913 | R²: 0.8062
# ▶ Training: lr=0.0005, batch=32, hidden=(64, 32, 16), epochs=200
# Epoch 10: Loss=38.5880
# Epoch 20: Loss=35.5831
# Epoch 30: Loss=36.2229
# Epoch 40: Loss=33.0950
# Epoch 50: Loss=31.1974
# Epoch 60: Loss=24.7697
# Epoch 70: Loss=16.8119
# Epoch 80: Loss=10.0117
# Epoch 90: Loss=6.8929
# Epoch 100: Loss=7.0211
# Epoch 110: Loss=5.7676
# Epoch 120: Loss=5.4807
# Epoch 130: Loss=5.9894
# Epoch 140: Loss=4.9025
# Epoch 150: Loss=6.5096
# Epoch 160: Loss=4.4594
# Epoch 170: Loss=4.6162
# Epoch 180: Loss=4.6790
# Epoch 190: Loss=5.4213
# Epoch 200: Loss=4.4556
# ✅ MSE: 7.9131 | R²: 0.7806
# ▶ Training: lr=0.0005, batch=32, hidden=(64, 32, 16), epochs=300
# Epoch 10: Loss=38.9518
# Epoch 20: Loss=33.2529
# Epoch 30: Loss=30.8086
# Epoch 40: Loss=31.4984
# Epoch 50: Loss=21.0971
# Epoch 60: Loss=16.0571
# Epoch 70: Loss=12.3645
# Epoch 80: Loss=11.0780
# Epoch 90: Loss=7.3376
# Epoch 100: Loss=5.8363
# Epoch 110: Loss=5.5898
# Epoch 120: Loss=5.1957
# Epoch 130: Loss=4.8998
# Epoch 140: Loss=7.2279
# Epoch 150: Loss=4.7582
# Epoch 160: Loss=6.3255
# Epoch 170: Loss=6.0054
# Epoch 180: Loss=5.1342
# Epoch 190: Loss=5.0795
# Epoch 200: Loss=4.4931
# Epoch 210: Loss=4.2323
# Epoch 220: Loss=5.6140
# Epoch 230: Loss=4.2573
# Epoch 240: Loss=3.8577
# Epoch 250: Loss=5.0680
# Epoch 260: Loss=4.5698
# Epoch 270: Loss=3.9095
# Epoch 280: Loss=4.8570
# Epoch 290: Loss=3.7794
# Epoch 300: Loss=4.2279
# ✅ MSE: 7.9979 | R²: 0.7783
# ▶ Training: lr=0.0005, batch=32, hidden=(64, 32, 16, 8), epochs=100
# Epoch 10: Loss=47.7795
# Epoch 20: Loss=44.0605
# Epoch 30: Loss=40.4502
# Epoch 40: Loss=40.7963
# Epoch 50: Loss=40.0783
# Epoch 60: Loss=40.3705
# Epoch 70: Loss=40.7378
# Epoch 80: Loss=39.7119
# Epoch 90: Loss=42.3398
# Epoch 100: Loss=40.0317
# ✅ MSE: 37.7422 | R²: -0.0464
# ▶ Training: lr=0.0005, batch=32, hidden=(64, 32, 16, 8), epochs=200
# Epoch 10: Loss=38.3111
# Epoch 20: Loss=36.7656
# Epoch 30: Loss=36.9971
# Epoch 40: Loss=35.2045
# Epoch 50: Loss=31.6817
# Epoch 60: Loss=19.6182
# Epoch 70: Loss=13.1585
# Epoch 80: Loss=6.0379
# Epoch 90: Loss=5.8611
# Epoch 100: Loss=5.2815
# Epoch 110: Loss=4.6155
# Epoch 120: Loss=4.6572
# Epoch 130: Loss=4.8884
# Epoch 140: Loss=4.8933
# Epoch 150: Loss=5.1601
# Epoch 160: Loss=4.8099
# Epoch 170: Loss=4.6254
# Epoch 180: Loss=4.3278
# Epoch 190: Loss=4.4899
# Epoch 200: Loss=5.4781
# ✅ MSE: 4.2633 | R²: 0.8818
# ▶ Training: lr=0.0005, batch=32, hidden=(64, 32, 16, 8), epochs=300
# Epoch 10: Loss=38.4239
# Epoch 20: Loss=37.7691
# Epoch 30: Loss=37.3924
# Epoch 40: Loss=37.4331
# Epoch 50: Loss=34.3160
# Epoch 60: Loss=31.0067
# Epoch 70: Loss=27.7634
# Epoch 80: Loss=11.5444
# Epoch 90: Loss=6.3512
# Epoch 100: Loss=5.0857
# Epoch 110: Loss=5.0569
# Epoch 120: Loss=5.9721
# Epoch 130: Loss=6.2275
# Epoch 140: Loss=4.7754
# Epoch 150: Loss=4.5837
# Epoch 160: Loss=4.3353
# Epoch 170: Loss=4.2977
# Epoch 180: Loss=4.3098
# Epoch 190: Loss=4.2481
# Epoch 200: Loss=4.2154
# Epoch 210: Loss=4.3198
# Epoch 220: Loss=4.7718
# Epoch 230: Loss=4.0924
# Epoch 240: Loss=4.3851
# Epoch 250: Loss=4.3481
# Epoch 260: Loss=4.5987
# Epoch 270: Loss=5.0082
# Epoch 280: Loss=4.6764
# Epoch 290: Loss=4.4901
# Epoch 300: Loss=4.6858
# ✅ MSE: 3.7695 | R²: 0.8955
# ▶ Training: lr=0.0005, batch=32, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=100
# Epoch 10: Loss=38.5207
# Epoch 20: Loss=38.9741
# Epoch 30: Loss=38.1540
# Epoch 40: Loss=34.1493
# Epoch 50: Loss=24.4518
# Epoch 60: Loss=8.7527
# Epoch 70: Loss=5.5823
# Epoch 80: Loss=5.9288
# Epoch 90: Loss=5.5085
# Epoch 100: Loss=5.3414
# ✅ MSE: 4.9931 | R²: 0.8616
# ▶ Training: lr=0.0005, batch=32, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=200
# Epoch 10: Loss=41.1537
# Epoch 20: Loss=38.1190
# Epoch 30: Loss=41.6670
# Epoch 40: Loss=38.4802
# Epoch 50: Loss=37.8033
# Epoch 60: Loss=38.7600
# Epoch 70: Loss=38.1422
# Epoch 80: Loss=38.3427
# Epoch 90: Loss=38.2142
# Epoch 100: Loss=33.2125
# Epoch 110: Loss=22.5946
# Epoch 120: Loss=20.1676
# Epoch 130: Loss=21.8693
# Epoch 140: Loss=19.2952
# Epoch 150: Loss=19.2275
# Epoch 160: Loss=18.8198
# Epoch 170: Loss=18.5062
# Epoch 180: Loss=18.4787
# Epoch 190: Loss=18.3339
# Epoch 200: Loss=18.1014
# ✅ MSE: 19.5713 | R²: 0.4574
# ▶ Training: lr=0.0005, batch=32, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=300
# Epoch 10: Loss=39.9147
# Epoch 20: Loss=38.4004
# Epoch 30: Loss=38.5226
# Epoch 40: Loss=41.0468
# Epoch 50: Loss=37.6606
# Epoch 60: Loss=38.4763
# Epoch 70: Loss=40.1679
# Epoch 80: Loss=37.7884
# Epoch 90: Loss=37.8768
# Epoch 100: Loss=37.4630
# Epoch 110: Loss=37.9915
# Epoch 120: Loss=30.5415
# Epoch 130: Loss=8.9260
# Epoch 140: Loss=7.7202
# Epoch 150: Loss=5.4444
# Epoch 160: Loss=4.8097
# Epoch 170: Loss=4.8588
# Epoch 180: Loss=5.5690
# Epoch 190: Loss=4.3831
# Epoch 200: Loss=5.9923
# Epoch 210: Loss=5.1669
# Epoch 220: Loss=4.1945
# Epoch 230: Loss=4.6199
# Epoch 240: Loss=4.3020
# Epoch 250: Loss=4.5629
# Epoch 260: Loss=4.6523
# Epoch 270: Loss=4.9296
# Epoch 280: Loss=4.3490
# Epoch 290: Loss=4.1460
# Epoch 300: Loss=4.4176
# ✅ MSE: 9.3018 | R²: 0.7421
# ▶ Training: lr=1e-05, batch=16, hidden=(128, 64, 32), epochs=100
# Epoch 10: Loss=45.9107
# Epoch 20: Loss=43.5028
# Epoch 30: Loss=37.3741
# Epoch 40: Loss=37.0975
# Epoch 50: Loss=36.7751
# Epoch 60: Loss=36.6811
# Epoch 70: Loss=36.2788
# Epoch 80: Loss=38.3327
# Epoch 90: Loss=36.7269
# Epoch 100: Loss=36.0803
# ✅ MSE: 34.1617 | R²: 0.0528
# ▶ Training: lr=1e-05, batch=16, hidden=(128, 64, 32), epochs=200
# Epoch 10: Loss=43.3666
# Epoch 20: Loss=39.0894
# Epoch 30: Loss=39.2302
# Epoch 40: Loss=38.6153
# Epoch 50: Loss=40.1868
# Epoch 60: Loss=38.3130
# Epoch 70: Loss=39.0275
# Epoch 80: Loss=37.8505
# Epoch 90: Loss=37.4102
# Epoch 100: Loss=38.6797
# Epoch 110: Loss=37.7233
# Epoch 120: Loss=37.2218
# Epoch 130: Loss=37.6183
# Epoch 140: Loss=46.2551
# Epoch 150: Loss=36.7202
# Epoch 160: Loss=37.4179
# Epoch 170: Loss=37.5289
# Epoch 180: Loss=36.5110
# Epoch 190: Loss=58.5204
# Epoch 200: Loss=37.3237
# ✅ MSE: 33.8935 | R²: 0.0603
# ▶ Training: lr=1e-05, batch=16, hidden=(128, 64, 32), epochs=300
# Epoch 10: Loss=82.1679
# Epoch 20: Loss=41.6987
# Epoch 30: Loss=51.7243
# Epoch 40: Loss=37.7553
# Epoch 50: Loss=37.7306
# Epoch 60: Loss=37.1522
# Epoch 70: Loss=37.1762
# Epoch 80: Loss=36.9587
# Epoch 90: Loss=36.9238
# Epoch 100: Loss=37.9618
# Epoch 110: Loss=36.6372
# Epoch 120: Loss=38.3308
# Epoch 130: Loss=37.9491
# Epoch 140: Loss=36.5689
# Epoch 150: Loss=36.3691
# Epoch 160: Loss=36.3181
# Epoch 170: Loss=36.3418
# Epoch 180: Loss=36.2725
# Epoch 190: Loss=36.0031
# Epoch 200: Loss=36.0930
# Epoch 210: Loss=35.7794
# Epoch 220: Loss=36.1382
# Epoch 230: Loss=35.6271
# Epoch 240: Loss=37.1044
# Epoch 250: Loss=35.3315
# Epoch 260: Loss=35.0943
# Epoch 270: Loss=35.8941
# Epoch 280: Loss=35.2811
# Epoch 290: Loss=35.2173
# Epoch 300: Loss=34.8285
# ✅ MSE: 33.1516 | R²: 0.0808
# ▶ Training: lr=1e-05, batch=16, hidden=(64, 32, 16), epochs=100
# Epoch 10: Loss=46.0230
# Epoch 20: Loss=39.2966
# Epoch 30: Loss=40.4325
# Epoch 40: Loss=49.2270
# Epoch 50: Loss=39.1240
# Epoch 60: Loss=37.9865
# Epoch 70: Loss=37.4384
# Epoch 80: Loss=40.8506
# Epoch 90: Loss=40.0314
# Epoch 100: Loss=38.1592
# ✅ MSE: 35.3596 | R²: 0.0196
# ▶ Training: lr=1e-05, batch=16, hidden=(64, 32, 16), epochs=200
# Epoch 10: Loss=212.7455
# Epoch 20: Loss=52.2477
# Epoch 30: Loss=45.3314
# Epoch 40: Loss=42.7353
# Epoch 50: Loss=41.0886
# Epoch 60: Loss=39.9777
# Epoch 70: Loss=39.5600
# Epoch 80: Loss=38.2018
# Epoch 90: Loss=37.8178
# Epoch 100: Loss=37.8029
# Epoch 110: Loss=37.8324
# Epoch 120: Loss=37.7230
# Epoch 130: Loss=37.2217
# Epoch 140: Loss=38.6304
# Epoch 150: Loss=37.3214
# Epoch 160: Loss=36.9179
# Epoch 170: Loss=36.8824
# Epoch 180: Loss=36.7770
# Epoch 190: Loss=39.8738
# Epoch 200: Loss=37.6848
# ✅ MSE: 34.6403 | R²: 0.0396
# ▶ Training: lr=1e-05, batch=16, hidden=(64, 32, 16), epochs=300
# Epoch 10: Loss=65.9695
# Epoch 20: Loss=53.9766
# Epoch 30: Loss=49.4467
# Epoch 40: Loss=45.5036
# Epoch 50: Loss=43.2846
# Epoch 60: Loss=41.3480
# Epoch 70: Loss=43.9071
# Epoch 80: Loss=39.3134
# Epoch 90: Loss=38.7451
# Epoch 100: Loss=38.1835
# Epoch 110: Loss=41.5249
# Epoch 120: Loss=37.9434
# Epoch 130: Loss=37.5808
# Epoch 140: Loss=37.4684
# Epoch 150: Loss=40.5973
# Epoch 160: Loss=37.4385
# Epoch 170: Loss=37.2313
# Epoch 180: Loss=37.2623
# Epoch 190: Loss=37.1200
# Epoch 200: Loss=37.2054
# Epoch 210: Loss=36.9014
# Epoch 220: Loss=44.9526
# Epoch 230: Loss=36.7825
# Epoch 240: Loss=37.1405
# Epoch 250: Loss=38.5672
# Epoch 260: Loss=36.8069
# Epoch 270: Loss=36.7032
# Epoch 280: Loss=40.9240
# Epoch 290: Loss=36.4896
# Epoch 300: Loss=48.6493
# ✅ MSE: 34.8459 | R²: 0.0339
# ▶ Training: lr=1e-05, batch=16, hidden=(64, 32, 16, 8), epochs=100
# Epoch 10: Loss=49.6149
# Epoch 20: Loss=39.3654
# Epoch 30: Loss=38.7862
# Epoch 40: Loss=44.8538
# Epoch 50: Loss=38.5478
# Epoch 60: Loss=38.0118
# Epoch 70: Loss=47.4481
# Epoch 80: Loss=37.9112
# Epoch 90: Loss=38.6181
# Epoch 100: Loss=37.6325
# ✅ MSE: 35.5826 | R²: 0.0134
# ▶ Training: lr=1e-05, batch=16, hidden=(64, 32, 16, 8), epochs=200
# Epoch 10: Loss=47.4262
# Epoch 20: Loss=40.2131
# Epoch 30: Loss=38.3413
# Epoch 40: Loss=38.1342
# Epoch 50: Loss=38.5989
# Epoch 60: Loss=37.8481
# Epoch 70: Loss=45.7900
# Epoch 80: Loss=39.3298
# Epoch 90: Loss=37.8001
# Epoch 100: Loss=37.6963
# Epoch 110: Loss=37.7718
# Epoch 120: Loss=40.7048
# Epoch 130: Loss=37.7987
# Epoch 140: Loss=37.7014
# Epoch 150: Loss=37.7880
# Epoch 160: Loss=38.2951
# Epoch 170: Loss=37.6340
# Epoch 180: Loss=38.2687
# Epoch 190: Loss=38.5382
# Epoch 200: Loss=40.8962
# ✅ MSE: 35.8100 | R²: 0.0071
# ▶ Training: lr=1e-05, batch=16, hidden=(64, 32, 16, 8), epochs=300
# Epoch 10: Loss=42.2433
# Epoch 20: Loss=39.4245
# Epoch 30: Loss=38.6659
# Epoch 40: Loss=39.8384
# Epoch 50: Loss=37.4743
# Epoch 60: Loss=38.2789
# Epoch 70: Loss=38.0562
# Epoch 80: Loss=38.3412
# Epoch 90: Loss=37.1932
# Epoch 100: Loss=39.4803
# Epoch 110: Loss=37.5678
# Epoch 120: Loss=37.7118
# Epoch 130: Loss=37.5167
# Epoch 140: Loss=40.7683
# Epoch 150: Loss=37.0450
# Epoch 160: Loss=39.1511
# Epoch 170: Loss=40.5834
# Epoch 180: Loss=37.2492
# Epoch 190: Loss=36.9962
# Epoch 200: Loss=37.1375
# Epoch 210: Loss=39.8946
# Epoch 220: Loss=37.1589
# Epoch 230: Loss=36.9349
# Epoch 240: Loss=47.2209
# Epoch 250: Loss=38.2510
# Epoch 260: Loss=38.9781
# Epoch 270: Loss=37.1828
# Epoch 280: Loss=36.9974
# Epoch 290: Loss=37.0032
# Epoch 300: Loss=40.5325
# ✅ MSE: 35.0947 | R²: 0.0270
# ▶ Training: lr=1e-05, batch=16, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=100
# Epoch 10: Loss=38.9313
# Epoch 20: Loss=38.1224
# Epoch 30: Loss=38.8979
# Epoch 40: Loss=40.8046
# Epoch 50: Loss=37.8573
# Epoch 60: Loss=37.8392
# Epoch 70: Loss=38.4469
# Epoch 80: Loss=37.7958
# Epoch 90: Loss=37.7850
# Epoch 100: Loss=38.1476
# ✅ MSE: 36.3164 | R²: -0.0069
# ▶ Training: lr=1e-05, batch=16, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=200
# Epoch 10: Loss=39.1416
# Epoch 20: Loss=38.5841
# Epoch 30: Loss=38.7635
# Epoch 40: Loss=38.8238
# Epoch 50: Loss=38.2864
# Epoch 60: Loss=38.4910
# Epoch 70: Loss=38.5486
# Epoch 80: Loss=38.2873
# Epoch 90: Loss=39.6137
# Epoch 100: Loss=39.6447
# Epoch 110: Loss=38.2272
# Epoch 120: Loss=40.5443
# Epoch 130: Loss=42.6921
# Epoch 140: Loss=39.5715
# Epoch 150: Loss=38.1369
# Epoch 160: Loss=39.7579
# Epoch 170: Loss=38.0865
# Epoch 180: Loss=39.4326
# Epoch 190: Loss=38.0862
# Epoch 200: Loss=37.9535
# ✅ MSE: 36.1913 | R²: -0.0034
# ▶ Training: lr=1e-05, batch=16, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=300
# Epoch 10: Loss=40.1374
# Epoch 20: Loss=41.0736
# Epoch 30: Loss=40.3589
# Epoch 40: Loss=39.6440
# Epoch 50: Loss=38.9882
# Epoch 60: Loss=38.6166
# Epoch 70: Loss=38.9932
# Epoch 80: Loss=38.6255
# Epoch 90: Loss=40.6342
# Epoch 100: Loss=38.8721
# Epoch 110: Loss=38.5411
# Epoch 120: Loss=38.1993
# Epoch 130: Loss=39.4600
# Epoch 140: Loss=38.9230
# Epoch 150: Loss=38.1462
# Epoch 160: Loss=39.9992
# Epoch 170: Loss=38.3124
# Epoch 180: Loss=38.7183
# Epoch 190: Loss=39.9556
# Epoch 200: Loss=40.1055
# Epoch 210: Loss=39.5392
# Epoch 220: Loss=38.9404
# Epoch 230: Loss=38.0735
# Epoch 240: Loss=38.1447
# Epoch 250: Loss=38.1442
# Epoch 260: Loss=38.0682
# Epoch 270: Loss=38.5713
# Epoch 280: Loss=38.0122
# Epoch 290: Loss=38.2536
# Epoch 300: Loss=38.1187
# ✅ MSE: 36.2865 | R²: -0.0061
# ▶ Training: lr=1e-05, batch=32, hidden=(128, 64, 32), epochs=100
# Epoch 10: Loss=2130.7023
# Epoch 20: Loss=466.2429
# Epoch 30: Loss=107.5750
# Epoch 40: Loss=50.8496
# Epoch 50: Loss=40.9751
# Epoch 60: Loss=39.2083
# Epoch 70: Loss=39.1326
# Epoch 80: Loss=39.5616
# Epoch 90: Loss=39.2656
# Epoch 100: Loss=39.4647
# ✅ MSE: 36.5784 | R²: -0.0142
# ▶ Training: lr=1e-05, batch=32, hidden=(128, 64, 32), epochs=200
# Epoch 10: Loss=348.5610
# Epoch 20: Loss=51.6456
# Epoch 30: Loss=42.2092
# Epoch 40: Loss=40.7206
# Epoch 50: Loss=39.1022
# Epoch 60: Loss=40.6419
# Epoch 70: Loss=38.4521
# Epoch 80: Loss=38.4804
# Epoch 90: Loss=39.0211
# Epoch 100: Loss=37.3978
# Epoch 110: Loss=38.1203
# Epoch 120: Loss=37.4925
# Epoch 130: Loss=37.2374
# Epoch 140: Loss=37.5860
# Epoch 150: Loss=37.6966
# Epoch 160: Loss=37.5773
# Epoch 170: Loss=37.3810
# Epoch 180: Loss=38.7075
# Epoch 190: Loss=37.8110
# Epoch 200: Loss=37.4965
# ✅ MSE: 34.0679 | R²: 0.0554
# ▶ Training: lr=1e-05, batch=32, hidden=(128, 64, 32), epochs=300
# Epoch 10: Loss=51.5528
# Epoch 20: Loss=42.4828
# Epoch 30: Loss=38.9617
# Epoch 40: Loss=40.7218
# Epoch 50: Loss=38.9617
# Epoch 60: Loss=38.9321
# Epoch 70: Loss=38.8604
# Epoch 80: Loss=40.4062
# Epoch 90: Loss=38.8529
# Epoch 100: Loss=40.7224
# Epoch 110: Loss=38.7900
# Epoch 120: Loss=38.9264
# Epoch 130: Loss=41.2820
# Epoch 140: Loss=39.1544
# Epoch 150: Loss=38.7245
# Epoch 160: Loss=38.1312
# Epoch 170: Loss=38.1197
# Epoch 180: Loss=38.1885
# Epoch 190: Loss=38.5416
# Epoch 200: Loss=38.8129
# Epoch 210: Loss=37.6592
# Epoch 220: Loss=37.9717
# Epoch 230: Loss=37.7035
# Epoch 240: Loss=37.5859
# Epoch 250: Loss=39.8999
# Epoch 260: Loss=37.5527
# Epoch 270: Loss=39.2817
# Epoch 280: Loss=37.5516
# Epoch 290: Loss=37.0682
# Epoch 300: Loss=39.4274
# ✅ MSE: 34.6492 | R²: 0.0393
# ▶ Training: lr=1e-05, batch=32, hidden=(64, 32, 16), epochs=100
# Epoch 10: Loss=189.4113
# Epoch 20: Loss=58.7662
# Epoch 30: Loss=39.9469
# Epoch 40: Loss=38.1324
# Epoch 50: Loss=36.9688
# Epoch 60: Loss=37.6434
# Epoch 70: Loss=37.3862
# Epoch 80: Loss=37.2970
# Epoch 90: Loss=37.4540
# Epoch 100: Loss=37.2560
# ✅ MSE: 34.0207 | R²: 0.0567
# ▶ Training: lr=1e-05, batch=32, hidden=(64, 32, 16), epochs=200
# Epoch 10: Loss=51.3047
# Epoch 20: Loss=44.1959
# Epoch 30: Loss=41.6438
# Epoch 40: Loss=40.8072
# Epoch 50: Loss=41.0815
# Epoch 60: Loss=43.0792
# Epoch 70: Loss=38.7499
# Epoch 80: Loss=38.6193
# Epoch 90: Loss=38.8071
# Epoch 100: Loss=38.7911
# Epoch 110: Loss=39.2944
# Epoch 120: Loss=38.5311
# Epoch 130: Loss=38.9141
# Epoch 140: Loss=38.3100
# Epoch 150: Loss=38.7981
# Epoch 160: Loss=38.6923
# Epoch 170: Loss=38.4201
# Epoch 180: Loss=41.8263
# Epoch 190: Loss=38.5474
# Epoch 200: Loss=37.9499
# ✅ MSE: 35.8612 | R²: 0.0057
# ▶ Training: lr=1e-05, batch=32, hidden=(64, 32, 16), epochs=300
# Epoch 10: Loss=302.6371
# Epoch 20: Loss=117.9539
# Epoch 30: Loss=69.3629
# Epoch 40: Loss=53.4749
# Epoch 50: Loss=47.9979
# Epoch 60: Loss=44.4225
# Epoch 70: Loss=41.5620
# Epoch 80: Loss=41.2965
# Epoch 90: Loss=41.6412
# Epoch 100: Loss=38.2802
# Epoch 110: Loss=37.4913
# Epoch 120: Loss=37.5367
# Epoch 130: Loss=37.0300
# Epoch 140: Loss=38.1264
# Epoch 150: Loss=36.9853
# Epoch 160: Loss=36.1696
# Epoch 170: Loss=36.1070
# Epoch 180: Loss=38.6561
# Epoch 190: Loss=38.8559
# Epoch 200: Loss=36.2290
# Epoch 210: Loss=36.9037
# Epoch 220: Loss=35.8673
# Epoch 230: Loss=35.6934
# Epoch 240: Loss=36.2582
# Epoch 250: Loss=35.1811
# Epoch 260: Loss=36.3805
# Epoch 270: Loss=35.2932
# Epoch 280: Loss=36.4149
# Epoch 290: Loss=36.8704
# Epoch 300: Loss=36.1889
# ✅ MSE: 32.7712 | R²: 0.0914
# ▶ Training: lr=1e-05, batch=32, hidden=(64, 32, 16, 8), epochs=100
# Epoch 10: Loss=49.2587
# Epoch 20: Loss=44.6162
# Epoch 30: Loss=42.8919
# Epoch 40: Loss=45.0126
# Epoch 50: Loss=42.2407
# Epoch 60: Loss=42.9129
# Epoch 70: Loss=43.1020
# Epoch 80: Loss=43.5020
# Epoch 90: Loss=46.8833
# Epoch 100: Loss=42.4206
# ✅ MSE: 41.1524 | R²: -0.1410
# ▶ Training: lr=1e-05, batch=32, hidden=(64, 32, 16, 8), epochs=200
# Epoch 10: Loss=495.6127
# Epoch 20: Loss=293.4553
# Epoch 30: Loss=184.1394
# Epoch 40: Loss=111.2216
# Epoch 50: Loss=82.1816
# Epoch 60: Loss=65.6732
# Epoch 70: Loss=54.8093
# Epoch 80: Loss=48.4633
# Epoch 90: Loss=45.1496
# Epoch 100: Loss=43.9893
# Epoch 110: Loss=41.9570
# Epoch 120: Loss=41.3543
# Epoch 130: Loss=44.7892
# Epoch 140: Loss=40.4633
# Epoch 150: Loss=40.9451
# Epoch 160: Loss=40.4653
# Epoch 170: Loss=39.7220
# Epoch 180: Loss=40.7832
# Epoch 190: Loss=39.8451
# Epoch 200: Loss=40.7073
# ✅ MSE: 36.8272 | R²: -0.0211
# ▶ Training: lr=1e-05, batch=32, hidden=(64, 32, 16, 8), epochs=300
# Epoch 10: Loss=58.9676
# Epoch 20: Loss=44.6705
# Epoch 30: Loss=41.0286
# Epoch 40: Loss=40.5765
# Epoch 50: Loss=44.1498
# Epoch 60: Loss=39.5655
# Epoch 70: Loss=39.5460
# Epoch 80: Loss=37.8805
# Epoch 90: Loss=39.1778
# Epoch 100: Loss=38.3751
# Epoch 110: Loss=38.9190
# Epoch 120: Loss=38.8823
# Epoch 130: Loss=38.1132
# Epoch 140: Loss=38.9113
# Epoch 150: Loss=37.4233
# Epoch 160: Loss=38.1125
# Epoch 170: Loss=39.6467
# Epoch 180: Loss=37.7171
# Epoch 190: Loss=37.9610
# Epoch 200: Loss=37.6286
# Epoch 210: Loss=37.5243
# Epoch 220: Loss=41.0986
# Epoch 230: Loss=37.6807
# Epoch 240: Loss=38.1139
# Epoch 250: Loss=37.7131
# Epoch 260: Loss=38.3162
# Epoch 270: Loss=38.3444
# Epoch 280: Loss=39.1497
# Epoch 290: Loss=38.3271
# Epoch 300: Loss=40.7238
# ✅ MSE: 35.3267 | R²: 0.0205
# ▶ Training: lr=1e-05, batch=32, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=100
# Epoch 10: Loss=41.2919
# Epoch 20: Loss=40.6766
# Epoch 30: Loss=39.4169
# Epoch 40: Loss=39.9395
# Epoch 50: Loss=40.0836
# Epoch 60: Loss=38.9186
# Epoch 70: Loss=42.0773
# Epoch 80: Loss=39.0629
# Epoch 90: Loss=38.9796
# Epoch 100: Loss=38.7641
# ✅ MSE: 36.3985 | R²: -0.0092
# ▶ Training: lr=1e-05, batch=32, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=200
# Epoch 10: Loss=41.7404
# Epoch 20: Loss=43.4832
# Epoch 30: Loss=39.9186
# Epoch 40: Loss=39.1990
# Epoch 50: Loss=40.0693
# Epoch 60: Loss=38.8530
# Epoch 70: Loss=38.4444
# Epoch 80: Loss=38.9494
# Epoch 90: Loss=39.0866
# Epoch 100: Loss=38.8558
# Epoch 110: Loss=38.6621
# Epoch 120: Loss=39.7054
# Epoch 130: Loss=38.8807
# Epoch 140: Loss=38.5457
# Epoch 150: Loss=39.9948
# Epoch 160: Loss=38.5637
# Epoch 170: Loss=38.9967
# Epoch 180: Loss=38.3936
# Epoch 190: Loss=38.6349
# Epoch 200: Loss=38.3565
# ✅ MSE: 36.0216 | R²: 0.0013
# ▶ Training: lr=1e-05, batch=32, hidden=(8, 16, 32, 64, 32, 16, 8), epochs=300
# Epoch 10: Loss=40.8941
# Epoch 20: Loss=39.9780
# Epoch 30: Loss=40.4422
# Epoch 40: Loss=39.8696
# Epoch 50: Loss=39.8447
# Epoch 60: Loss=39.4968
# Epoch 70: Loss=40.4350
# Epoch 80: Loss=39.9603
# Epoch 90: Loss=39.1767
# Epoch 100: Loss=39.4045
# Epoch 110: Loss=40.2095
# Epoch 120: Loss=40.3191
# Epoch 130: Loss=39.4905
# Epoch 140: Loss=39.9476
# Epoch 150: Loss=41.5316
# Epoch 160: Loss=39.2869
# Epoch 170: Loss=39.0292
# Epoch 180: Loss=39.3926
# Epoch 190: Loss=39.6256
# Epoch 200: Loss=40.5458
# Epoch 210: Loss=39.9457
# Epoch 220: Loss=39.9597
# Epoch 230: Loss=40.6749
# Epoch 240: Loss=39.6445
# Epoch 250: Loss=41.6609
# Epoch 260: Loss=39.2789
# Epoch 270: Loss=39.1036
# Epoch 280: Loss=39.0578
# Epoch 290: Loss=40.1630
# Epoch 300: Loss=39.6289
# ✅ MSE: 36.5469 | R²: -0.0133
# 🏆 Best config: {'lr': 0.0005, 'batch_size': 32, 'hidden_sizes': (64, 32, 16, 8), 'epochs': 300}, R²=0.8955
