# %%
import phate
import scprep
import seaborn as sns
import os
import json
from PIL import Image, ImageDraw
import re
import numpy as np
import cv2
import imageio
import matplotlib.pyplot as plt
import tifffile as tiff
from tqdm import tqdm
from skimage.exposure import equalize_adapthist
from scipy.stats import stats
import matplotlib.animation as animation
import pandas as pd
import csv
import shutil
from skimage.morphology import dilation, erosion
import numpy as np
import matplotlib.pyplot as plt
import imageio
from skimage import measure
from skimage.measure import regionprops, label
from scipy.spatial import distance
import time
import datetime
from mpl_toolkits.mplot3d import Axes3D  # 3D Plotting
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import seaborn as sns
from sklearn.manifold import TSNE
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.stats.diagnostic import het_breuschpagan
from statsmodels.stats.stattools import durbin_watson
from sklearn.linear_model import Ridge, Lasso
from sklearn.preprocessing import StandardScaler, PowerTransformer
from sklearn.metrics import mean_squared_error, r2_score

from skimage.morphology import dilation, erosion
from skimage import measure
from scipy.ndimage import center_of_mass
from glob import glob
import random
from skimage.measure import regionprops, label
from scipy.spatial import distance

import imageio.v2 as imageio
from tifffile import imread

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score


from scipy import stats
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import RidgeCV, LassoCV, ElasticNetCV, LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Final Regression model

# %%
# === CONFIGURATION ===
input_path = "/home/MinaHossain/EmbedTrack/Track_HP4_Result_Shape/Mean/Cells_Centroid_Velocity_TrueLabel_MA_Mean_5.csv"
output_root = "/home/MinaHossain/EmbedTrack/Track_HP4_Result_Shape/Mean"
plot_dir = f"{output_root}/Reg_Results"
os.makedirs(plot_dir, exist_ok=True)

# === LOAD AND CLEAN DATA ===
df = pd.read_csv(input_path)
collinear_features = ['Area_MA', 'Perimeter_MA', 'Solidity_MA', 'Extent_MA',
                      'Circularity_MA', 'Convexity_MA', 'Elongation_MA', 'Compactness_MA']
# spatial_features = ['Centroid_X_MA', 'Centroid_Y_MA', 'X_Centroid_Distance_MA', 'Y_Centroid_Distance_MA']
target_col = 'X_Centroid_Velocity_MA'

# df_clean = df[collinear_features + spatial_features + [target_col]].dropna()
df_clean = df[collinear_features + [target_col]].dropna()
X_collinear = df_clean[collinear_features].values
# X_spatial = df_clean[spatial_features].values
y = df_clean[target_col].values

# === SPLIT DATA ===
# X_col_train, X_col_temp, X_spatial_train, X_spatial_temp, y_train, y_temp = train_test_split(
#     X_collinear, X_spatial, y, test_size=0.4, random_state=42)
# X_col_val, X_col_test, X_spatial_val, X_spatial_test, y_val, y_test = train_test_split(
#     X_col_temp, X_spatial_temp, y_temp, test_size=0.5, random_state=42)


X_col_train, X_col_temp, y_train, y_temp = train_test_split( X_collinear,  y, test_size=0.4, random_state=42)
X_col_val, X_col_test, y_val, y_test = train_test_split(X_col_temp,  y_temp, test_size=0.5, random_state=42)
# === PCA ON TRAIN ===
scaler = StandardScaler()
X_col_train_scaled = scaler.fit_transform(X_col_train)
X_col_val_scaled = scaler.transform(X_col_val)
X_col_test_scaled = scaler.transform(X_col_test)

pca = PCA(n_components=5)
X_pca_train = pca.fit_transform(X_col_train_scaled)
X_pca_val = pca.transform(X_col_val_scaled)
X_pca_test = pca.transform(X_col_test_scaled)

# X_scaled_val = X_col_val_scaled
# pca_full = PCA()
# pca_full.fit(X_scaled_val)
# explained_variance = pca_full.explained_variance_ratio_
# cumulative_variance = np.cumsum(explained_variance)

# optimal_components = np.argmax(cumulative_variance >= 0.95) + 1

# X_train_final = np.hstack([X_pca_train, X_spatial_train])
# X_val_final = np.hstack([X_pca_val, X_spatial_val])
# X_test_final = np.hstack([X_pca_test, X_spatial_test])

X_train_final = X_pca_train
X_val_final = X_pca_val
X_test_final = X_pca_test

# === DEFINE MODELS ===
models = {
    "LinearRegression": LinearRegression(),
    "Ridge": RidgeCV(alphas=np.logspace(-3, 3, 50), cv=5),
    "Lasso": LassoCV(cv=5, random_state=42, max_iter=10000),
    "ElasticNet": ElasticNetCV(cv=5, random_state=42, max_iter=10000),
    "RandomForest": RandomForestRegressor(n_estimators=200, max_depth=10, random_state=42, n_jobs=-1),
    "XGBoost": XGBRegressor(n_estimators=200, max_depth=10, learning_rate=0.01, random_state=42, n_jobs=-1, verbosity=0)
}

# === EVALUATE MODELS ON VALIDATION SET ===
results = {}
for name, model in models.items():
    try:
        model.fit(X_train_final, y_train)
        y_val_pred = model.predict(X_val_final)
        r2 = r2_score(y_val, y_val_pred)
        results[name] = r2
    except Exception as e:
        results[name] = f"Failed: {str(e)}"

best_model_name = max(results, key=lambda k: results[k] if isinstance(results[k], float) else -np.inf)
best_model = models[best_model_name]
best_model.fit(X_train_final, y_train)
y_test_pred = best_model.predict(X_test_final)

# === SAVE COEFFICIENTS AND PERFORMANCE ===
# coeff_labels = [f'PC{i+1}' for i in range(3)] + spatial_features
coeff_labels = [f'PC{i+1}' for i in range(3)] 
coef_df = pd.DataFrame({'Feature': coeff_labels, 'Coefficient': best_model.coef_}) if hasattr(best_model, 'coef_') else pd.DataFrame()
metrics_df = pd.DataFrame({
    'Metric': ['R-squared', 'MSE'],
    'Value': [r2_score(y_test, y_test_pred), mean_squared_error(y_test, y_test_pred)]
})
coef_df.to_csv(f"{plot_dir}/best_model_coefficients.csv", index=False)
metrics_df.to_csv(f"{plot_dir}/best_model_metrics.csv", index=False)

# === PLOTTING ===
def plot_results(y_true, y_pred):
    residuals = y_true - y_pred
    absolute_errors = np.abs(residuals)

    def save_plot(fig, name):
        fig.tight_layout()
        fig.savefig(f"{plot_dir}/{name}.png")
        plt.close(fig)

    fig, ax = plt.subplots(figsize=(8, 5))
    sns.scatterplot(x=y_pred, y=residuals, ax=ax)
    ax.axhline(0, linestyle='--', color='red')
    ax.set_title("Residuals vs Predicted")
    ax.set_xlabel("Predicted")
    ax.set_ylabel("Residuals")
    save_plot(fig, "residuals_vs_predicted")

    fig, ax = plt.subplots(figsize=(8, 5))
    sns.scatterplot(x=y_true, y=y_pred, ax=ax)
    ax.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], linestyle='--', color='red')
    ax.set_title("Predicted vs Actual")
    ax.set_xlabel("Actual")
    ax.set_ylabel("Predicted")
    save_plot(fig, "predicted_vs_actual")

    fig, ax = plt.subplots(figsize=(8, 5))
    sns.histplot(residuals, bins=30, kde=True, ax=ax)
    ax.set_title("Distribution of Residuals")
    ax.set_xlabel("Residuals")
    save_plot(fig, "residuals_distribution")

    fig, ax = plt.subplots(figsize=(8, 5))
    sorted_errors = np.sort(absolute_errors)
    cum_dist = np.arange(1, len(sorted_errors) + 1) / len(sorted_errors)
    ax.plot(sorted_errors, cum_dist)
    ax.set_title("Cumulative Distribution of Absolute Errors")
    ax.set_xlabel("Absolute Error")
    ax.set_ylabel("Cumulative Proportion")
    save_plot(fig, "cumulative_absolute_errors")

    fig = plt.figure(figsize=(6, 6))
    stats.probplot(residuals, dist="norm", plot=plt)
    plt.title("Q-Q Plot of Residuals")
    save_plot(fig, "qq_plot_residuals")

    fig, ax = plt.subplots(figsize=(8, 5))
    sns.scatterplot(x=y_true, y=absolute_errors, ax=ax)
    ax.set_title("Absolute Error vs Actual Value")
    ax.set_xlabel("Actual Values")
    ax.set_ylabel("Absolute Error")
    save_plot(fig, "absolute_error_vs_actual")

plot_results(y_test, y_test_pred)

# === REPORT ON SPLITS ===
y_train_pred = best_model.predict(X_train_final)
y_val_pred = best_model.predict(X_val_final)
y_test_pred = best_model.predict(X_test_final)

performance = pd.DataFrame({
    "Split": ["Train", "Validation", "Test"],
    "R-squared": [
        r2_score(y_train, y_train_pred),
        r2_score(y_val, y_val_pred),
        r2_score(y_test, y_test_pred)
    ],
    "MSE": [
        mean_squared_error(y_train, y_train_pred),
        mean_squared_error(y_val, y_val_pred),
        mean_squared_error(y_test, y_test_pred)
    ]
})

performance.to_csv(f"{plot_dir}/model_performance_by_split.csv", index=False)
print(f"Best model: {best_model_name}")
print(performance)


# Generate the code block for PCA + Clustering using validation data and applying to test data


# === PCA + KMeans CLUSTERING (Fit on Validation, Apply to Test) ===
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

output_directory = plot_dir
window_size = 5

# --- Fit PCA on Validation Set ---
X_scaled_val = X_col_val_scaled
pca_full = PCA()
pca_full.fit(X_scaled_val)
explained_variance = pca_full.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance)

optimal_components = np.argmax(cumulative_variance >= 0.95) + 1

# --- Plot PCA Cumulative Variance (Elbow Plot) ---
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker='s', linestyle='-', color='red', label="Cumulative Variance")
plt.axvline(x=optimal_components, color='green', linestyle='--', label=f"Optimal Components ({optimal_components})")
plt.scatter(optimal_components, cumulative_variance[optimal_components-1], color='black', s=50, label="Chosen Point")
plt.xlabel("Number of Principal Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("PCA Elbow Plot with Cumulative Variance")
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig(os.path.join(output_directory, f"PCA_Elbow_Plot_{window_size}.png"))
plt.close()

# --- Fit 2D PCA on Validation ---
pca_2d = PCA(n_components=2)
pca_val_2d = pca_2d.fit_transform(X_scaled_val)

# --- KMeans on 2D PCA space (Validation) ---
silhouette_scores = []
k_range = range(3, 15)
for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=0, n_init='auto').fit(pca_val_2d)
    score = silhouette_score(pca_val_2d, kmeans.labels_)
    silhouette_scores.append(score)

optimal_k = k_range[np.argmax(silhouette_scores)]
optimal_score = max(silhouette_scores)

# --- Plot Silhouette Scores ---
plt.figure(figsize=(8, 6))
plt.plot(k_range, silhouette_scores, marker='o', linestyle='-', color='purple', label="Silhouette Score")
plt.axvline(x=optimal_k, color='green', linestyle='--', label=f"Optimal k = {optimal_k}")
plt.scatter(optimal_k, optimal_score, color='red', s=100, zorder=5)
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score vs Number of Clusters (Validation)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig(os.path.join(output_directory, f"Silhouette_Score_vs_K_{window_size}.png"))
plt.close()

# --- Apply to Test Data ---
X_scaled_test = X_col_test_scaled
pca_test_2d = pca_2d.transform(X_scaled_test)
kmeans_final = KMeans(n_clusters=optimal_k, random_state=0, n_init='auto').fit(pca_val_2d)
test_clusters = kmeans_final.predict(pca_test_2d)

# --- Create Test DataFrame with PCA + Clusters ---
pca_test_df = pd.DataFrame(pca_test_2d, columns=["PCA1", "PCA2"])
pca_test_df["X_Centroid_Velocity_MA"] = X_col_test[:, 0]  # Area_MA is first collinear feature
pca_test_df["Cluster"] = test_clusters

# --- Clustered 2D PCA (Colored by Area) ---
vmin = np.percentile(pca_test_df["X_Centroid_Velocity_MA"], 5)
vmax = np.percentile(pca_test_df["X_Centroid_Velocity_MA"], 95)
plt.figure(figsize=(10, 7))
sc = plt.scatter(pca_test_df["PCA1"], pca_test_df["PCA2"], c=pca_test_df["X_Centroid_Velocity_MA"], cmap="plasma", alpha=0.8, vmin=vmin, vmax=vmax)
plt.colorbar(sc, label="X_Centroid Velocity (MA)")
plt.title("2D PCA Test Data Colored by X_Centroid Velocity(MA)")
plt.xlabel("PCA1")
plt.ylabel("PCA2")
plt.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(output_directory, f"PCA_2D_X_Centroid_Velocity_MA_{window_size}.png"))
plt.close()

# --- Cluster Plot with Centers ---
plt.figure(figsize=(10, 7))
plt.scatter(pca_test_df["PCA1"], pca_test_df["PCA2"], c=pca_test_df["Cluster"], cmap="tab10", alpha=0.8)
centers = kmeans_final.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, marker='o', label='Centers')
for idx, (x, y) in enumerate(centers):
    plt.text(x, y, str(idx), fontsize=12, fontweight='bold', ha='center', va='center', color='white',
             bbox=dict(facecolor='black', boxstyle='circle,pad=0.2'))
plt.title(f"Test Data PCA with KMeans Clusters (k={optimal_k})")
plt.xlabel("PCA1")
plt.ylabel("PCA2")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(output_directory, f"PCA_2D_Clusters_X_Centroid_Velocity_MA_{window_size}.png"))
plt.close()

# --- Boxplot: Area by Cluster (Test Data) ---
plt.figure(figsize=(10, 6))
sns.boxplot(data=pca_test_df, x="Cluster", y="X_Centroid_Velocity_MA", palette="Set2")
sns.stripplot(data=pca_test_df, x="Cluster", y="X_Centroid_Velocity_MA", color='gray', alpha=0.5, jitter=0.2, size=3)
plt.title("X_Centroid Velocity (MA) by Cluster (Test Data)", fontsize=14)
plt.xlabel("Cluster")
plt.ylabel("X_Centroid Velocity (MA)")
plt.tight_layout()
plt.savefig(os.path.join(output_directory, f"Boxplot_X_Centroid_Velocity_MA_By_Cluster_{window_size}.png"))
plt.close()

# --- Save clustered PCA test data and summary ---
pca_test_df.to_csv(os.path.join(output_directory, f"PCA_Cluster_Results_Test_{window_size}.csv"), index=False)

summary = pca_test_df.groupby("Cluster").agg({
    "PCA1": ["mean", "std"],
    "PCA2": ["mean", "std"],
    "X_Centroid_Velocity_MA": ["mean", "std"]
}).reset_index()
summary.columns = ["_".join(col).strip("_") for col in summary.columns.values]
summary.to_csv(os.path.join(output_directory, f"PCA_Cluster_Summary_Test_{window_size}.csv"), index=False)
# Out:
# Best model: RandomForest
#         Split  R-squared        MSE
# 0       Train   0.832742  28.795202
# 1  Validation   0.109655  92.072594
# 2        Test  -0.294657  84.136988
# /tmp/ipykernel_679803/3026260600.py:278: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=pca_test_df, x="Cluster", y="X_Centroid_Velocity_MA", palette="Set2")

# %%
# from sklearn.model_selection import train_test_split, RandomizedSearchCV
# from sklearn.preprocessing import StandardScaler
# from sklearn.decomposition import PCA
# from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression
# from sklearn.ensemble import RandomForestRegressor
# from xgboost import XGBRegressor
# from sklearn.metrics import r2_score, mean_squared_error
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# import scipy.stats as stats
# import os

# # === CONFIGURATION ===
# input_path = "/home/MinaHossain/EmbedTrack/Track_HP4_Result_Shape/Mean/Cells_Centroid_Velocity_TrueLabel_MA_Mean_5.csv"
# output_root = "/home/MinaHossain/EmbedTrack/Track_HP4_Result_Shape/Mean"
# plot_dir = f"{output_root}/Reg_Results"
# os.makedirs(plot_dir, exist_ok=True)

# # === LOAD AND CLEAN DATA ===
# df = pd.read_csv(input_path)
# collinear_features = ['Area_MA', 'Perimeter_MA', 'Solidity_MA', 'Extent_MA',
#                       'Circularity_MA', 'Convexity_MA', 'Elongation_MA', 'Compactness_MA']
# target_col = 'X_Centroid_Velocity_MA'
# df_clean = df[collinear_features + [target_col]].dropna()
# X_collinear = df_clean[collinear_features].values
# y = df_clean[target_col].values

# # === SPLIT DATA ===
# X_col_train, X_col_temp, y_train, y_temp = train_test_split(X_collinear, y, test_size=0.4, random_state=42)
# X_col_val, X_col_test, y_val, y_test = train_test_split(X_col_temp, y_temp, test_size=0.5, random_state=42)

# # === PCA ON TRAIN ===
# scaler = StandardScaler()
# X_col_train_scaled = scaler.fit_transform(X_col_train)
# X_col_val_scaled = scaler.transform(X_col_val)
# X_col_test_scaled = scaler.transform(X_col_test)

# pca = PCA(n_components=5)
# X_pca_train = pca.fit_transform(X_col_train_scaled)
# X_pca_val = pca.transform(X_col_val_scaled)
# X_pca_test = pca.transform(X_col_test_scaled)

# X_train_final = X_pca_train
# X_val_final = X_pca_val
# X_test_final = X_pca_test

# # === TUNE MODELS USING RANDOMIZED SEARCH ===
# tuned_models = {}
# param_logs = []

# ridge_param_grid = {"alpha": np.logspace(-3, 3, 100)}
# ridge_search = RandomizedSearchCV(Ridge(), param_distributions=ridge_param_grid, n_iter=20, cv=3, scoring='r2', random_state=42)
# ridge_search.fit(X_train_final, y_train)
# tuned_models["Ridge_Tuned"] = ridge_search.best_estimator_
# param_logs.append(("Ridge_Tuned", ridge_search.best_params_))

# lasso_param_grid = {"alpha": np.logspace(-3, 3, 100), "max_iter": [10000]}
# lasso_search = RandomizedSearchCV(Lasso(random_state=42), param_distributions=lasso_param_grid, n_iter=20, cv=3, scoring='r2', random_state=42)
# lasso_search.fit(X_train_final, y_train)
# tuned_models["Lasso_Tuned"] = lasso_search.best_estimator_
# param_logs.append(("Lasso_Tuned", lasso_search.best_params_))

# enet_param_grid = {
#     "alpha": np.logspace(-3, 3, 50),
#     "l1_ratio": np.linspace(0.1, 0.9, 9),
#     "max_iter": [10000]
# }
# enet_search = RandomizedSearchCV(ElasticNet(random_state=42), param_distributions=enet_param_grid, n_iter=30, cv=3, scoring='r2', random_state=42)
# enet_search.fit(X_train_final, y_train)
# tuned_models["ElasticNet_Tuned"] = enet_search.best_estimator_
# param_logs.append(("ElasticNet_Tuned", enet_search.best_params_))

# rf_param_grid = {
#     "n_estimators": [50, 100, 200],
#     "max_depth": [5, 10, 15, None],
#     "min_samples_split": [2, 5, 10],
#     "min_samples_leaf": [1, 2, 4],
#     "max_features": ["auto", "sqrt", "log2"]
# }
# rf_search = RandomizedSearchCV(RandomForestRegressor(random_state=42, n_jobs=-1),
#                                param_distributions=rf_param_grid,
#                                n_iter=30, cv=3, scoring='r2', random_state=42, n_jobs=-1)
# rf_search.fit(X_train_final, y_train)
# tuned_models["RandomForest_Tuned"] = rf_search.best_estimator_
# param_logs.append(("RandomForest_Tuned", rf_search.best_params_))

# xgb_param_grid = {
#     "n_estimators": [100, 200, 300],
#     "max_depth": [3, 6, 10],
#     "learning_rate": [0.01, 0.05, 0.1],
#     "subsample": [0.7, 0.9, 1.0],
#     "colsample_bytree": [0.7, 0.9, 1.0]
# }
# xgb_search = RandomizedSearchCV(XGBRegressor(random_state=42, verbosity=0, n_jobs=-1),
#                                 param_distributions=xgb_param_grid,
#                                 n_iter=30, cv=3, scoring='r2', random_state=42, n_jobs=-1)
# xgb_search.fit(X_train_final, y_train)
# tuned_models["XGBoost_Tuned"] = xgb_search.best_estimator_
# param_logs.append(("XGBoost_Tuned", xgb_search.best_params_))

# tuned_models["LinearRegression_Tuned"] = LinearRegression()
# param_logs.append(("LinearRegression_Tuned", "No tuning required"))

# # === LOG BEST PARAMS ===
# param_df = pd.DataFrame(param_logs, columns=["Model", "Best_Params"])
# param_df.to_csv(f"{plot_dir}/best_model_hyperparameters.csv", index=False)

# # === EVALUATE TUNED MODELS ===
# results = {}
# for name, model in tuned_models.items():
#     try:
#         model.fit(X_train_final, y_train)
#         y_val_pred = model.predict(X_val_final)
#         r2 = r2_score(y_val, y_val_pred)
#         results[name] = r2
#     except Exception as e:
#         results[name] = f"Failed: {str(e)}"

# best_model_name = max(results, key=lambda k: results[k] if isinstance(results[k], float) else -np.inf)
# best_model = tuned_models[best_model_name]
# best_model.fit(X_train_final, y_train)
# y_test_pred = best_model.predict(X_test_final)

# print(f"Best Tuned Model: {best_model_name}")


# # === PLOTTING ===
# def plot_results(y_true, y_pred):
#     residuals = y_true - y_pred
#     absolute_errors = np.abs(residuals)

#     def save_plot(fig, name):
#         fig.tight_layout()
#         fig.savefig(f"{plot_dir}/{name}.png")
#         plt.close(fig)

#     fig, ax = plt.subplots(figsize=(8, 5))
#     sns.scatterplot(x=y_pred, y=residuals, ax=ax)
#     ax.axhline(0, linestyle='--', color='red')
#     ax.set_title("Residuals vs Predicted")
#     ax.set_xlabel("Predicted")
#     ax.set_ylabel("Residuals")
#     save_plot(fig, "residuals_vs_predicted")

#     fig, ax = plt.subplots(figsize=(8, 5))
#     sns.scatterplot(x=y_true, y=y_pred, ax=ax)
#     ax.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], linestyle='--', color='red')
#     ax.set_title("Predicted vs Actual")
#     ax.set_xlabel("Actual")
#     ax.set_ylabel("Predicted")
#     save_plot(fig, "predicted_vs_actual")

#     fig, ax = plt.subplots(figsize=(8, 5))
#     sns.histplot(residuals, bins=30, kde=True, ax=ax)
#     ax.set_title("Distribution of Residuals")
#     ax.set_xlabel("Residuals")
#     save_plot(fig, "residuals_distribution")

#     fig, ax = plt.subplots(figsize=(8, 5))
#     sorted_errors = np.sort(absolute_errors)
#     cum_dist = np.arange(1, len(sorted_errors) + 1) / len(sorted_errors)
#     ax.plot(sorted_errors, cum_dist)
#     ax.set_title("Cumulative Distribution of Absolute Errors")
#     ax.set_xlabel("Absolute Error")
#     ax.set_ylabel("Cumulative Proportion")
#     save_plot(fig, "cumulative_absolute_errors")

#     fig = plt.figure(figsize=(6, 6))
#     stats.probplot(residuals, dist="norm", plot=plt)
#     plt.title("Q-Q Plot of Residuals")
#     save_plot(fig, "qq_plot_residuals")

#     fig, ax = plt.subplots(figsize=(8, 5))
#     sns.scatterplot(x=y_true, y=absolute_errors, ax=ax)
#     ax.set_title("Absolute Error vs Actual Value")
#     ax.set_xlabel("Actual Values")
#     ax.set_ylabel("Absolute Error")
#     save_plot(fig, "absolute_error_vs_actual")

# plot_results(y_test, y_test_pred)



# performance.to_csv(f"{plot_dir}/model_performance_by_split.csv", index=False)
# print(f"Best model: {best_model_name}")
# print(performance)

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_squared_error
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import os

# === CONFIGURATION ===
input_path = "/home/MinaHossain/EmbedTrack/Track_HP4_Result_Shape/Mean/Cells_Centroid_Velocity_TrueLabel_MA_Mean_5.csv"
output_root = "/home/MinaHossain/EmbedTrack/Track_HP4_Result_Shape/Mean"
plot_dir = f"{output_root}/Reg_Results"
os.makedirs(plot_dir, exist_ok=True)

# === LOAD AND CLEAN DATA ===
df = pd.read_csv(input_path)
collinear_features = ['Area_MA', 'Perimeter_MA', 'Solidity_MA', 'Extent_MA',
                      'Circularity_MA', 'Convexity_MA', 'Elongation_MA', 'Compactness_MA']
target_col = 'X_Centroid_Velocity_MA'
df_clean = df[collinear_features + [target_col]].dropna()
X_collinear = df_clean[collinear_features].values
y = df_clean[target_col].values

# === SPLIT DATA ===
X_col_train, X_col_temp, y_train, y_temp = train_test_split(X_collinear, y, test_size=0.4, random_state=42)
X_col_val, X_col_test, y_val, y_test = train_test_split(X_col_temp, y_temp, test_size=0.5, random_state=42)

# === SCALING ONLY (NO PCA) ===
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_col_train)
X_val_scaled = scaler.transform(X_col_val)
X_test_scaled = scaler.transform(X_col_test)

X_train_final = X_train_scaled
X_val_final = X_val_scaled
X_test_final = X_test_scaled



# # === PCA ON TRAIN ===
# scaler = StandardScaler()
# X_col_train_scaled = scaler.fit_transform(X_col_train)
# X_col_val_scaled = scaler.transform(X_col_val)
# X_col_test_scaled = scaler.transform(X_col_test)

# pca = PCA(n_components=5)
# X_pca_train = pca.fit_transform(X_col_train_scaled)
# X_pca_val = pca.transform(X_col_val_scaled)
# X_pca_test = pca.transform(X_col_test_scaled)

# X_train_final = X_pca_train
# X_val_final = X_pca_val
# X_test_final = X_pca_test







# === TUNE MODELS USING RANDOMIZED SEARCH ===
tuned_models = {}
param_logs = []

ridge_param_grid = {"alpha": np.logspace(-3, 3, 100)}
ridge_search = RandomizedSearchCV(Ridge(), param_distributions=ridge_param_grid, n_iter=20, cv=3, scoring='r2', random_state=42)
ridge_search.fit(X_train_final, y_train)
tuned_models["Ridge_Tuned"] = ridge_search.best_estimator_
param_logs.append(("Ridge_Tuned", ridge_search.best_params_))

lasso_param_grid = {"alpha": np.logspace(-3, 3, 100), "max_iter": [10000]}
lasso_search = RandomizedSearchCV(Lasso(random_state=42), param_distributions=lasso_param_grid, n_iter=20, cv=3, scoring='r2', random_state=42)
lasso_search.fit(X_train_final, y_train)
tuned_models["Lasso_Tuned"] = lasso_search.best_estimator_
param_logs.append(("Lasso_Tuned", lasso_search.best_params_))

enet_param_grid = {
    "alpha": np.logspace(-3, 3, 50),
    "l1_ratio": np.linspace(0.1, 0.9, 9),
    "max_iter": [10000]
}
enet_search = RandomizedSearchCV(ElasticNet(random_state=42), param_distributions=enet_param_grid, n_iter=30, cv=3, scoring='r2', random_state=42)
enet_search.fit(X_train_final, y_train)
tuned_models["ElasticNet_Tuned"] = enet_search.best_estimator_
param_logs.append(("ElasticNet_Tuned", enet_search.best_params_))

rf_param_grid = {
    "n_estimators": [100, 200, 300],
    "max_depth": [5, 10, 15, None],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "max_features": ["auto", "sqrt", "log2"]
}
rf_search = RandomizedSearchCV(RandomForestRegressor(random_state=42, n_jobs=-1),
                               param_distributions=rf_param_grid,
                               n_iter=30, cv=3, scoring='r2', random_state=42, n_jobs=-1)
rf_search.fit(X_train_final, y_train)
tuned_models["RandomForest_Tuned"] = rf_search.best_estimator_
param_logs.append(("RandomForest_Tuned", rf_search.best_params_))

xgb_param_grid = {
    "n_estimators": [100, 200, 300],
    "max_depth": [3, 6, 10],
    "learning_rate": [0.01, 0.05, 0.1],
    "subsample": [0.7, 0.9, 1.0],
    "colsample_bytree": [0.7, 0.9, 1.0]
}
xgb_search = RandomizedSearchCV(XGBRegressor(random_state=42, verbosity=0, n_jobs=-1),
                                param_distributions=xgb_param_grid,
                                n_iter=30, cv=3, scoring='r2', random_state=42, n_jobs=-1)
xgb_search.fit(X_train_final, y_train)
tuned_models["XGBoost_Tuned"] = xgb_search.best_estimator_
param_logs.append(("XGBoost_Tuned", xgb_search.best_params_))

tuned_models["LinearRegression_Tuned"] = LinearRegression()
param_logs.append(("LinearRegression_Tuned", "No tuning required"))

# === LOG BEST PARAMS ===
param_df = pd.DataFrame(param_logs, columns=["Model", "Best_Params"])
param_df.to_csv(f"{plot_dir}/best_model_hyperparameters.csv", index=False)

# === EVALUATE TUNED MODELS ===
results = {}
all_metrics = []
for name, model in tuned_models.items():
    try:
        model.fit(X_train_final, y_train)
        y_val_pred = model.predict(X_val_final)
        r2 = r2_score(y_val, y_val_pred)
        mse = mean_squared_error(y_val, y_val_pred)
        results[name] = r2
        all_metrics.append({"Model": name, "R2_Val": r2, "MSE_Val": mse})
    except Exception as e:
        results[name] = f"Failed: {str(e)}"

metrics_df_all = pd.DataFrame(all_metrics)
metrics_df_all.to_csv(f"{plot_dir}/all_model_val_metrics.csv", index=False)

# === COMPARISON PLOT ===
plt.figure(figsize=(10, 6))
sns.barplot(data=metrics_df_all.sort_values("R2_Val", ascending=False), x="R2_Val", y="Model", palette="viridis")
plt.title("Validation R² Score by Model")
plt.xlabel("R² Score")
plt.ylabel("Model")
plt.tight_layout()
plt.savefig(f"{plot_dir}/model_comparison_r2.png")
plt.close()

# === SELECT AND TEST BEST MODEL ===
best_model_name = max(results, key=lambda k: results[k] if isinstance(results[k], float) else -np.inf)
best_model = tuned_models[best_model_name]
best_model.fit(X_train_final, y_train)
y_test_pred = best_model.predict(X_test_final)

print(f"Best Tuned Model: {best_model_name}")

# === FEATURE IMPORTANCE (if available) ===
if hasattr(best_model, "feature_importances_"):
    importances = best_model.feature_importances_
    feat_df = pd.DataFrame({"Feature": collinear_features, "Importance": importances})
    feat_df = feat_df.sort_values(by="Importance", ascending=False)
    feat_df.to_csv(f"{plot_dir}/best_model_feature_importances.csv", index=False)

    plt.figure(figsize=(10, 6))
    sns.barplot(data=feat_df, x="Importance", y="Feature", palette="crest")
    plt.title("Feature Importances - Best Model")
    plt.tight_layout()
    plt.savefig(f"{plot_dir}/best_model_feature_importance_plot.png")
    plt.close()
# Out:
# /home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 30 fits failed out of a total of 90.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 16 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "/home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 14 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "/home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [0.21931632 0.35082185 0.35432421        nan        nan 0.21578457
#  0.35103023 0.31560914        nan 0.32275734        nan        nan
#  0.32315007 0.29148331        nan 0.34953699 0.23715988 0.33413469
#         nan        nan 0.32263332 0.3447908  0.22204441        nan
#         nan 0.23859076 0.23137683 0.22997051 0.33303191 0.23649439]
#   warnings.warn(
# /tmp/ipykernel_679803/3902549604.py:147: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=metrics_df_all.sort_values("R2_Val", ascending=False), x="R2_Val", y="Model", palette="viridis")
# Best Tuned Model: XGBoost_Tuned
# /tmp/ipykernel_679803/3902549604.py:171: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=feat_df, x="Importance", y="Feature", palette="crest")

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_squared_error
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import os

# === CONFIGURATION ===
input_path = "/home/MinaHossain/EmbedTrack/Track_HP4_Result_Shape/Mean/Cells_Centroid_Velocity_TrueLabel_MA_Mean_5.csv"
output_root = "/home/MinaHossain/EmbedTrack/Track_HP4_Result_Shape/Mean"
plot_dir = f"{output_root}/Reg_Results"
os.makedirs(plot_dir, exist_ok=True)

# === LOAD AND CLEAN DATA ===
df = pd.read_csv(input_path)
collinear_features = ['Area_MA', 'Perimeter_MA', 'Solidity_MA', 'Extent_MA',
                      'Circularity_MA', 'Convexity_MA', 'Elongation_MA', 'Compactness_MA']
target_col = 'X_Centroid_Velocity_MA'
df_clean = df[collinear_features + [target_col]].dropna()
X_collinear = df_clean[collinear_features].values
y = df_clean[target_col].values

# === SPLIT DATA (Train/Test Only) ===
X_train, X_test, y_train, y_test = train_test_split(X_collinear, y, test_size=0.2, random_state=42)

# # === SCALING ONLY (NO PCA) ===
# scaler = StandardScaler()
# X_train_final = scaler.fit_transform(X_train)
# X_test_final = scaler.transform(X_test)


# # === SCALING ONLY (NO PCA) ===
# scaler = StandardScaler()
# X_train_final = scaler.fit_transform(X_train)
# X_test_final = scaler.transform(X_test)


# === PCA ON TRAIN ===
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

pca = PCA(n_components=5)
X_train_final = pca.fit_transform(X_train_scaled)
X_test_final = pca.transform(X_test_scaled)



# === TUNE MODELS USING RANDOMIZED SEARCH ===
tuned_models = {}
param_logs = []

ridge_param_grid = {"alpha": np.logspace(-3, 3, 100)}
ridge_search = RandomizedSearchCV(Ridge(), param_distributions=ridge_param_grid, n_iter=20, cv=3, scoring='r2', random_state=42)
ridge_search.fit(X_train_final, y_train)
tuned_models["Ridge_Tuned"] = ridge_search.best_estimator_
param_logs.append(("Ridge_Tuned", ridge_search.best_params_))

lasso_param_grid = {"alpha": np.logspace(-3, 3, 100), "max_iter": [10000]}
lasso_search = RandomizedSearchCV(Lasso(random_state=42), param_distributions=lasso_param_grid, n_iter=20, cv=3, scoring='r2', random_state=42)
lasso_search.fit(X_train_final, y_train)
tuned_models["Lasso_Tuned"] = lasso_search.best_estimator_
param_logs.append(("Lasso_Tuned", lasso_search.best_params_))

enet_param_grid = {
    "alpha": np.logspace(-3, 3, 50),
    "l1_ratio": np.linspace(0.1, 0.9, 9),
    "max_iter": [10000]
}
enet_search = RandomizedSearchCV(ElasticNet(random_state=42), param_distributions=enet_param_grid, n_iter=30, cv=3, scoring='r2', random_state=42)
enet_search.fit(X_train_final, y_train)
tuned_models["ElasticNet_Tuned"] = enet_search.best_estimator_
param_logs.append(("ElasticNet_Tuned", enet_search.best_params_))

rf_param_grid = {
    "n_estimators": [100, 200, 300],
    "max_depth": [5, 10, 15, None],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "max_features": ["auto", "sqrt", "log2"]
}
rf_search = RandomizedSearchCV(RandomForestRegressor(random_state=42, n_jobs=-1),
                               param_distributions=rf_param_grid,
                               n_iter=30, cv=3, scoring='r2', random_state=42, n_jobs=-1)
rf_search.fit(X_train_final, y_train)
tuned_models["RandomForest_Tuned"] = rf_search.best_estimator_
param_logs.append(("RandomForest_Tuned", rf_search.best_params_))

xgb_param_grid = {
    "n_estimators": [100, 200, 300],
    "max_depth": [3, 6, 10],
    "learning_rate": [0.01, 0.05, 0.1],
    "subsample": [0.7, 0.9, 1.0],
    "colsample_bytree": [0.7, 0.9, 1.0]
}
xgb_search = RandomizedSearchCV(XGBRegressor(random_state=42, verbosity=0, n_jobs=-1),
                                param_distributions=xgb_param_grid,
                                n_iter=30, cv=3, scoring='r2', random_state=42, n_jobs=-1)
xgb_search.fit(X_train_final, y_train)
tuned_models["XGBoost_Tuned"] = xgb_search.best_estimator_
param_logs.append(("XGBoost_Tuned", xgb_search.best_params_))

tuned_models["LinearRegression_Tuned"] = LinearRegression()
param_logs.append(("LinearRegression_Tuned", "No tuning required"))

# === LOG BEST PARAMS ===
param_df = pd.DataFrame(param_logs, columns=["Model", "Best_Params"])
param_df.to_csv(f"{plot_dir}/best_model_hyperparameters.csv", index=False)

# === EVALUATE TUNED MODELS ON TEST ===
results = {}
all_metrics = []
for name, model in tuned_models.items():
    try:
        model.fit(X_train_final, y_train)
        y_test_pred = model.predict(X_test_final)
        r2 = r2_score(y_test, y_test_pred)
        mse = mean_squared_error(y_test, y_test_pred)
        results[name] = r2
        all_metrics.append({"Model": name, "R2_Test": r2, "MSE_Test": mse})
    except Exception as e:
        results[name] = f"Failed: {str(e)}"

metrics_df_all = pd.DataFrame(all_metrics)
metrics_df_all.to_csv(f"{plot_dir}/all_model_test_metrics.csv", index=False)

# === COMPARISON PLOT ===
plt.figure(figsize=(10, 6))
sns.barplot(data=metrics_df_all.sort_values("R2_Test", ascending=False), x="R2_Test", y="Model", palette="viridis")
plt.title("Test R² Score by Model")
plt.xlabel("R² Score")
plt.ylabel("Model")
plt.tight_layout()
plt.savefig(f"{plot_dir}/model_comparison_r2_test.png")
plt.close()

# === SELECT AND RETRAIN BEST MODEL FOR TEST SET ===
best_model_name = max(results, key=lambda k: results[k] if isinstance(results[k], float) else -np.inf)
best_model = tuned_models[best_model_name]
best_model.fit(X_train_final, y_train)
y_test_pred = best_model.predict(X_test_final)

print(f"Best Tuned Model: {best_model_name}")

# === FEATURE IMPORTANCE (if available) ===
# === FEATURE IMPORTANCE (if available) ===
if hasattr(best_model, "feature_importances_"):
    importances = best_model.feature_importances_
    feat_labels = [f"PC{i+1}" for i in range(len(importances))]
    feat_df = pd.DataFrame({"Feature": feat_labels, "Importance": importances})
    feat_df = feat_df.sort_values(by="Importance", ascending=False)
    feat_df.to_csv(f"{plot_dir}/best_model_feature_importances.csv", index=False)

    plt.figure(figsize=(10, 6))
    sns.barplot(data=feat_df, x="Importance", y="Feature", palette="crest")
    plt.title("Feature Importances - Best Model")
    plt.tight_layout()
    plt.savefig(f"{plot_dir}/best_model_feature_importance_plot.png")
    plt.close()




# # === PLOTTING ===
def plot_results(y_true, y_pred):
    residuals = y_true - y_pred
    absolute_errors = np.abs(residuals)

    def save_plot(fig, name):
        fig.tight_layout()
        fig.savefig(f"{plot_dir}/{name}.png")
        plt.close(fig)

    fig, ax = plt.subplots(figsize=(8, 5))
    sns.scatterplot(x=y_pred, y=residuals, ax=ax)
    ax.axhline(0, linestyle='--', color='red')
    ax.set_title("Residuals vs Predicted")
    ax.set_xlabel("Predicted")
    ax.set_ylabel("Residuals")
    save_plot(fig, "residuals_vs_predicted")

    fig, ax = plt.subplots(figsize=(8, 5))
    sns.scatterplot(x=y_true, y=y_pred, ax=ax)
    ax.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], linestyle='--', color='red')
    ax.set_title("Predicted vs Actual")
    ax.set_xlabel("Actual")
    ax.set_ylabel("Predicted")
    save_plot(fig, "predicted_vs_actual")

    fig, ax = plt.subplots(figsize=(8, 5))
    sns.histplot(residuals, bins=30, kde=True, ax=ax)
    ax.set_title("Distribution of Residuals")
    ax.set_xlabel("Residuals")
    save_plot(fig, "residuals_distribution")

    fig, ax = plt.subplots(figsize=(8, 5))
    sorted_errors = np.sort(absolute_errors)
    cum_dist = np.arange(1, len(sorted_errors) + 1) / len(sorted_errors)
    ax.plot(sorted_errors, cum_dist)
    ax.set_title("Cumulative Distribution of Absolute Errors")
    ax.set_xlabel("Absolute Error")
    ax.set_ylabel("Cumulative Proportion")
    save_plot(fig, "cumulative_absolute_errors")

    fig = plt.figure(figsize=(6, 6))
    stats.probplot(residuals, dist="norm", plot=plt)
    plt.title("Q-Q Plot of Residuals")
    save_plot(fig, "qq_plot_residuals")

    fig, ax = plt.subplots(figsize=(8, 5))
    sns.scatterplot(x=y_true, y=absolute_errors, ax=ax)
    ax.set_title("Absolute Error vs Actual Value")
    ax.set_xlabel("Actual Values")
    ax.set_ylabel("Absolute Error")
    save_plot(fig, "absolute_error_vs_actual")

plot_results(y_test, y_test_pred)

# === PRINT FINAL TEST METRICS ===
r2 = r2_score(y_test, y_test_pred)
mse = mean_squared_error(y_test, y_test_pred)
print(f"Test R² Score: {r2:.4f}")
print(f"Test Mean Squared Error: {mse:.4f}")

pred_df = pd.DataFrame({
    "True": y_test,
    "Predicted": y_test_pred
})
pred_df.to_csv(f"{plot_dir}/best_model_predictions.csv", index=False)
# Out:
# /home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 30 fits failed out of a total of 90.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "/home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "/home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [0.11712322 0.2935139  0.28177571        nan        nan 0.13147428
#  0.29169481 0.29555719        nan 0.19564033        nan        nan
#  0.20949597 0.20200623        nan 0.28389366 0.10118503 0.28082853
#         nan        nan 0.20805401 0.26380155 0.1263538         nan
#         nan 0.12260737 0.11385329 0.11863305 0.20563074 0.11702907]
#   warnings.warn(
# /tmp/ipykernel_679803/3868762660.py:135: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=metrics_df_all.sort_values("R2_Test", ascending=False), x="R2_Test", y="Model", palette="viridis")
# Best Tuned Model: RandomForest_Tuned
# /tmp/ipykernel_679803/3868762660.py:161: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=feat_df, x="Importance", y="Feature", palette="crest")
# Test R² Score: 0.2856
# Test Mean Squared Error: 91.1628

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_squared_error
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import os

# === CONFIGURATION ===
input_path = "/home/MinaHossain/EmbedTrack/Track_HP4_Result_Shape/Mean/Cells_Centroid_Velocity_TrueLabel_MA_Mean_5.csv"
output_root = "/home/MinaHossain/EmbedTrack/Track_HP4_Result_Shape/Mean"
plot_dir = f"{output_root}/Reg_Results"
os.makedirs(plot_dir, exist_ok=True)

# === LOAD AND CLEAN DATA ===
df = pd.read_csv(input_path)
collinear_features = ['Area_MA', 'Perimeter_MA', 'Solidity_MA', 'Extent_MA',
                      'Circularity_MA', 'Convexity_MA', 'Elongation_MA', 'Compactness_MA']
target_col = 'X_Centroid_Velocity_MA'
df_clean = df[collinear_features + [target_col]].dropna()
X_collinear = df_clean[collinear_features].values
y = df_clean[target_col].values

# === SPLIT DATA (Train/Test Only) ===
X_train, X_test, y_train, y_test = train_test_split(X_collinear, y, test_size=0.2, random_state=42)

# === PCA ON TRAIN ===
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

pca = PCA(n_components=5)
X_train_final = pca.fit_transform(X_train_scaled)
X_test_final = pca.transform(X_test_scaled)

# === TUNE MODELS USING RANDOMIZED SEARCH ===
tuned_models = {}
param_logs = []

ridge_param_grid = {"alpha": np.logspace(-3, 3, 100)}
ridge_search = RandomizedSearchCV(Ridge(), param_distributions=ridge_param_grid, n_iter=20, cv=3, scoring='r2', random_state=42)
ridge_search.fit(X_train_final, y_train)
tuned_models["Ridge_Tuned"] = ridge_search.best_estimator_
param_logs.append(("Ridge_Tuned", ridge_search.best_params_))

lasso_param_grid = {"alpha": np.logspace(-3, 3, 100), "max_iter": [10000]}
lasso_search = RandomizedSearchCV(Lasso(random_state=42), param_distributions=lasso_param_grid, n_iter=20, cv=3, scoring='r2', random_state=42)
lasso_search.fit(X_train_final, y_train)
tuned_models["Lasso_Tuned"] = lasso_search.best_estimator_
param_logs.append(("Lasso_Tuned", lasso_search.best_params_))

enet_param_grid = {
    "alpha": np.logspace(-3, 3, 50),
    "l1_ratio": np.linspace(0.1, 0.9, 9),
    "max_iter": [10000]
}
enet_search = RandomizedSearchCV(ElasticNet(random_state=42), param_distributions=enet_param_grid, n_iter=30, cv=3, scoring='r2', random_state=42)
enet_search.fit(X_train_final, y_train)
tuned_models["ElasticNet_Tuned"] = enet_search.best_estimator_
param_logs.append(("ElasticNet_Tuned", enet_search.best_params_))

rf_param_grid = {
    "n_estimators": [100, 200, 300],
    "max_depth": [5, 10, 15, None],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "max_features": ["auto", "sqrt", "log2"]
}
rf_search = RandomizedSearchCV(RandomForestRegressor(random_state=42, n_jobs=-1),
                               param_distributions=rf_param_grid,
                               n_iter=30, cv=3, scoring='r2', random_state=42, n_jobs=-1)
rf_search.fit(X_train_final, y_train)
tuned_models["RandomForest_Tuned"] = rf_search.best_estimator_
param_logs.append(("RandomForest_Tuned", rf_search.best_params_))

xgb_param_grid = {
    "n_estimators": [100, 200, 300],
    "max_depth": [3, 6, 10],
    "learning_rate": [0.01, 0.05, 0.1],
    "subsample": [0.7, 0.9, 1.0],
    "colsample_bytree": [0.7, 0.9, 1.0]
}
xgb_search = RandomizedSearchCV(XGBRegressor(random_state=42, verbosity=0, n_jobs=-1),
                                param_distributions=xgb_param_grid,
                                n_iter=30, cv=3, scoring='r2', random_state=42, n_jobs=-1)
xgb_search.fit(X_train_final, y_train)
tuned_models["XGBoost_Tuned"] = xgb_search.best_estimator_
param_logs.append(("XGBoost_Tuned", xgb_search.best_params_))

tuned_models["LinearRegression_Tuned"] = LinearRegression()
param_logs.append(("LinearRegression_Tuned", "No tuning required"))

# === LOG BEST PARAMS ===
param_df = pd.DataFrame(param_logs, columns=["Model", "Best_Params"])
param_df.to_csv(f"{plot_dir}/best_model_hyperparameters.csv", index=False)

# === EVALUATE TUNED MODELS ON TEST ===
results = {}
all_metrics = []
for name, model in tuned_models.items():
    try:
        model.fit(X_train_final, y_train)
        y_test_pred = model.predict(X_test_final)
        r2 = r2_score(y_test, y_test_pred)
        mse = mean_squared_error(y_test, y_test_pred)
        results[name] = r2
        all_metrics.append({"Model": name, "R2_Test": r2, "MSE_Test": mse})
    except Exception as e:
        results[name] = f"Failed: {str(e)}"

metrics_df_all = pd.DataFrame(all_metrics)
metrics_df_all.to_csv(f"{plot_dir}/all_model_test_metrics.csv", index=False)

# === COMPARISON PLOT ===
plt.figure(figsize=(10, 6))
sns.barplot(data=metrics_df_all.sort_values("R2_Test", ascending=False), x="R2_Test", y="Model", palette="viridis")
plt.title("Test R² Score by Model")
plt.xlabel("R² Score")
plt.ylabel("Model")
plt.tight_layout()
plt.savefig(f"{plot_dir}/model_comparison_r2_test.png")
plt.close()

# === SELECT AND RETRAIN BEST MODEL FOR TEST SET ===
best_model_name = max(results, key=lambda k: results[k] if isinstance(results[k], float) else -np.inf)
best_model = tuned_models[best_model_name]
best_model.fit(X_train_final, y_train)
y_test_pred = best_model.predict(X_test_final)

print(f"Best Tuned Model: {best_model_name}")

# === FUNCTION: COLLECT FEATURE IMPORTANCES ===
def get_feature_importance_df(model, model_name, feature_names):
    if hasattr(model, "feature_importances_"):
        importances = model.feature_importances_
        return pd.DataFrame({"Model": model_name, "Feature": feature_names, "Importance": importances})
    return None

# === COLLECT AND PLOT ALL FEATURE IMPORTANCES ===
feature_names = [f"PC{i+1}" for i in range(X_train_final.shape[1])]
importance_dfs = []

for name, model in tuned_models.items():
    imp_df = get_feature_importance_df(model, name, feature_names)
    if imp_df is not None:
        importance_dfs.append(imp_df)

if importance_dfs:
    combined_df = pd.concat(importance_dfs)
    combined_df.to_csv(f"{plot_dir}/all_models_feature_importances.csv", index=False)

    # Barplot comparison
    plt.figure(figsize=(12, 6))
    sns.barplot(data=combined_df, x="Importance", y="Feature", hue="Model", dodge=True)
    plt.title("Feature Importances by Model")
    plt.tight_layout()
    plt.savefig(f"{plot_dir}/feature_importances_by_model_barplot.png")
    plt.close()

    # Heatmap comparison
    pivot_df = combined_df.pivot(index="Feature", columns="Model", values="Importance").fillna(0)
    plt.figure(figsize=(10, 6))
    sns.heatmap(pivot_df, annot=True, cmap="YlGnBu", fmt=".2f")
    plt.title("Feature Importances Heatmap Across Models")
    plt.tight_layout()
    plt.savefig(f"{plot_dir}/feature_importances_by_model_heatmap.png")
    plt.close()




# # === PLOTTING ===
def plot_results(y_true, y_pred):
    residuals = y_true - y_pred
    absolute_errors = np.abs(residuals)

    def save_plot(fig, name):
        fig.tight_layout()
        fig.savefig(f"{plot_dir}/{name}.png")
        plt.close(fig)

    fig, ax = plt.subplots(figsize=(8, 5))
    sns.scatterplot(x=y_pred, y=residuals, ax=ax)
    ax.axhline(0, linestyle='--', color='red')
    ax.set_title("Residuals vs Predicted")
    ax.set_xlabel("Predicted")
    ax.set_ylabel("Residuals")
    save_plot(fig, "residuals_vs_predicted")

    fig, ax = plt.subplots(figsize=(8, 5))
    sns.scatterplot(x=y_true, y=y_pred, ax=ax)
    ax.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], linestyle='--', color='red')
    ax.set_title("Predicted vs Actual")
    ax.set_xlabel("Actual")
    ax.set_ylabel("Predicted")
    save_plot(fig, "predicted_vs_actual")

    fig, ax = plt.subplots(figsize=(8, 5))
    sns.histplot(residuals, bins=30, kde=True, ax=ax)
    ax.set_title("Distribution of Residuals")
    ax.set_xlabel("Residuals")
    save_plot(fig, "residuals_distribution")

    fig, ax = plt.subplots(figsize=(8, 5))
    sorted_errors = np.sort(absolute_errors)
    cum_dist = np.arange(1, len(sorted_errors) + 1) / len(sorted_errors)
    ax.plot(sorted_errors, cum_dist)
    ax.set_title("Cumulative Distribution of Absolute Errors")
    ax.set_xlabel("Absolute Error")
    ax.set_ylabel("Cumulative Proportion")
    save_plot(fig, "cumulative_absolute_errors")

    fig = plt.figure(figsize=(6, 6))
    stats.probplot(residuals, dist="norm", plot=plt)
    plt.title("Q-Q Plot of Residuals")
    save_plot(fig, "qq_plot_residuals")

    fig, ax = plt.subplots(figsize=(8, 5))
    sns.scatterplot(x=y_true, y=absolute_errors, ax=ax)
    ax.set_title("Absolute Error vs Actual Value")
    ax.set_xlabel("Actual Values")
    ax.set_ylabel("Absolute Error")
    save_plot(fig, "absolute_error_vs_actual")

plot_results(y_test, y_test_pred)

# === PRINT FINAL TEST METRICS ===
r2 = r2_score(y_test, y_test_pred)
mse = mean_squared_error(y_test, y_test_pred)
print(f"Test R² Score: {r2:.4f}")
print(f"Test Mean Squared Error: {mse:.4f}")

pred_df = pd.DataFrame({
    "True": y_test,
    "Predicted": y_test_pred
})
pred_df.to_csv(f"{plot_dir}/best_model_predictions.csv", index=False)
# Out:
# /home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 30 fits failed out of a total of 90.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 17 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "/home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 13 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "/home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/MinaHossain/anaconda3/envs/Shp_chc/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [0.11712322 0.2935139  0.28177571        nan        nan 0.13147428
#  0.29169481 0.29555719        nan 0.19564033        nan        nan
#  0.20949597 0.20200623        nan 0.28389366 0.10118503 0.28082853
#         nan        nan 0.20805401 0.26380155 0.1263538         nan
#         nan 0.12260737 0.11385329 0.11863305 0.20563074 0.11702907]
#   warnings.warn(
# /tmp/ipykernel_679803/769988914.py:122: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=metrics_df_all.sort_values("R2_Test", ascending=False), x="R2_Test", y="Model", palette="viridis")
# Best Tuned Model: RandomForest_Tuned
# Test R² Score: 0.2856
# Test Mean Squared Error: 91.1628

# %% [markdown]
# # Create the updated FNN pipeline script content with PCA + spatial features + grid search

# %%
import os
import argparse
import datetime
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset
from itertools import product

# --- CONFIG ---
output_root = "/home/MinaHossain/EmbedTrack/Track_HP4_Result_Shape/Mean/Reg_Analysis_FNN_PCA"
os.makedirs(f"{output_root}/models", exist_ok=True)
os.makedirs(f"{output_root}/results", exist_ok=True)
os.makedirs(f"{output_root}/plots", exist_ok=True)

# --- FNN Model ---
class FNN(nn.Module):
    def __init__(self, input_size, hidden_sizes):
        super(FNN, self).__init__()
        layers = [nn.Linear(input_size, hidden_sizes[0]), nn.ReLU()]
        for i in range(1, len(hidden_sizes)):
            layers.append(nn.Linear(hidden_sizes[i-1], hidden_sizes[i]))
            layers.append(nn.ReLU())
        layers.append(nn.Linear(hidden_sizes[-1], 1))
        self.model = nn.Sequential(*layers)

    def forward(self, x):
        return self.model(x)

# --- Evaluation ---
def evaluate_model(model, X_test_tensor, y_test_tensor):
    model.eval()
    with torch.no_grad():
        y_pred_tensor = model(X_test_tensor)
    y_pred = y_pred_tensor.cpu().numpy().flatten()
    y_true = y_test_tensor.cpu().numpy().flatten()
    mse = mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"✅ MSE: {mse:.4f} | R²: {r2:.4f}")
    return mse, r2, y_true, y_pred

# --- Plotting ---
def plot_results(y_true, y_pred, train_losses=None):
    residuals = y_true - y_pred
    if train_losses:
        plt.figure(); plt.plot(train_losses); plt.title("Training Loss"); plt.tight_layout()
        plt.savefig(f"{output_root}/plots/loss_curve.png"); plt.close()
    plt.figure(); sns.scatterplot(x=y_pred, y=residuals); plt.axhline(0, linestyle='--', color='red')
    plt.title("Residuals vs Predicted"); plt.tight_layout()
    plt.savefig(f"{output_root}/plots/residuals_vs_predicted.png"); plt.close()
    plt.figure(); sns.scatterplot(x=y_true, y=y_pred); plt.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], 'r--')
    plt.title("Predicted vs Actual"); plt.tight_layout()
    plt.savefig(f"{output_root}/plots/predicted_vs_actual.png"); plt.close()
    plt.figure(); sns.histplot(residuals, bins=30, kde=True)
    plt.title("Distribution of Residuals"); plt.tight_layout()
    plt.savefig(f"{output_root}/plots/residuals_distribution.png"); plt.close()
    plt.figure(); plt.plot(np.sort(np.abs(residuals)), np.linspace(0, 1, len(residuals)))
    plt.title("Cumulative Absolute Errors"); plt.tight_layout()
    plt.savefig(f"{output_root}/plots/cumulative_absolute_errors.png"); plt.close()
    plt.figure(); stats.probplot(residuals, dist="norm", plot=plt)
    plt.title("Q-Q Plot"); plt.tight_layout()
    plt.savefig(f"{output_root}/plots/qq_plot_residuals.png"); plt.close()
    plt.figure(); sns.scatterplot(x=y_true, y=np.abs(residuals))
    plt.title("Absolute Error vs Actual"); plt.tight_layout()
    plt.savefig(f"{output_root}/plots/absolute_error_vs_actual.png"); plt.close()

# --- Run FNN ---
def run_fnn(X_train, X_val, X_test, y_train, y_val, y_test, input_size, hidden_sizes, lr, batch_size, epochs):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = FNN(input_size=input_size, hidden_sizes=hidden_sizes).to(device)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)

    X_train_tensor = torch.tensor(X_train).float().to(device)
    y_train_tensor = torch.tensor(y_train).float().to(device)
    X_val_tensor = torch.tensor(X_val).float().to(device)
    y_val_tensor = torch.tensor(y_val).float().to(device)
    X_test_tensor = torch.tensor(X_test).float().to(device)
    y_test_tensor = torch.tensor(y_test).float().to(device)

    train_loader = DataLoader(TensorDataset(X_train_tensor, y_train_tensor), batch_size=batch_size, shuffle=True)

    train_losses = []
    for epoch in range(epochs):
        model.train()
        total_loss = 0
        for xb, yb in train_loader:
            optimizer.zero_grad()
            pred = model(xb)
            loss = criterion(pred, yb)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        train_losses.append(total_loss / len(train_loader))
        if (epoch + 1) % 10 == 0:
            print(f"Epoch {epoch+1}: Loss={train_losses[-1]:.4f}")

    return model, train_losses, X_test_tensor, y_test_tensor

# --- Grid Search ---
def grid_search_fnn(csv_path, param_grid):
    df = pd.read_csv(csv_path)
    shape_features = ['Area_MA', 'Perimeter_MA', 'Extent_MA', 'Solidity_MA', 'Compactness_MA', 'Elongation_MA', 'Circularity_MA', 'Convexity_MA']
    spatial_features = ['Centroid_X_MA', 'Centroid_Y_MA', 'X_Centroid_Distance_MA', 'Y_Centroid_Distance_MA']
    target = 'X_Centroid_Velocity_MA'
    df = df.dropna(subset=shape_features + spatial_features + [target])

    X_shape = df[shape_features].values
    X_spatial = df[spatial_features].values
    y = df[target].values.reshape(-1, 1)

    X_shape_scaled = StandardScaler().fit_transform(X_shape)
    X_train_s, X_temp_s, X_train_spatial, X_temp_spatial, y_train, y_temp = train_test_split(
        X_shape_scaled, X_spatial, y, test_size=0.4, random_state=42)
    X_val_s, X_test_s, X_val_spatial, X_test_spatial, y_val, y_test = train_test_split(
        X_temp_s, X_temp_spatial, y_temp, test_size=0.5, random_state=42)

    # PCA
    pca = PCA(n_components=0.95)
    X_train_pca = pca.fit_transform(X_train_s)
    X_val_pca = pca.transform(X_val_s)
    X_test_pca = pca.transform(X_test_s)

    # Combine PCA + spatial
    X_train_final = np.hstack([X_train_pca, X_train_spatial])
    X_val_final = np.hstack([X_val_pca, X_val_spatial])
    X_test_final = np.hstack([X_test_pca, X_test_spatial])

    results = []
    best_r2 = -np.inf
    best_model = None
    best_config = None
    best_losses = None
    best_test_tensors = None

    for lr, batch_size, hidden_sizes, epochs in product(param_grid["lr"], param_grid["batch_size"],
                                                        param_grid["hidden_sizes"], param_grid["epochs"]):
        print(f"▶ Training: lr={lr}, batch={batch_size}, hidden={hidden_sizes}, epochs={epochs}")
        model, train_losses, X_test_tensor, y_test_tensor = run_fnn(
            X_train_final, X_val_final, X_test_final,
            y_train, y_val, y_test,
            input_size=X_train_final.shape[1],
            hidden_sizes=hidden_sizes,
            lr=lr,
            batch_size=batch_size,
            epochs=epochs
        )
        mse, r2, y_true, y_pred = evaluate_model(model, X_test_tensor, y_test_tensor)

        results.append({
            "lr": lr, "batch_size": batch_size, "hidden_sizes": str(hidden_sizes),
            "epochs": epochs, "mse": mse, "r2": r2
        })

        if r2 > best_r2:
            best_r2 = r2
            best_model = model
            best_config = {
                "lr": lr, "batch_size": batch_size,
                "hidden_sizes": hidden_sizes, "epochs": epochs
            }
            best_losses = train_losses
            best_test_tensors = (X_test_tensor, y_test_tensor, y_true, y_pred)

    # Save best model
    model_path = f"{output_root}/models/fnn_best_model.pt"
    torch.save(best_model.state_dict(), model_path)

    pd.DataFrame(results).to_csv(f"{output_root}/results/grid_search_results.csv", index=False)
    print(f"🏆 Best config: {best_config}, R²={best_r2:.4f}")
    return best_model, best_config, best_losses, best_test_tensors

# --- Entry Point ---
if __name__ == "__main__":
    param_grid = {
        "lr": [0.001, 0.0005],
        "batch_size": [16, 32],
        "hidden_sizes": [(128, 64, 32), (64, 32, 16),(64,32,16,8)],
        "epochs": [100, 200]
    }
    csv_path = "/home/MinaHossain/EmbedTrack/Track_HP4_Result_Shape/Mean/Cells_Centroid_Velocity_TrueLabel_MA_Mean_5.csv"
    best_model, best_config, best_losses, (X_test_tensor, y_test_tensor, y_true, y_pred) = grid_search_fnn(csv_path, param_grid)
    plot_results(y_true, y_pred, train_losses=best_losses)
# Out:
# ▶ Training: lr=0.001, batch=16, hidden=(128, 64, 32), epochs=100
# Epoch 10: Loss=159.1789
# Epoch 20: Loss=82.5358
# Epoch 30: Loss=2.4484
# Epoch 40: Loss=2.7489
# Epoch 50: Loss=0.9089
# Epoch 60: Loss=1.0584
# Epoch 70: Loss=0.5403
# Epoch 80: Loss=0.1862
# Epoch 90: Loss=0.9635
# Epoch 100: Loss=0.5307
# ✅ MSE: 0.7948 | R²: 0.9878
# ▶ Training: lr=0.001, batch=16, hidden=(128, 64, 32), epochs=200
# Epoch 10: Loss=164.2653
# Epoch 20: Loss=100.4026
# Epoch 30: Loss=1.6674
# Epoch 40: Loss=0.8581
# Epoch 50: Loss=1.6793
# Epoch 60: Loss=0.5309
# Epoch 70: Loss=0.4413
# Epoch 80: Loss=2.4693
# Epoch 90: Loss=0.3537
# Epoch 100: Loss=0.3338
# Epoch 110: Loss=8.8898
# Epoch 120: Loss=1.9489
# Epoch 130: Loss=0.1367
# Epoch 140: Loss=1.7793
# Epoch 150: Loss=0.1536
# Epoch 160: Loss=0.0949
# Epoch 170: Loss=0.2549
# Epoch 180: Loss=3.0203
# Epoch 190: Loss=0.0862
# Epoch 200: Loss=0.7024
# ✅ MSE: 0.2598 | R²: 0.9960
# ▶ Training: lr=0.001, batch=16, hidden=(64, 32, 16), epochs=100
# Epoch 10: Loss=181.2662
# Epoch 20: Loss=158.0000
# Epoch 30: Loss=106.2025
# Epoch 40: Loss=8.5681
# Epoch 50: Loss=1.2027
# Epoch 60: Loss=1.1735
# Epoch 70: Loss=1.0291
# Epoch 80: Loss=0.3828
# Epoch 90: Loss=1.3335
# Epoch 100: Loss=0.4588
# ✅ MSE: 0.3486 | R²: 0.9946
# ▶ Training: lr=0.001, batch=16, hidden=(64, 32, 16), epochs=200
# Epoch 10: Loss=168.3102
# Epoch 20: Loss=133.8221
# Epoch 30: Loss=23.5468
# Epoch 40: Loss=3.6632
# Epoch 50: Loss=1.0825
# Epoch 60: Loss=0.7980
# Epoch 70: Loss=0.9190
# Epoch 80: Loss=0.6826
# Epoch 90: Loss=0.5942
# Epoch 100: Loss=0.5924
# Epoch 110: Loss=0.3728
# Epoch 120: Loss=0.3972
# Epoch 130: Loss=0.1933
# Epoch 140: Loss=0.2357
# Epoch 150: Loss=0.4179
# Epoch 160: Loss=0.3214
# Epoch 170: Loss=0.1157
# Epoch 180: Loss=0.3861
# Epoch 190: Loss=4.9675
# Epoch 200: Loss=0.2415
# ✅ MSE: 0.1618 | R²: 0.9975
# ▶ Training: lr=0.001, batch=16, hidden=(64, 32, 16, 8), epochs=100
# Epoch 10: Loss=168.4905
# Epoch 20: Loss=147.8649
# Epoch 30: Loss=2.1277
# Epoch 40: Loss=1.3518
# Epoch 50: Loss=0.8725
# Epoch 60: Loss=0.5819
# Epoch 70: Loss=0.5078
# Epoch 80: Loss=0.2526
# Epoch 90: Loss=0.2651
# Epoch 100: Loss=2.0758
# ✅ MSE: 0.2270 | R²: 0.9965
# ▶ Training: lr=0.001, batch=16, hidden=(64, 32, 16, 8), epochs=200
# Epoch 10: Loss=169.5216
# Epoch 20: Loss=155.5447
# Epoch 30: Loss=2.4319
# Epoch 40: Loss=2.7283
# Epoch 50: Loss=1.1595
# Epoch 60: Loss=0.6299
# Epoch 70: Loss=0.4006
# Epoch 80: Loss=0.7418
# Epoch 90: Loss=0.1690
# Epoch 100: Loss=0.2684
# Epoch 110: Loss=0.4862
# Epoch 120: Loss=1.3685
# Epoch 130: Loss=0.6630
# Epoch 140: Loss=0.0955
# Epoch 150: Loss=0.1786
# Epoch 160: Loss=0.6370
# Epoch 170: Loss=0.0878
# Epoch 180: Loss=0.1585
# Epoch 190: Loss=0.0672
# Epoch 200: Loss=0.1167
# ✅ MSE: 0.1402 | R²: 0.9978
# ▶ Training: lr=0.001, batch=32, hidden=(128, 64, 32), epochs=100
# Epoch 10: Loss=164.3123
# Epoch 20: Loss=148.5657
# Epoch 30: Loss=131.3759
# Epoch 40: Loss=13.9623
# Epoch 50: Loss=1.5059
# Epoch 60: Loss=1.9081
# Epoch 70: Loss=1.2869
# Epoch 80: Loss=0.7680
# Epoch 90: Loss=0.8914
# Epoch 100: Loss=0.4897
# ✅ MSE: 0.7193 | R²: 0.9889
# ▶ Training: lr=0.001, batch=32, hidden=(128, 64, 32), epochs=200
# Epoch 10: Loss=143.9626
# Epoch 20: Loss=102.2973
# Epoch 30: Loss=13.3437
# Epoch 40: Loss=5.2093
# Epoch 50: Loss=1.7220
# Epoch 60: Loss=0.7866
# Epoch 70: Loss=0.4136
# Epoch 80: Loss=1.0007
# Epoch 90: Loss=1.4098
# Epoch 100: Loss=0.6066
# Epoch 110: Loss=0.3310
# Epoch 120: Loss=3.6352
# Epoch 130: Loss=2.8064
# Epoch 140: Loss=1.2282
# Epoch 150: Loss=0.4980
# Epoch 160: Loss=5.4435
# Epoch 170: Loss=0.5352
# Epoch 180: Loss=0.4092
# Epoch 190: Loss=0.2636
# Epoch 200: Loss=0.3552
# ✅ MSE: 0.2270 | R²: 0.9965
# ▶ Training: lr=0.001, batch=32, hidden=(64, 32, 16), epochs=100
# Epoch 10: Loss=167.2077
# Epoch 20: Loss=137.8770
# Epoch 30: Loss=51.2647
# Epoch 40: Loss=4.3247
# Epoch 50: Loss=1.2094
# Epoch 60: Loss=0.7016
# Epoch 70: Loss=0.5251
# Epoch 80: Loss=0.3921
# Epoch 90: Loss=0.4751
# Epoch 100: Loss=0.2853
# ✅ MSE: 0.3261 | R²: 0.9950
# ▶ Training: lr=0.001, batch=32, hidden=(64, 32, 16), epochs=200
# Epoch 10: Loss=174.4988
# Epoch 20: Loss=159.0072
# Epoch 30: Loss=138.3429
# Epoch 40: Loss=73.0928
# Epoch 50: Loss=3.8976
# Epoch 60: Loss=1.5305
# Epoch 70: Loss=0.3187
# Epoch 80: Loss=0.6797
# Epoch 90: Loss=0.5689
# Epoch 100: Loss=0.4185
# Epoch 110: Loss=0.2883
# Epoch 120: Loss=0.2515
# Epoch 130: Loss=0.1987
# Epoch 140: Loss=0.1170
# Epoch 150: Loss=0.1571
# Epoch 160: Loss=0.1291
# Epoch 170: Loss=0.1636
# Epoch 180: Loss=0.1023
# Epoch 190: Loss=0.1848
# Epoch 200: Loss=0.2909
# ✅ MSE: 0.1630 | R²: 0.9975
# ▶ Training: lr=0.001, batch=32, hidden=(64, 32, 16, 8), epochs=100
# Epoch 10: Loss=169.9234
# Epoch 20: Loss=153.6866
# Epoch 30: Loss=126.5585
# Epoch 40: Loss=5.3985
# Epoch 50: Loss=2.1881
# Epoch 60: Loss=0.6077
# Epoch 70: Loss=0.6051
# Epoch 80: Loss=0.4716
# Epoch 90: Loss=1.9484
# Epoch 100: Loss=3.4862
# ✅ MSE: 5.8498 | R²: 0.9100
# ▶ Training: lr=0.001, batch=32, hidden=(64, 32, 16, 8), epochs=200
# Epoch 10: Loss=171.7348
# Epoch 20: Loss=171.6657
# Epoch 30: Loss=171.5300
# Epoch 40: Loss=171.5500
# Epoch 50: Loss=171.3080
# Epoch 60: Loss=170.9265
# Epoch 70: Loss=168.2191
# Epoch 80: Loss=146.8724
# Epoch 90: Loss=20.6691
# Epoch 100: Loss=1.1243
# Epoch 110: Loss=0.9867
# Epoch 120: Loss=0.3550
# Epoch 130: Loss=0.6474
# Epoch 140: Loss=0.3747
# Epoch 150: Loss=0.4555
# Epoch 160: Loss=0.2730
# Epoch 170: Loss=0.2553
# Epoch 180: Loss=0.2136
# Epoch 190: Loss=0.2158
# Epoch 200: Loss=0.1882
# ✅ MSE: 0.3216 | R²: 0.9951
# ▶ Training: lr=0.0005, batch=16, hidden=(128, 64, 32), epochs=100
# Epoch 10: Loss=178.1250
# Epoch 20: Loss=136.5337
# Epoch 30: Loss=81.3477
# Epoch 40: Loss=13.8687
# Epoch 50: Loss=2.3760
# Epoch 60: Loss=1.0328
# Epoch 70: Loss=1.4811
# Epoch 80: Loss=0.5714
# Epoch 90: Loss=1.0362
# Epoch 100: Loss=0.2371
# ✅ MSE: 0.3215 | R²: 0.9951
# ▶ Training: lr=0.0005, batch=16, hidden=(128, 64, 32), epochs=200
# Epoch 10: Loss=166.7685
# Epoch 20: Loss=147.2789
# Epoch 30: Loss=116.6588
# Epoch 40: Loss=39.6019
# Epoch 50: Loss=2.0325
# Epoch 60: Loss=0.7178
# Epoch 70: Loss=0.4647
# Epoch 80: Loss=0.7044
# Epoch 90: Loss=0.7514
# Epoch 100: Loss=0.5724
# Epoch 110: Loss=1.3052
# Epoch 120: Loss=0.4347
# Epoch 130: Loss=0.8684
# Epoch 140: Loss=0.3657
# Epoch 150: Loss=3.8759
# Epoch 160: Loss=0.1944
# Epoch 170: Loss=1.8738
# Epoch 180: Loss=0.3688
# Epoch 190: Loss=0.1491
# Epoch 200: Loss=0.3770
# ✅ MSE: 0.2687 | R²: 0.9959
# ▶ Training: lr=0.0005, batch=16, hidden=(64, 32, 16), epochs=100
# Epoch 10: Loss=172.3308
# Epoch 20: Loss=150.0951
# Epoch 30: Loss=153.3709
# Epoch 40: Loss=78.8235
# Epoch 50: Loss=17.6260
# Epoch 60: Loss=2.5146
# Epoch 70: Loss=2.2867
# Epoch 80: Loss=1.8717
# Epoch 90: Loss=2.1267
# Epoch 100: Loss=0.9466
# ✅ MSE: 1.3354 | R²: 0.9795
# ▶ Training: lr=0.0005, batch=16, hidden=(64, 32, 16), epochs=200
# Epoch 10: Loss=165.4997
# Epoch 20: Loss=146.0396
# Epoch 30: Loss=118.6073
# Epoch 40: Loss=68.3469
# Epoch 50: Loss=30.7078
# Epoch 60: Loss=4.6599
# Epoch 70: Loss=2.3092
# Epoch 80: Loss=1.4771
# Epoch 90: Loss=1.4088
# Epoch 100: Loss=1.1219
# Epoch 110: Loss=0.7874
# Epoch 120: Loss=0.7894
# Epoch 130: Loss=0.6436
# Epoch 140: Loss=0.5505
# Epoch 150: Loss=2.4534
# Epoch 160: Loss=0.4474
# Epoch 170: Loss=0.5925
# Epoch 180: Loss=0.6372
# Epoch 190: Loss=0.5798
# Epoch 200: Loss=0.3489
# ✅ MSE: 0.1387 | R²: 0.9979
# ▶ Training: lr=0.0005, batch=16, hidden=(64, 32, 16, 8), epochs=100
# Epoch 10: Loss=169.0716
# Epoch 20: Loss=164.5336
# Epoch 30: Loss=160.6737
# Epoch 40: Loss=70.3418
# Epoch 50: Loss=2.2242
# Epoch 60: Loss=1.0650
# Epoch 70: Loss=1.6571
# Epoch 80: Loss=0.5529
# Epoch 90: Loss=1.2144
# Epoch 100: Loss=0.5236
# ✅ MSE: 0.4760 | R²: 0.9927
# ▶ Training: lr=0.0005, batch=16, hidden=(64, 32, 16, 8), epochs=200
# Epoch 10: Loss=168.3408
# Epoch 20: Loss=161.1139
# Epoch 30: Loss=146.5190
# Epoch 40: Loss=76.8784
# Epoch 50: Loss=5.9143
# Epoch 60: Loss=3.1784
# Epoch 70: Loss=1.1430
# Epoch 80: Loss=0.9883
# Epoch 90: Loss=0.7873
# Epoch 100: Loss=1.1480
# Epoch 110: Loss=0.6123
# Epoch 120: Loss=0.6738
# Epoch 130: Loss=1.1354
# Epoch 140: Loss=1.2492
# Epoch 150: Loss=0.2988
# Epoch 160: Loss=0.3704
# Epoch 170: Loss=0.3214
# Epoch 180: Loss=0.5245
# Epoch 190: Loss=0.4585
# Epoch 200: Loss=0.5187
# ✅ MSE: 0.3569 | R²: 0.9945
# ▶ Training: lr=0.0005, batch=32, hidden=(128, 64, 32), epochs=100
# Epoch 10: Loss=163.0233
# Epoch 20: Loss=159.1987
# Epoch 30: Loss=113.1478
# Epoch 40: Loss=53.2256
# Epoch 50: Loss=5.7610
# Epoch 60: Loss=0.9554
# Epoch 70: Loss=0.6987
# Epoch 80: Loss=0.6102
# Epoch 90: Loss=0.3327
# Epoch 100: Loss=0.6590
# ✅ MSE: 0.7334 | R²: 0.9887
# ▶ Training: lr=0.0005, batch=32, hidden=(128, 64, 32), epochs=200
# Epoch 10: Loss=162.3549
# Epoch 20: Loss=160.2750
# Epoch 30: Loss=121.5456
# Epoch 40: Loss=83.0607
# Epoch 50: Loss=26.3954
# Epoch 60: Loss=5.4416
# Epoch 70: Loss=0.8847
# Epoch 80: Loss=1.2665
# Epoch 90: Loss=1.0398
# Epoch 100: Loss=0.4710
# Epoch 110: Loss=0.6345
# Epoch 120: Loss=0.3340
# Epoch 130: Loss=0.5958
# Epoch 140: Loss=0.2620
# Epoch 150: Loss=0.3033
# Epoch 160: Loss=0.2500
# Epoch 170: Loss=0.9788
# Epoch 180: Loss=0.1736
# Epoch 190: Loss=0.4443
# Epoch 200: Loss=0.3480
# ✅ MSE: 0.6290 | R²: 0.9903
# ▶ Training: lr=0.0005, batch=32, hidden=(64, 32, 16), epochs=100
# Epoch 10: Loss=178.9092
# Epoch 20: Loss=164.3499
# Epoch 30: Loss=148.5781
# Epoch 40: Loss=124.8082
# Epoch 50: Loss=78.0380
# Epoch 60: Loss=20.5284
# Epoch 70: Loss=3.6774
# Epoch 80: Loss=2.5036
# Epoch 90: Loss=1.5200
# Epoch 100: Loss=1.1329
# ✅ MSE: 0.6701 | R²: 0.9897
# ▶ Training: lr=0.0005, batch=32, hidden=(64, 32, 16), epochs=200
# Epoch 10: Loss=169.7692
# Epoch 20: Loss=148.1413
# Epoch 30: Loss=129.6772
# Epoch 40: Loss=75.7795
# Epoch 50: Loss=28.1175
# Epoch 60: Loss=7.4844
# Epoch 70: Loss=4.0274
# Epoch 80: Loss=1.5380
# Epoch 90: Loss=0.8706
# Epoch 100: Loss=0.5779
# Epoch 110: Loss=0.5121
# Epoch 120: Loss=0.3504
# Epoch 130: Loss=0.3825
# Epoch 140: Loss=0.3226
# Epoch 150: Loss=0.4404
# Epoch 160: Loss=0.3961
# Epoch 170: Loss=0.2351
# Epoch 180: Loss=0.3481
# Epoch 190: Loss=0.1664
# Epoch 200: Loss=0.1711
# ✅ MSE: 0.2357 | R²: 0.9964
# ▶ Training: lr=0.0005, batch=32, hidden=(64, 32, 16, 8), epochs=100
# Epoch 10: Loss=168.7307
# Epoch 20: Loss=164.2929
# Epoch 30: Loss=146.6235
# Epoch 40: Loss=82.7513
# Epoch 50: Loss=28.9226
# Epoch 60: Loss=3.0183
# Epoch 70: Loss=0.9416
# Epoch 80: Loss=0.8908
# Epoch 90: Loss=0.8152
# Epoch 100: Loss=0.7521
# ✅ MSE: 0.9256 | R²: 0.9858
# ▶ Training: lr=0.0005, batch=32, hidden=(64, 32, 16, 8), epochs=200
# Epoch 10: Loss=167.9394
# Epoch 20: Loss=159.9540
# Epoch 30: Loss=140.7128
# Epoch 40: Loss=109.4616
# Epoch 50: Loss=45.6073
# Epoch 60: Loss=5.6316
# Epoch 70: Loss=4.3269
# Epoch 80: Loss=1.7686
# Epoch 90: Loss=1.6872
# Epoch 100: Loss=1.6695
# Epoch 110: Loss=1.1693
# Epoch 120: Loss=1.0214
# Epoch 130: Loss=0.7390
# Epoch 140: Loss=0.7465
# Epoch 150: Loss=0.6051
# Epoch 160: Loss=0.6551
# Epoch 170: Loss=0.6034
# Epoch 180: Loss=0.4871
# Epoch 190: Loss=0.3630
# Epoch 200: Loss=0.3823
# ✅ MSE: 0.1574 | R²: 0.9976
# 🏆 Best config: {'lr': 0.0005, 'batch_size': 16, 'hidden_sizes': (64, 32, 16), 'epochs': 200}, R²=0.9979

# %%
import os
import argparse
import datetime
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset
from itertools import product

# --- CONFIG ---
output_root = "/home/MinaHossain/EmbedTrack/Track_HP4_Result_Shape/Mean/Reg_Analysis"
os.makedirs(f"{output_root}/models", exist_ok=True)
os.makedirs(f"{output_root}/results", exist_ok=True)
os.makedirs(f"{output_root}/plots", exist_ok=True)

# --- FNN Model ---
class FNN(nn.Module):
    def __init__(self, input_size, hidden_sizes):
        super(FNN, self).__init__()
        layers = [nn.Linear(input_size, hidden_sizes[0]), nn.ReLU()]
        for i in range(1, len(hidden_sizes)):
            layers.append(nn.Linear(hidden_sizes[i-1], hidden_sizes[i]))
            layers.append(nn.ReLU())
        layers.append(nn.Linear(hidden_sizes[-1], 1))
        self.model = nn.Sequential(*layers)

    def forward(self, x):
        return self.model(x)

# --- Evaluation ---
def evaluate_model(model, X_test_tensor, y_test_tensor):
    model.eval()
    with torch.no_grad():
        y_pred_tensor = model(X_test_tensor)
    y_pred = y_pred_tensor.cpu().numpy().flatten()
    y_true = y_test_tensor.cpu().numpy().flatten()
    mse = mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"✅ MSE: {mse:.4f} | R²: {r2:.4f}")
    return mse, r2, y_true, y_pred

# --- Plotting ---
def plot_results(y_true, y_pred, train_losses=None):
    residuals = y_true - y_pred
    if train_losses:
        plt.figure(); plt.plot(train_losses); plt.title("Training Loss"); plt.tight_layout()
        plt.savefig(f"{output_root}/plots/loss_curve.png"); plt.close()
    plt.figure(); sns.scatterplot(x=y_pred, y=residuals); plt.axhline(0, linestyle='--', color='red')
    plt.title("Residuals vs Predicted"); plt.tight_layout()
    plt.savefig(f"{output_root}/plots/residuals_vs_predicted.png"); plt.close()
    plt.figure(); sns.scatterplot(x=y_true, y=y_pred); plt.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], 'r--')
    plt.title("Predicted vs Actual"); plt.tight_layout()
    plt.savefig(f"{output_root}/plots/predicted_vs_actual.png"); plt.close()
    plt.figure(); sns.histplot(residuals, bins=30, kde=True)
    plt.title("Distribution of Residuals"); plt.tight_layout()
    plt.savefig(f"{output_root}/plots/residuals_distribution.png"); plt.close()
    plt.figure(); plt.plot(np.sort(np.abs(residuals)), np.linspace(0, 1, len(residuals)))
    plt.title("Cumulative Absolute Errors"); plt.tight_layout()
    plt.savefig(f"{output_root}/plots/cumulative_absolute_errors.png"); plt.close()
    plt.figure(); stats.probplot(residuals, dist="norm", plot=plt)
    plt.title("Q-Q Plot"); plt.tight_layout()
    plt.savefig(f"{output_root}/plots/qq_plot_residuals.png"); plt.close()
    plt.figure(); sns.scatterplot(x=y_true, y=np.abs(residuals))
    plt.title("Absolute Error vs Actual"); plt.tight_layout()
    plt.savefig(f"{output_root}/plots/absolute_error_vs_actual.png"); plt.close()

# --- Run FNN ---
def run_fnn(X_train, X_test, y_train, y_test, input_size, hidden_sizes, lr, batch_size, epochs):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = FNN(input_size=input_size, hidden_sizes=hidden_sizes).to(device)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)

    X_train_tensor = torch.tensor(X_train).float().to(device)
    y_train_tensor = torch.tensor(y_train).float().to(device)
    X_test_tensor = torch.tensor(X_test).float().to(device)
    y_test_tensor = torch.tensor(y_test).float().to(device)

    train_loader = DataLoader(TensorDataset(X_train_tensor, y_train_tensor), batch_size=batch_size, shuffle=True)

    train_losses = []
    for epoch in range(epochs):
        model.train()
        total_loss = 0
        for xb, yb in train_loader:
            optimizer.zero_grad()
            pred = model(xb)
            loss = criterion(pred, yb)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        train_losses.append(total_loss / len(train_loader))
        if (epoch + 1) % 10 == 0:
            print(f"Epoch {epoch+1}: Loss={train_losses[-1]:.4f}")

    return model, train_losses, X_test_tensor, y_test_tensor

# --- Grid Search ---
def grid_search_fnn(csv_path, param_grid):
    df = pd.read_csv(csv_path)
    shape_features = ['Area_MA', 'Perimeter_MA', 'Extent_MA', 'Solidity_MA', 'Compactness_MA', 'Elongation_MA', 'Circularity_MA', 'Convexity_MA']
    target = 'X_Centroid_Velocity_MA'
    df = df.dropna(subset=shape_features + [target])

    X = df[shape_features].values
    y = df[target].values.reshape(-1, 1)

    X_scaled = StandardScaler().fit_transform(X)
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

    # PCA
    pca = PCA(n_components=0.95)
    X_train_pca = pca.fit_transform(X_train)
    X_test_pca = pca.transform(X_test)

    results = []
    best_r2 = -np.inf
    best_model = None
    best_config = None
    best_losses = None
    best_test_tensors = None

    for lr, batch_size, hidden_sizes, epochs in product(param_grid["lr"], param_grid["batch_size"],
                                                        param_grid["hidden_sizes"], param_grid["epochs"]):
        print(f"▶ Training: lr={lr}, batch={batch_size}, hidden={hidden_sizes}, epochs={epochs}")
        model, train_losses, X_test_tensor, y_test_tensor = run_fnn(
            X_train_pca, X_test_pca, y_train, y_test,
            input_size=X_train_pca.shape[1],
            hidden_sizes=hidden_sizes,
            lr=lr,
            batch_size=batch_size,
            epochs=epochs
        )
        mse, r2, y_true, y_pred = evaluate_model(model, X_test_tensor, y_test_tensor)

        results.append({
            "lr": lr, "batch_size": batch_size, "hidden_sizes": str(hidden_sizes),
            "epochs": epochs, "mse": mse, "r2": r2
        })

        if r2 > best_r2:
            best_r2 = r2
            best_model = model
            best_config = {
                "lr": lr, "batch_size": batch_size,
                "hidden_sizes": hidden_sizes, "epochs": epochs
            }
            best_losses = train_losses
            best_test_tensors = (X_test_tensor, y_test_tensor, y_true, y_pred)

    # Save best model
    model_path = f"{output_root}/models/fnn_best_model.pt"
    torch.save(best_model.state_dict(), model_path)

    pd.DataFrame(results).to_csv(f"{output_root}/results/grid_search_results.csv", index=False)
    print(f"🏆 Best config: {best_config}, R²={best_r2:.4f}")
    return best_model, best_config, best_losses, best_test_tensors

# --- Entry Point ---
if __name__ == "__main__":
    param_grid = {
        "lr": [0.001,0.0001, 0.00001],
        "batch_size": [8,16, 32],
        "hidden_sizes": [(128, 64, 32), (64, 32, 16), (64, 32, 16, 8),(128, 64, 32,16,8),(256,128, 64, 32,16)],
        "epochs": [100, 200,300]
    }
    csv_path = "/home/MinaHossain/EmbedTrack/Track_HP4_Result_Shape/Mean/Cells_Centroid_Velocity_TrueLabel_MA_Mean_5.csv"
    best_model, best_config, best_losses, (X_test_tensor, y_test_tensor, y_true, y_pred) = grid_search_fnn(csv_path, param_grid)
    plot_results(y_true, y_pred, train_losses=best_losses)
# Out:
# ▶ Training: lr=0.001, batch=8, hidden=(128, 64, 32), epochs=100
# Epoch 10: Loss=119.0897
# Epoch 20: Loss=64.4118
# Epoch 30: Loss=58.0437
# Epoch 40: Loss=57.8621
# Epoch 50: Loss=53.5017
# Epoch 60: Loss=52.6418
# Epoch 70: Loss=51.1897
# Epoch 80: Loss=50.3978
# Epoch 90: Loss=49.7324
# Epoch 100: Loss=48.1722
# ✅ MSE: 77.2555 | R²: 0.3946
# ▶ Training: lr=0.001, batch=8, hidden=(128, 64, 32), epochs=200
# Epoch 10: Loss=96.7600
# Epoch 20: Loss=61.9241
# Epoch 30: Loss=58.4574
# Epoch 40: Loss=58.0534
# Epoch 50: Loss=57.8446
# Epoch 60: Loss=54.9720
# Epoch 70: Loss=53.2038
# Epoch 80: Loss=51.7503
# Epoch 90: Loss=50.1373
# Epoch 100: Loss=50.0099
# Epoch 110: Loss=55.9173
# Epoch 120: Loss=51.3915
# Epoch 130: Loss=47.5850
# Epoch 140: Loss=45.2957
# Epoch 150: Loss=46.5912
# Epoch 160: Loss=44.2917
# Epoch 170: Loss=42.4344
# Epoch 180: Loss=43.0984
# Epoch 190: Loss=40.1454
# Epoch 200: Loss=39.3656
# ✅ MSE: 78.3727 | R²: 0.3859
# ▶ Training: lr=0.001, batch=8, hidden=(128, 64, 32), epochs=300
# Epoch 10: Loss=124.2366
# Epoch 20: Loss=71.9466
# Epoch 30: Loss=55.8170
# Epoch 40: Loss=53.5972
# Epoch 50: Loss=55.7606
# Epoch 60: Loss=52.7693
# Epoch 70: Loss=50.2598
# Epoch 80: Loss=47.4444
# Epoch 90: Loss=48.1108
# Epoch 100: Loss=45.7398
# Epoch 110: Loss=45.4642
# Epoch 120: Loss=43.3400
# Epoch 130: Loss=41.7046
# Epoch 140: Loss=41.7253
# Epoch 150: Loss=39.5539
# Epoch 160: Loss=39.0061
# Epoch 170: Loss=37.8666
# Epoch 180: Loss=35.8996
# Epoch 190: Loss=37.6034
# Epoch 200: Loss=34.2715
# Epoch 210: Loss=34.2385
# Epoch 220: Loss=32.8252
# Epoch 230: Loss=33.0738
# Epoch 240: Loss=30.8469
# Epoch 250: Loss=31.4066
# Epoch 260: Loss=29.2961
# Epoch 270: Loss=29.3211
# Epoch 280: Loss=28.8741
# Epoch 290: Loss=29.3401
# Epoch 300: Loss=27.2875
# ✅ MSE: 87.4760 | R²: 0.3145
# ▶ Training: lr=0.001, batch=8, hidden=(64, 32, 16), epochs=100
# Epoch 10: Loss=131.9769
# Epoch 20: Loss=108.7763
# Epoch 30: Loss=81.6968
# Epoch 40: Loss=63.0117
# Epoch 50: Loss=57.5767
# Epoch 60: Loss=54.4293
# Epoch 70: Loss=52.7677
# Epoch 80: Loss=52.6729
# Epoch 90: Loss=52.5681
# Epoch 100: Loss=52.2201
# ✅ MSE: 79.5752 | R²: 0.3764
# ▶ Training: lr=0.001, batch=8, hidden=(64, 32, 16), epochs=200
# Epoch 10: Loss=131.2684
# Epoch 20: Loss=104.7696
# Epoch 30: Loss=78.4662
# Epoch 40: Loss=63.5893
# Epoch 50: Loss=57.6841
# Epoch 60: Loss=57.5727
# Epoch 70: Loss=55.8027
# Epoch 80: Loss=54.2767
# Epoch 90: Loss=54.4984
# Epoch 100: Loss=53.6759
# Epoch 110: Loss=53.3149
# Epoch 120: Loss=50.5845
# Epoch 130: Loss=49.7800
# Epoch 140: Loss=49.2211
# Epoch 150: Loss=49.2074
# Epoch 160: Loss=52.4430
# Epoch 170: Loss=47.9160
# Epoch 180: Loss=47.6155
# Epoch 190: Loss=46.7369
# Epoch 200: Loss=47.9070
# ✅ MSE: 90.3353 | R²: 0.2921
# ▶ Training: lr=0.001, batch=8, hidden=(64, 32, 16), epochs=300
# Epoch 10: Loss=133.6116
# Epoch 20: Loss=109.0734
# Epoch 30: Loss=73.5376
# Epoch 40: Loss=59.7805
# Epoch 50: Loss=56.5215
# Epoch 60: Loss=54.9093
# Epoch 70: Loss=54.3401
# Epoch 80: Loss=53.4993
# Epoch 90: Loss=53.6875
# Epoch 100: Loss=53.5310
# Epoch 110: Loss=52.3023
# Epoch 120: Loss=52.0716
# Epoch 130: Loss=52.0700
# Epoch 140: Loss=51.8459
# Epoch 150: Loss=50.9851
# Epoch 160: Loss=51.2160
# Epoch 170: Loss=49.5795
# Epoch 180: Loss=50.2917
# Epoch 190: Loss=47.9217
# Epoch 200: Loss=46.9701
# Epoch 210: Loss=45.9915
# Epoch 220: Loss=46.2339
# Epoch 230: Loss=45.7105
# Epoch 240: Loss=45.1161
# Epoch 250: Loss=43.8892
# Epoch 260: Loss=43.2258
# Epoch 270: Loss=43.4273
# Epoch 280: Loss=42.0978
# Epoch 290: Loss=40.8438
# Epoch 300: Loss=42.2771
# ✅ MSE: 82.3154 | R²: 0.3550
# ▶ Training: lr=0.001, batch=8, hidden=(64, 32, 16, 8), epochs=100
# Epoch 10: Loss=136.6342
# Epoch 20: Loss=94.7206
# Epoch 30: Loss=61.8918
# Epoch 40: Loss=58.3018
# Epoch 50: Loss=57.9600
# Epoch 60: Loss=57.3465
# Epoch 70: Loss=58.2473
# Epoch 80: Loss=55.2133
# Epoch 90: Loss=54.8187
# Epoch 100: Loss=54.9812
# ✅ MSE: 77.3215 | R²: 0.3941
# ▶ Training: lr=0.001, batch=8, hidden=(64, 32, 16, 8), epochs=200
# Epoch 10: Loss=132.2365
# Epoch 20: Loss=71.4539
# Epoch 30: Loss=60.4369
# Epoch 40: Loss=57.2335
# Epoch 50: Loss=58.1044
# Epoch 60: Loss=56.9406
# Epoch 70: Loss=55.5353
# Epoch 80: Loss=55.3098
# Epoch 90: Loss=54.8645
# Epoch 100: Loss=53.3601
# Epoch 110: Loss=52.1534
# Epoch 120: Loss=52.4571
# Epoch 130: Loss=52.0629
# Epoch 140: Loss=50.6546
# Epoch 150: Loss=49.9074
# Epoch 160: Loss=49.6353
# Epoch 170: Loss=49.7914
# Epoch 180: Loss=50.2932
# Epoch 190: Loss=48.2852
# Epoch 200: Loss=47.1764
# ✅ MSE: 80.2848 | R²: 0.3709
# ▶ Training: lr=0.001, batch=8, hidden=(64, 32, 16, 8), epochs=300
# Epoch 10: Loss=138.1011
# Epoch 20: Loss=116.2578
# Epoch 30: Loss=74.3842
# Epoch 40: Loss=59.2898
# Epoch 50: Loss=57.2850
# Epoch 60: Loss=55.9451
# Epoch 70: Loss=56.7189
# Epoch 80: Loss=53.4504
# Epoch 90: Loss=52.8348
# Epoch 100: Loss=52.3206
# Epoch 110: Loss=54.3585
# Epoch 120: Loss=51.2079
# Epoch 130: Loss=48.5442
# Epoch 140: Loss=47.9773
# Epoch 150: Loss=49.2432
# Epoch 160: Loss=47.8097
# Epoch 170: Loss=46.2060
# Epoch 180: Loss=45.5681
# Epoch 190: Loss=44.9479
# Epoch 200: Loss=44.8006
# Epoch 210: Loss=43.9056
# Epoch 220: Loss=44.3171
# Epoch 230: Loss=42.6977
# Epoch 240: Loss=42.9738
# Epoch 250: Loss=42.1979
# Epoch 260: Loss=41.4369
# Epoch 270: Loss=41.7205
# Epoch 280: Loss=40.1102
# Epoch 290: Loss=39.8623
# Epoch 300: Loss=38.9843
# ✅ MSE: 85.8520 | R²: 0.3273
# ▶ Training: lr=0.001, batch=8, hidden=(128, 64, 32, 16, 8), epochs=100
# Epoch 10: Loss=89.0969
# Epoch 20: Loss=58.1700
# Epoch 30: Loss=57.3916
# Epoch 40: Loss=55.6415
# Epoch 50: Loss=55.5142
# Epoch 60: Loss=54.5480
# Epoch 70: Loss=52.4165
# Epoch 80: Loss=50.5501
# Epoch 90: Loss=45.5261
# Epoch 100: Loss=48.0909
# ✅ MSE: 84.0368 | R²: 0.3415
# ▶ Training: lr=0.001, batch=8, hidden=(128, 64, 32, 16, 8), epochs=200
# Epoch 10: Loss=127.9123
# Epoch 20: Loss=64.5664
# Epoch 30: Loss=55.9788
# Epoch 40: Loss=57.2927
# Epoch 50: Loss=58.0224
# Epoch 60: Loss=51.9587
# Epoch 70: Loss=51.6481
# Epoch 80: Loss=54.3330
# Epoch 90: Loss=54.2594
# Epoch 100: Loss=48.4497
# Epoch 110: Loss=48.7328
# Epoch 120: Loss=46.5216
# Epoch 130: Loss=46.3574
# Epoch 140: Loss=45.4060
# Epoch 150: Loss=47.1413
# Epoch 160: Loss=44.2433
# Epoch 170: Loss=40.1514
# Epoch 180: Loss=38.8440
# Epoch 190: Loss=38.8463
# Epoch 200: Loss=34.9999
# ✅ MSE: 76.7315 | R²: 0.3987
# ▶ Training: lr=0.001, batch=8, hidden=(128, 64, 32, 16, 8), epochs=300
# Epoch 10: Loss=129.6509
# Epoch 20: Loss=60.9261
# Epoch 30: Loss=62.3697
# Epoch 40: Loss=58.1953
# Epoch 50: Loss=57.3397
# Epoch 60: Loss=59.4196
# Epoch 70: Loss=57.2226
# Epoch 80: Loss=55.1373
# Epoch 90: Loss=53.6439
# Epoch 100: Loss=51.0310
# Epoch 110: Loss=49.7070
# Epoch 120: Loss=50.1611
# Epoch 130: Loss=51.0802
# Epoch 140: Loss=49.3478
# Epoch 150: Loss=47.7392
# Epoch 160: Loss=43.1430
# Epoch 170: Loss=42.2004
# Epoch 180: Loss=40.1810
# Epoch 190: Loss=37.2987
# Epoch 200: Loss=37.5127
# Epoch 210: Loss=37.4905
# Epoch 220: Loss=37.6030
# Epoch 230: Loss=35.8734
# Epoch 240: Loss=34.2535
# Epoch 250: Loss=33.5993
# Epoch 260: Loss=35.7757
# Epoch 270: Loss=32.7969
# Epoch 280: Loss=32.8660
# Epoch 290: Loss=34.1881
# Epoch 300: Loss=31.8330
# ✅ MSE: 75.0832 | R²: 0.4116
# ▶ Training: lr=0.001, batch=8, hidden=(256, 128, 64, 32, 16), epochs=100
# Epoch 10: Loss=68.6189
# Epoch 20: Loss=60.8012
# Epoch 30: Loss=57.3664
# Epoch 40: Loss=59.3108
# Epoch 50: Loss=52.8777
# Epoch 60: Loss=52.7743
# Epoch 70: Loss=47.2463
# Epoch 80: Loss=44.4228
# Epoch 90: Loss=41.3663
# Epoch 100: Loss=36.5732
# ✅ MSE: 78.5721 | R²: 0.3843
# ▶ Training: lr=0.001, batch=8, hidden=(256, 128, 64, 32, 16), epochs=200
# Epoch 10: Loss=92.5933
# Epoch 20: Loss=61.2944
# Epoch 30: Loss=61.5596
# Epoch 40: Loss=59.1117
# Epoch 50: Loss=52.6881
# Epoch 60: Loss=55.4613
# Epoch 70: Loss=47.9883
# Epoch 80: Loss=46.4997
# Epoch 90: Loss=44.3049
# Epoch 100: Loss=41.5149
# Epoch 110: Loss=37.7488
# Epoch 120: Loss=40.1299
# Epoch 130: Loss=36.6254
# Epoch 140: Loss=33.2120
# Epoch 150: Loss=31.7280
# Epoch 160: Loss=32.4585
# Epoch 170: Loss=42.5071
# Epoch 180: Loss=28.3569
# Epoch 190: Loss=28.3394
# Epoch 200: Loss=27.1723
# ✅ MSE: 81.5904 | R²: 0.3606
# ▶ Training: lr=0.001, batch=8, hidden=(256, 128, 64, 32, 16), epochs=300
# Epoch 10: Loss=133.2914
# Epoch 20: Loss=67.3942
# Epoch 30: Loss=61.3542
# Epoch 40: Loss=57.4419
# Epoch 50: Loss=55.5099
# Epoch 60: Loss=53.4280
# Epoch 70: Loss=52.1189
# Epoch 80: Loss=49.9288
# Epoch 90: Loss=45.1479
# Epoch 100: Loss=41.5727
# Epoch 110: Loss=38.2931
# Epoch 120: Loss=34.5177
# Epoch 130: Loss=34.1785
# Epoch 140: Loss=33.1570
# Epoch 150: Loss=30.5019
# Epoch 160: Loss=28.6027
# Epoch 170: Loss=26.4633
# Epoch 180: Loss=26.4809
# Epoch 190: Loss=23.8007
# Epoch 200: Loss=23.2857
# Epoch 210: Loss=29.2864
# Epoch 220: Loss=21.9830
# Epoch 230: Loss=21.3267
# Epoch 240: Loss=19.6507
# Epoch 250: Loss=19.9236
# Epoch 260: Loss=21.9771
# Epoch 270: Loss=18.7265
# Epoch 280: Loss=28.5675
# Epoch 290: Loss=18.1566
# Epoch 300: Loss=20.7086
# ✅ MSE: 86.7453 | R²: 0.3203
# ▶ Training: lr=0.001, batch=16, hidden=(128, 64, 32), epochs=100
# Epoch 10: Loss=127.3831
# Epoch 20: Loss=84.0602
# Epoch 30: Loss=61.3764
# Epoch 40: Loss=57.2523
# Epoch 50: Loss=53.9004
# Epoch 60: Loss=55.6273
# Epoch 70: Loss=53.8151
# Epoch 80: Loss=52.9001
# Epoch 90: Loss=51.1601
# Epoch 100: Loss=50.5794
# ✅ MSE: 77.2121 | R²: 0.3950
# ▶ Training: lr=0.001, batch=16, hidden=(128, 64, 32), epochs=200
# Epoch 10: Loss=119.2555
# Epoch 20: Loss=64.7146
# Epoch 30: Loss=59.0568
# Epoch 40: Loss=57.8351
# Epoch 50: Loss=56.7860
# Epoch 60: Loss=57.1440
# Epoch 70: Loss=53.0162
# Epoch 80: Loss=53.9976
# Epoch 90: Loss=51.7708
# Epoch 100: Loss=50.9261
# Epoch 110: Loss=48.0063
# Epoch 120: Loss=47.8725
# Epoch 130: Loss=45.2974
# Epoch 140: Loss=44.9725
# Epoch 150: Loss=44.5454
# Epoch 160: Loss=43.3221
# Epoch 170: Loss=42.5056
# Epoch 180: Loss=41.8103
# Epoch 190: Loss=38.7567
# Epoch 200: Loss=38.5675
# ✅ MSE: 81.9599 | R²: 0.3578
# ▶ Training: lr=0.001, batch=16, hidden=(128, 64, 32), epochs=300
# Epoch 10: Loss=119.0571
# Epoch 20: Loss=68.5403
# Epoch 30: Loss=61.1949
# Epoch 40: Loss=56.1288
# Epoch 50: Loss=55.7836
# Epoch 60: Loss=55.6782
# Epoch 70: Loss=55.7089
# Epoch 80: Loss=54.4054
# Epoch 90: Loss=52.1912
# Epoch 100: Loss=51.0812
# Epoch 110: Loss=51.1354
# Epoch 120: Loss=49.9542
# Epoch 130: Loss=48.4150
# Epoch 140: Loss=48.4562
# Epoch 150: Loss=49.8611
# Epoch 160: Loss=46.7005
# Epoch 170: Loss=45.4902
# Epoch 180: Loss=43.7391
# Epoch 190: Loss=44.0925
# Epoch 200: Loss=43.5103
# Epoch 210: Loss=42.8422
# Epoch 220: Loss=41.6853
# Epoch 230: Loss=41.0104
# Epoch 240: Loss=38.6256
# Epoch 250: Loss=37.8473
# Epoch 260: Loss=37.5979
# Epoch 270: Loss=36.9568
# Epoch 280: Loss=35.4145
# Epoch 290: Loss=35.3697
# Epoch 300: Loss=34.9414
# ✅ MSE: 97.3964 | R²: 0.2368
# ▶ Training: lr=0.001, batch=16, hidden=(64, 32, 16), epochs=100
# Epoch 10: Loss=131.8138
# Epoch 20: Loss=97.7567
# Epoch 30: Loss=63.9785
# Epoch 40: Loss=58.6629
# Epoch 50: Loss=56.1054
# Epoch 60: Loss=55.9632
# Epoch 70: Loss=55.0712
# Epoch 80: Loss=57.6292
# Epoch 90: Loss=52.0367
# Epoch 100: Loss=51.0155
# ✅ MSE: 78.2432 | R²: 0.3869
# ▶ Training: lr=0.001, batch=16, hidden=(64, 32, 16), epochs=200
# Epoch 10: Loss=135.2887
# Epoch 20: Loss=118.3799
# Epoch 30: Loss=103.0412
# Epoch 40: Loss=85.1685
# Epoch 50: Loss=70.8584
# Epoch 60: Loss=63.1203
# Epoch 70: Loss=59.3533
# Epoch 80: Loss=57.0269
# Epoch 90: Loss=55.4139
# Epoch 100: Loss=53.6557
# Epoch 110: Loss=52.3361
# Epoch 120: Loss=52.8406
# Epoch 130: Loss=54.5723
# Epoch 140: Loss=49.6947
# Epoch 150: Loss=49.6937
# Epoch 160: Loss=50.6319
# Epoch 170: Loss=50.5220
# Epoch 180: Loss=49.9589
# Epoch 190: Loss=48.1979
# Epoch 200: Loss=47.6087
# ✅ MSE: 83.4523 | R²: 0.3461
# ▶ Training: lr=0.001, batch=16, hidden=(64, 32, 16), epochs=300
# Epoch 10: Loss=135.0769
# Epoch 20: Loss=118.3316
# Epoch 30: Loss=96.4701
# Epoch 40: Loss=78.5805
# Epoch 50: Loss=64.0921
# Epoch 60: Loss=58.6894
# Epoch 70: Loss=54.9947
# Epoch 80: Loss=55.8586
# Epoch 90: Loss=52.8323
# Epoch 100: Loss=52.3672
# Epoch 110: Loss=50.6895
# Epoch 120: Loss=49.7264
# Epoch 130: Loss=49.8882
# Epoch 140: Loss=49.5722
# Epoch 150: Loss=49.0908
# Epoch 160: Loss=49.3040
# Epoch 170: Loss=49.1945
# Epoch 180: Loss=47.7348
# Epoch 190: Loss=46.4132
# Epoch 200: Loss=46.7439
# Epoch 210: Loss=46.9506
# Epoch 220: Loss=46.2149
# Epoch 230: Loss=44.0987
# Epoch 240: Loss=44.0822
# Epoch 250: Loss=44.3895
# Epoch 260: Loss=45.8027
# Epoch 270: Loss=43.3366
# Epoch 280: Loss=43.0622
# Epoch 290: Loss=44.9637
# Epoch 300: Loss=43.8360
# ✅ MSE: 79.1060 | R²: 0.3801
# ▶ Training: lr=0.001, batch=16, hidden=(64, 32, 16, 8), epochs=100
# Epoch 10: Loss=135.1019
# Epoch 20: Loss=97.4339
# Epoch 30: Loss=63.6655
# Epoch 40: Loss=61.0174
# Epoch 50: Loss=56.8672
# Epoch 60: Loss=58.1201
# Epoch 70: Loss=61.1261
# Epoch 80: Loss=54.9213
# Epoch 90: Loss=54.5476
# Epoch 100: Loss=56.2562
# ✅ MSE: 78.6116 | R²: 0.3840
# ▶ Training: lr=0.001, batch=16, hidden=(64, 32, 16, 8), epochs=200
# Epoch 10: Loss=135.5101
# Epoch 20: Loss=115.7290
# Epoch 30: Loss=70.1679
# Epoch 40: Loss=60.7088
# Epoch 50: Loss=58.4955
# Epoch 60: Loss=56.4623
# Epoch 70: Loss=54.8284
# Epoch 80: Loss=55.4675
# Epoch 90: Loss=53.7420
# Epoch 100: Loss=52.1026
# Epoch 110: Loss=53.1821
# Epoch 120: Loss=51.4664
# Epoch 130: Loss=50.8510
# Epoch 140: Loss=51.0962
# Epoch 150: Loss=51.5099
# Epoch 160: Loss=50.4239
# Epoch 170: Loss=48.9899
# Epoch 180: Loss=50.8420
# Epoch 190: Loss=49.1916
# Epoch 200: Loss=49.2238
# ✅ MSE: 77.9789 | R²: 0.3889
# ▶ Training: lr=0.001, batch=16, hidden=(64, 32, 16, 8), epochs=300
# Epoch 10: Loss=135.6413
# Epoch 20: Loss=109.9909
# Epoch 30: Loss=67.8829
# Epoch 40: Loss=65.2794
# Epoch 50: Loss=61.8768
# Epoch 60: Loss=58.1551
# Epoch 70: Loss=58.1406
# Epoch 80: Loss=54.8861
# Epoch 90: Loss=55.3025
# Epoch 100: Loss=54.0366
# Epoch 110: Loss=56.0660
# Epoch 120: Loss=52.8734
# Epoch 130: Loss=52.5908
# Epoch 140: Loss=52.6872
# Epoch 150: Loss=52.7167
# Epoch 160: Loss=52.0302
# Epoch 170: Loss=50.7214
# Epoch 180: Loss=51.4269
# Epoch 190: Loss=50.2076
# Epoch 200: Loss=49.8042
# Epoch 210: Loss=49.5050
# Epoch 220: Loss=49.5660
# Epoch 230: Loss=48.2637
# Epoch 240: Loss=47.7192
# Epoch 250: Loss=48.4911
# Epoch 260: Loss=45.5090
# Epoch 270: Loss=45.7195
# Epoch 280: Loss=44.1680
# Epoch 290: Loss=49.1385
# Epoch 300: Loss=43.7382
# ✅ MSE: 74.6047 | R²: 0.4154
# ▶ Training: lr=0.001, batch=16, hidden=(128, 64, 32, 16, 8), epochs=100
# Epoch 10: Loss=132.0867
# Epoch 20: Loss=63.3550
# Epoch 30: Loss=59.7684
# Epoch 40: Loss=56.6260
# Epoch 50: Loss=56.2574
# Epoch 60: Loss=59.1586
# Epoch 70: Loss=53.7271
# Epoch 80: Loss=56.5197
# Epoch 90: Loss=55.0799
# Epoch 100: Loss=53.2282
# ✅ MSE: 82.0074 | R²: 0.3574
# ▶ Training: lr=0.001, batch=16, hidden=(128, 64, 32, 16, 8), epochs=200
# Epoch 10: Loss=132.7417
# Epoch 20: Loss=63.9182
# Epoch 30: Loss=60.0941
# Epoch 40: Loss=57.8918
# Epoch 50: Loss=57.5513
# Epoch 60: Loss=55.7400
# Epoch 70: Loss=56.3247
# Epoch 80: Loss=53.8844
# Epoch 90: Loss=49.1728
# Epoch 100: Loss=46.2669
# Epoch 110: Loss=46.1388
# Epoch 120: Loss=52.3565
# Epoch 130: Loss=43.9262
# Epoch 140: Loss=43.6624
# Epoch 150: Loss=43.6923
# Epoch 160: Loss=43.4306
# Epoch 170: Loss=42.3694
# Epoch 180: Loss=39.0406
# Epoch 190: Loss=38.5550
# Epoch 200: Loss=38.3615
# ✅ MSE: 75.1007 | R²: 0.4115
# ▶ Training: lr=0.001, batch=16, hidden=(128, 64, 32, 16, 8), epochs=300
# Epoch 10: Loss=119.6719
# Epoch 20: Loss=62.2086
# Epoch 30: Loss=61.4089
# Epoch 40: Loss=58.3055
# Epoch 50: Loss=58.3036
# Epoch 60: Loss=56.6057
# Epoch 70: Loss=57.6135
# Epoch 80: Loss=56.0754
# Epoch 90: Loss=55.4993
# Epoch 100: Loss=54.6512
# Epoch 110: Loss=53.9384
# Epoch 120: Loss=54.2016
# Epoch 130: Loss=53.3070
# Epoch 140: Loss=53.3047
# Epoch 150: Loss=55.3266
# Epoch 160: Loss=51.6351
# Epoch 170: Loss=49.9299
# Epoch 180: Loss=50.8788
# Epoch 190: Loss=48.6442
# Epoch 200: Loss=48.1440
# Epoch 210: Loss=48.5760
# Epoch 220: Loss=50.8505
# Epoch 230: Loss=48.4302
# Epoch 240: Loss=46.4441
# Epoch 250: Loss=50.1495
# Epoch 260: Loss=51.4730
# Epoch 270: Loss=47.2127
# Epoch 280: Loss=45.6250
# Epoch 290: Loss=46.6155
# Epoch 300: Loss=44.6576
# ✅ MSE: 80.2087 | R²: 0.3715
# ▶ Training: lr=0.001, batch=16, hidden=(256, 128, 64, 32, 16), epochs=100
# Epoch 10: Loss=97.0519
# Epoch 20: Loss=59.1496
# Epoch 30: Loss=56.5468
# Epoch 40: Loss=55.9286
# Epoch 50: Loss=56.1922
# Epoch 60: Loss=51.0082
# Epoch 70: Loss=52.3429
# Epoch 80: Loss=46.4712
# Epoch 90: Loss=43.8608
# Epoch 100: Loss=40.4091
# ✅ MSE: 75.1649 | R²: 0.4110
# ▶ Training: lr=0.001, batch=16, hidden=(256, 128, 64, 32, 16), epochs=200
# Epoch 10: Loss=89.9592
# Epoch 20: Loss=70.2545
# Epoch 30: Loss=59.5365
# Epoch 40: Loss=58.2467
# Epoch 50: Loss=58.2820
# Epoch 60: Loss=55.0898
# Epoch 70: Loss=54.0999
# Epoch 80: Loss=54.2658
# Epoch 90: Loss=45.9899
# Epoch 100: Loss=45.9022
# Epoch 110: Loss=41.4404
# Epoch 120: Loss=42.1724
# Epoch 130: Loss=42.4525
# Epoch 140: Loss=42.0773
# Epoch 150: Loss=38.2755
# Epoch 160: Loss=35.1563
# Epoch 170: Loss=35.1861
# Epoch 180: Loss=36.4251
# Epoch 190: Loss=30.9577
# Epoch 200: Loss=31.1106
# ✅ MSE: 86.6658 | R²: 0.3209
# ▶ Training: lr=0.001, batch=16, hidden=(256, 128, 64, 32, 16), epochs=300
# Epoch 10: Loss=110.4547
# Epoch 20: Loss=60.7419
# Epoch 30: Loss=58.0235
# Epoch 40: Loss=57.0547
# Epoch 50: Loss=55.7814
# Epoch 60: Loss=53.6025
# Epoch 70: Loss=48.1966
# Epoch 80: Loss=51.6545
# Epoch 90: Loss=41.6301
# Epoch 100: Loss=41.0225
# Epoch 110: Loss=40.3077
# Epoch 120: Loss=35.0128
# Epoch 130: Loss=37.6927
# Epoch 140: Loss=32.3851
# Epoch 150: Loss=31.3410
# Epoch 160: Loss=35.2657
# Epoch 170: Loss=34.3159
# Epoch 180: Loss=27.0315
# Epoch 190: Loss=27.2247
# Epoch 200: Loss=25.3893
# Epoch 210: Loss=27.4085
# Epoch 220: Loss=23.0976
# Epoch 230: Loss=28.4640
# Epoch 240: Loss=24.9790
# Epoch 250: Loss=27.4683
# Epoch 260: Loss=26.6026
# Epoch 270: Loss=24.7940
# Epoch 280: Loss=21.2289
# Epoch 290: Loss=22.2164
# Epoch 300: Loss=29.2253
# ✅ MSE: 79.7253 | R²: 0.3753
# ▶ Training: lr=0.001, batch=32, hidden=(128, 64, 32), epochs=100
# Epoch 10: Loss=129.5271
# Epoch 20: Loss=113.7541
# Epoch 30: Loss=95.9094
# Epoch 40: Loss=70.9353
# Epoch 50: Loss=63.4512
# Epoch 60: Loss=56.4239
# Epoch 70: Loss=59.1595
# Epoch 80: Loss=50.5545
# Epoch 90: Loss=51.4190
# Epoch 100: Loss=49.7650
# ✅ MSE: 80.9922 | R²: 0.3653
# ▶ Training: lr=0.001, batch=32, hidden=(128, 64, 32), epochs=200
# Epoch 10: Loss=126.9100
# Epoch 20: Loss=97.7450
# Epoch 30: Loss=62.8390
# Epoch 40: Loss=55.4837
# Epoch 50: Loss=55.2651
# Epoch 60: Loss=62.0764
# Epoch 70: Loss=50.7213
# Epoch 80: Loss=52.5731
# Epoch 90: Loss=51.8533
# Epoch 100: Loss=51.3229
# Epoch 110: Loss=49.5399
# Epoch 120: Loss=56.4535
# Epoch 130: Loss=50.0241
# Epoch 140: Loss=49.9896
# Epoch 150: Loss=49.8571
# Epoch 160: Loss=47.0612
# Epoch 170: Loss=46.6884
# Epoch 180: Loss=46.5683
# Epoch 190: Loss=47.1005
# Epoch 200: Loss=46.3493
# ✅ MSE: 72.7795 | R²: 0.4297
# ▶ Training: lr=0.001, batch=32, hidden=(128, 64, 32), epochs=300
# Epoch 10: Loss=125.5736
# Epoch 20: Loss=99.5204
# Epoch 30: Loss=72.2922
# Epoch 40: Loss=63.3585
# Epoch 50: Loss=60.5454
# Epoch 60: Loss=54.2407
# Epoch 70: Loss=54.3336
# Epoch 80: Loss=53.9529
# Epoch 90: Loss=53.0097
# Epoch 100: Loss=60.2716
# Epoch 110: Loss=51.3961
# Epoch 120: Loss=51.5347
# Epoch 130: Loss=48.5858
# Epoch 140: Loss=55.9712
# Epoch 150: Loss=48.5325
# Epoch 160: Loss=47.4539
# Epoch 170: Loss=48.1449
# Epoch 180: Loss=47.5234
# Epoch 190: Loss=48.2199
# Epoch 200: Loss=48.9383
# Epoch 210: Loss=42.9716
# Epoch 220: Loss=43.9891
# Epoch 230: Loss=41.1092
# Epoch 240: Loss=40.7403
# Epoch 250: Loss=39.2758
# Epoch 260: Loss=44.2795
# Epoch 270: Loss=39.1464
# Epoch 280: Loss=38.1695
# Epoch 290: Loss=37.2870
# Epoch 300: Loss=36.9816
# ✅ MSE: 80.6295 | R²: 0.3682
# ▶ Training: lr=0.001, batch=32, hidden=(64, 32, 16), epochs=100
# Epoch 10: Loss=132.0770
# Epoch 20: Loss=122.6557
# Epoch 30: Loss=105.0553
# Epoch 40: Loss=88.6397
# Epoch 50: Loss=79.6430
# Epoch 60: Loss=63.5936
# Epoch 70: Loss=58.0582
# Epoch 80: Loss=62.0626
# Epoch 90: Loss=55.7638
# Epoch 100: Loss=54.7180
# ✅ MSE: 85.8903 | R²: 0.3270
# ▶ Training: lr=0.001, batch=32, hidden=(64, 32, 16), epochs=200
# Epoch 10: Loss=134.5395
# Epoch 20: Loss=128.9695
# Epoch 30: Loss=113.8473
# Epoch 40: Loss=97.6225
# Epoch 50: Loss=89.3071
# Epoch 60: Loss=73.3399
# Epoch 70: Loss=64.8198
# Epoch 80: Loss=58.7097
# Epoch 90: Loss=60.8844
# Epoch 100: Loss=56.7345
# Epoch 110: Loss=57.2835
# Epoch 120: Loss=51.6102
# Epoch 130: Loss=53.0874
# Epoch 140: Loss=50.2206
# Epoch 150: Loss=49.6451
# Epoch 160: Loss=51.0491
# Epoch 170: Loss=49.3611
# Epoch 180: Loss=48.3275
# Epoch 190: Loss=48.0071
# Epoch 200: Loss=48.0357
# ✅ MSE: 89.6597 | R²: 0.2974
# ▶ Training: lr=0.001, batch=32, hidden=(64, 32, 16), epochs=300
# Epoch 10: Loss=131.0915
# Epoch 20: Loss=115.3077
# Epoch 30: Loss=88.3369
# Epoch 40: Loss=65.3443
# Epoch 50: Loss=58.7114
# Epoch 60: Loss=56.6715
# Epoch 70: Loss=63.0023
# Epoch 80: Loss=55.8751
# Epoch 90: Loss=52.3040
# Epoch 100: Loss=53.0233
# Epoch 110: Loss=52.1926
# Epoch 120: Loss=52.3400
# Epoch 130: Loss=51.1276
# Epoch 140: Loss=51.2000
# Epoch 150: Loss=50.3783
# Epoch 160: Loss=53.5335
# Epoch 170: Loss=49.5014
# Epoch 180: Loss=50.9443
# Epoch 190: Loss=49.7211
# Epoch 200: Loss=48.6216
# Epoch 210: Loss=49.9444
# Epoch 220: Loss=50.3192
# Epoch 230: Loss=47.9647
# Epoch 240: Loss=51.1754
# Epoch 250: Loss=48.1953
# Epoch 260: Loss=52.2449
# Epoch 270: Loss=46.7357
# Epoch 280: Loss=47.7179
# Epoch 290: Loss=48.9175
# Epoch 300: Loss=46.9538
# ✅ MSE: 81.1768 | R²: 0.3639
# ▶ Training: lr=0.001, batch=32, hidden=(64, 32, 16, 8), epochs=100
# Epoch 10: Loss=140.1565
# Epoch 20: Loss=122.7520
# Epoch 30: Loss=113.3056
# Epoch 40: Loss=88.6295
# Epoch 50: Loss=69.0169
# Epoch 60: Loss=65.6717
# Epoch 70: Loss=62.2977
# Epoch 80: Loss=57.7341
# Epoch 90: Loss=53.7028
# Epoch 100: Loss=53.6736
# ✅ MSE: 79.4494 | R²: 0.3774
# ▶ Training: lr=0.001, batch=32, hidden=(64, 32, 16, 8), epochs=200
# Epoch 10: Loss=131.5667
# Epoch 20: Loss=123.7977
# Epoch 30: Loss=97.3347
# Epoch 40: Loss=69.1104
# Epoch 50: Loss=60.1142
# Epoch 60: Loss=60.2507
# Epoch 70: Loss=54.6371
# Epoch 80: Loss=57.4822
# Epoch 90: Loss=56.5473
# Epoch 100: Loss=54.6023
# Epoch 110: Loss=55.9377
# Epoch 120: Loss=58.8299
# Epoch 130: Loss=53.7046
# Epoch 140: Loss=51.5363
# Epoch 150: Loss=52.4672
# Epoch 160: Loss=60.3353
# Epoch 170: Loss=52.4193
# Epoch 180: Loss=51.4385
# Epoch 190: Loss=50.7603
# Epoch 200: Loss=50.6376
# ✅ MSE: 79.7257 | R²: 0.3753
# ▶ Training: lr=0.001, batch=32, hidden=(64, 32, 16, 8), epochs=300
# Epoch 10: Loss=131.2513
# Epoch 20: Loss=113.6316
# Epoch 30: Loss=76.5808
# Epoch 40: Loss=61.9660
# Epoch 50: Loss=59.3401
# Epoch 60: Loss=55.5777
# Epoch 70: Loss=55.8908
# Epoch 80: Loss=56.2265
# Epoch 90: Loss=54.3895
# Epoch 100: Loss=54.1052
# Epoch 110: Loss=54.6485
# Epoch 120: Loss=55.2348
# Epoch 130: Loss=53.6733
# Epoch 140: Loss=57.3055
# Epoch 150: Loss=55.9271
# Epoch 160: Loss=55.9321
# Epoch 170: Loss=53.2458
# Epoch 180: Loss=53.6203
# Epoch 190: Loss=53.8022
# Epoch 200: Loss=53.6302
# Epoch 210: Loss=64.4255
# Epoch 220: Loss=55.5419
# Epoch 230: Loss=55.0664
# Epoch 240: Loss=52.4477
# Epoch 250: Loss=51.9471
# Epoch 260: Loss=51.7988
# Epoch 270: Loss=53.8293
# Epoch 280: Loss=57.4070
# Epoch 290: Loss=50.8438
# Epoch 300: Loss=52.4085
# ✅ MSE: 80.3895 | R²: 0.3701
# ▶ Training: lr=0.001, batch=32, hidden=(128, 64, 32, 16, 8), epochs=100
# Epoch 10: Loss=134.8724
# Epoch 20: Loss=122.4888
# Epoch 30: Loss=92.6521
# Epoch 40: Loss=60.5197
# Epoch 50: Loss=55.5417
# Epoch 60: Loss=58.2908
# Epoch 70: Loss=53.9475
# Epoch 80: Loss=54.1330
# Epoch 90: Loss=50.9231
# Epoch 100: Loss=49.5507
# ✅ MSE: 81.0969 | R²: 0.3645
# ▶ Training: lr=0.001, batch=32, hidden=(128, 64, 32, 16, 8), epochs=200
# Epoch 10: Loss=126.8039
# Epoch 20: Loss=70.2496
# Epoch 30: Loss=57.5320
# Epoch 40: Loss=55.7891
# Epoch 50: Loss=55.3822
# Epoch 60: Loss=53.2618
# Epoch 70: Loss=54.5753
# Epoch 80: Loss=54.5934
# Epoch 90: Loss=54.1868
# Epoch 100: Loss=58.8630
# Epoch 110: Loss=51.4568
# Epoch 120: Loss=55.9017
# Epoch 130: Loss=54.3898
# Epoch 140: Loss=50.0694
# Epoch 150: Loss=50.4518
# Epoch 160: Loss=50.0609
# Epoch 170: Loss=53.6413
# Epoch 180: Loss=50.9228
# Epoch 190: Loss=50.8421
# Epoch 200: Loss=49.6476
# ✅ MSE: 79.7299 | R²: 0.3752
# ▶ Training: lr=0.001, batch=32, hidden=(128, 64, 32, 16, 8), epochs=300
# Epoch 10: Loss=148.7417
# Epoch 20: Loss=111.7981
# Epoch 30: Loss=70.3045
# Epoch 40: Loss=59.8033
# Epoch 50: Loss=55.9883
# Epoch 60: Loss=60.7906
# Epoch 70: Loss=58.5727
# Epoch 80: Loss=57.0326
# Epoch 90: Loss=56.1182
# Epoch 100: Loss=58.4855
# Epoch 110: Loss=54.7239
# Epoch 120: Loss=52.0464
# Epoch 130: Loss=51.7078
# Epoch 140: Loss=54.9986
# Epoch 150: Loss=51.5152
# Epoch 160: Loss=52.3324
# Epoch 170: Loss=50.5733
# Epoch 180: Loss=52.9874
# Epoch 190: Loss=51.2692
# Epoch 200: Loss=50.0878
# Epoch 210: Loss=51.3559
# Epoch 220: Loss=52.5137
# Epoch 230: Loss=50.6139
# Epoch 240: Loss=47.6934
# Epoch 250: Loss=47.9651
# Epoch 260: Loss=46.2287
# Epoch 270: Loss=54.0933
# Epoch 280: Loss=46.5412
# Epoch 290: Loss=48.3600
# Epoch 300: Loss=49.7241
# ✅ MSE: 76.3447 | R²: 0.4018
# ▶ Training: lr=0.001, batch=32, hidden=(256, 128, 64, 32, 16), epochs=100
# Epoch 10: Loss=111.1396
# Epoch 20: Loss=65.5264
# Epoch 30: Loss=58.2147
# Epoch 40: Loss=57.4658
# Epoch 50: Loss=57.0611
# Epoch 60: Loss=50.8798
# Epoch 70: Loss=52.3489
# Epoch 80: Loss=51.6634
# Epoch 90: Loss=50.2102
# Epoch 100: Loss=48.1261
# ✅ MSE: 73.2981 | R²: 0.4256
# ▶ Training: lr=0.001, batch=32, hidden=(256, 128, 64, 32, 16), epochs=200
# Epoch 10: Loss=130.9836
# Epoch 20: Loss=66.3132
# Epoch 30: Loss=60.5838
# Epoch 40: Loss=58.1094
# Epoch 50: Loss=56.6651
# Epoch 60: Loss=54.7116
# Epoch 70: Loss=55.4985
# Epoch 80: Loss=52.1192
# Epoch 90: Loss=54.0533
# Epoch 100: Loss=53.5553
# Epoch 110: Loss=48.8782
# Epoch 120: Loss=46.6347
# Epoch 130: Loss=54.0136
# Epoch 140: Loss=45.2974
# Epoch 150: Loss=41.4420
# Epoch 160: Loss=41.6994
# Epoch 170: Loss=40.8575
# Epoch 180: Loss=33.8492
# Epoch 190: Loss=31.8831
# Epoch 200: Loss=37.0991
# ✅ MSE: 76.5383 | R²: 0.4002
# ▶ Training: lr=0.001, batch=32, hidden=(256, 128, 64, 32, 16), epochs=300
# Epoch 10: Loss=121.0779
# Epoch 20: Loss=61.3232
# Epoch 30: Loss=57.1496
# Epoch 40: Loss=58.3203
# Epoch 50: Loss=58.3815
# Epoch 60: Loss=51.5590
# Epoch 70: Loss=51.9402
# Epoch 80: Loss=52.2633
# Epoch 90: Loss=48.9661
# Epoch 100: Loss=49.3180
# Epoch 110: Loss=47.0575
# Epoch 120: Loss=52.6251
# Epoch 130: Loss=47.9170
# Epoch 140: Loss=39.1860
# Epoch 150: Loss=42.7975
# Epoch 160: Loss=37.4322
# Epoch 170: Loss=36.9715
# Epoch 180: Loss=36.2779
# Epoch 190: Loss=34.6480
# Epoch 200: Loss=35.7455
# Epoch 210: Loss=33.1020
# Epoch 220: Loss=31.6011
# Epoch 230: Loss=32.8974
# Epoch 240: Loss=30.6422
# Epoch 250: Loss=34.9667
# Epoch 260: Loss=33.5761
# Epoch 270: Loss=32.6171
# Epoch 280: Loss=34.4122
# Epoch 290: Loss=31.2778
# Epoch 300: Loss=27.6808
# ✅ MSE: 86.1362 | R²: 0.3250
# ▶ Training: lr=0.0001, batch=8, hidden=(128, 64, 32), epochs=100
# Epoch 10: Loss=139.7048
# Epoch 20: Loss=138.6060
# Epoch 30: Loss=136.9370
# Epoch 40: Loss=134.4045
# Epoch 50: Loss=131.0295
# Epoch 60: Loss=126.8827
# Epoch 70: Loss=122.4008
# Epoch 80: Loss=118.0971
# Epoch 90: Loss=113.7119
# Epoch 100: Loss=109.1563
# ✅ MSE: 113.4467 | R²: 0.1110
# ▶ Training: lr=0.0001, batch=8, hidden=(128, 64, 32), epochs=200
# Epoch 10: Loss=139.4262
# Epoch 20: Loss=138.0189
# Epoch 30: Loss=135.5772
# Epoch 40: Loss=132.2425
# Epoch 50: Loss=127.9362
# Epoch 60: Loss=123.3854
# Epoch 70: Loss=118.4804
# Epoch 80: Loss=113.7598
# Epoch 90: Loss=109.0586
# Epoch 100: Loss=104.3388
# Epoch 110: Loss=99.9744
# Epoch 120: Loss=95.6361
# Epoch 130: Loss=90.9855
# Epoch 140: Loss=86.9803
# Epoch 150: Loss=82.5349
# Epoch 160: Loss=78.7042
# Epoch 170: Loss=75.5422
# Epoch 180: Loss=72.3249
# Epoch 190: Loss=69.4287
# Epoch 200: Loss=66.7896
# ✅ MSE: 95.1502 | R²: 0.2544
# ▶ Training: lr=0.0001, batch=8, hidden=(128, 64, 32), epochs=300
# Epoch 10: Loss=138.7260
# Epoch 20: Loss=135.6280
# Epoch 30: Loss=131.3096
# Epoch 40: Loss=125.6370
# Epoch 50: Loss=119.9292
# Epoch 60: Loss=114.3557
# Epoch 70: Loss=109.3322
# Epoch 80: Loss=104.7833
# Epoch 90: Loss=99.8874
# Epoch 100: Loss=95.5228
# Epoch 110: Loss=91.7706
# Epoch 120: Loss=87.3193
# Epoch 130: Loss=83.5143
# Epoch 140: Loss=79.4122
# Epoch 150: Loss=75.9157
# Epoch 160: Loss=72.4960
# Epoch 170: Loss=69.7112
# Epoch 180: Loss=66.7340
# Epoch 190: Loss=64.5585
# Epoch 200: Loss=62.7378
# Epoch 210: Loss=61.1554
# Epoch 220: Loss=60.4714
# Epoch 230: Loss=58.7955
# Epoch 240: Loss=57.7860
# Epoch 250: Loss=56.3502
# Epoch 260: Loss=56.1053
# Epoch 270: Loss=55.4197
# Epoch 280: Loss=54.7213
# Epoch 290: Loss=53.9134
# Epoch 300: Loss=53.4489
# ✅ MSE: 83.9673 | R²: 0.3420
# ▶ Training: lr=0.0001, batch=8, hidden=(64, 32, 16), epochs=100
# Epoch 10: Loss=140.1082
# Epoch 20: Loss=139.7643
# Epoch 30: Loss=139.5001
# Epoch 40: Loss=139.1863
# Epoch 50: Loss=138.7576
# Epoch 60: Loss=138.1512
# Epoch 70: Loss=137.4204
# Epoch 80: Loss=136.5238
# Epoch 90: Loss=135.5271
# Epoch 100: Loss=134.3589
# ✅ MSE: 123.0636 | R²: 0.0357
# ▶ Training: lr=0.0001, batch=8, hidden=(64, 32, 16), epochs=200
# Epoch 10: Loss=139.7736
# Epoch 20: Loss=139.2598
# Epoch 30: Loss=138.6892
# Epoch 40: Loss=137.9029
# Epoch 50: Loss=136.8649
# Epoch 60: Loss=135.5734
# Epoch 70: Loss=133.9877
# Epoch 80: Loss=132.1412
# Epoch 90: Loss=130.1399
# Epoch 100: Loss=127.8677
# Epoch 110: Loss=125.5292
# Epoch 120: Loss=123.2954
# Epoch 130: Loss=120.9177
# Epoch 140: Loss=118.6735
# Epoch 150: Loss=116.5700
# Epoch 160: Loss=114.5441
# Epoch 170: Loss=112.5604
# Epoch 180: Loss=110.6317
# Epoch 190: Loss=108.6023
# Epoch 200: Loss=106.5203
# ✅ MSE: 113.6073 | R²: 0.1098
# ▶ Training: lr=0.0001, batch=8, hidden=(64, 32, 16), epochs=300
# Epoch 10: Loss=140.1440
# Epoch 20: Loss=139.7597
# Epoch 30: Loss=138.8415
# Epoch 40: Loss=137.7928
# Epoch 50: Loss=136.6096
# Epoch 60: Loss=135.2191
# Epoch 70: Loss=133.5868
# Epoch 80: Loss=131.8231
# Epoch 90: Loss=129.7167
# Epoch 100: Loss=127.3509
# Epoch 110: Loss=124.9755
# Epoch 120: Loss=122.5972
# Epoch 130: Loss=120.4266
# Epoch 140: Loss=118.2445
# Epoch 150: Loss=116.3532
# Epoch 160: Loss=114.2077
# Epoch 170: Loss=112.3640
# Epoch 180: Loss=110.8344
# Epoch 190: Loss=109.0016
# Epoch 200: Loss=106.8851
# Epoch 210: Loss=105.0777
# Epoch 220: Loss=103.2191
# Epoch 230: Loss=101.4735
# Epoch 240: Loss=100.2136
# Epoch 250: Loss=97.7087
# Epoch 260: Loss=95.8473
# Epoch 270: Loss=93.6999
# Epoch 280: Loss=92.0760
# Epoch 290: Loss=89.8214
# Epoch 300: Loss=87.6896
# ✅ MSE: 105.7575 | R²: 0.1713
# ▶ Training: lr=0.0001, batch=8, hidden=(64, 32, 16, 8), epochs=100
# Epoch 10: Loss=140.0245
# Epoch 20: Loss=139.0874
# Epoch 30: Loss=138.1870
# Epoch 40: Loss=137.0150
# Epoch 50: Loss=135.4197
# Epoch 60: Loss=133.3794
# Epoch 70: Loss=131.0754
# Epoch 80: Loss=128.6517
# Epoch 90: Loss=125.9020
# Epoch 100: Loss=123.3855
# ✅ MSE: 117.1703 | R²: 0.0818
# ▶ Training: lr=0.0001, batch=8, hidden=(64, 32, 16, 8), epochs=200
# Epoch 10: Loss=140.4456
# Epoch 20: Loss=140.3184
# Epoch 30: Loss=140.0920
# Epoch 40: Loss=139.6866
# Epoch 50: Loss=139.0109
# Epoch 60: Loss=138.0854
# Epoch 70: Loss=136.9274
# Epoch 80: Loss=135.5670
# Epoch 90: Loss=133.9392
# Epoch 100: Loss=131.8232
# Epoch 110: Loss=129.5628
# Epoch 120: Loss=126.8609
# Epoch 130: Loss=124.1187
# Epoch 140: Loss=121.1067
# Epoch 150: Loss=117.6528
# Epoch 160: Loss=114.1705
# Epoch 170: Loss=110.6449
# Epoch 180: Loss=106.7969
# Epoch 190: Loss=103.0702
# Epoch 200: Loss=99.5570
# ✅ MSE: 107.8767 | R²: 0.1547
# ▶ Training: lr=0.0001, batch=8, hidden=(64, 32, 16, 8), epochs=300
# Epoch 10: Loss=140.1248
# Epoch 20: Loss=139.6525
# Epoch 30: Loss=139.0346
# Epoch 40: Loss=138.1564
# Epoch 50: Loss=136.9156
# Epoch 60: Loss=135.4111
# Epoch 70: Loss=133.5615
# Epoch 80: Loss=131.2591
# Epoch 90: Loss=128.9074
# Epoch 100: Loss=126.2453
# Epoch 110: Loss=123.6040
# Epoch 120: Loss=120.7596
# Epoch 130: Loss=118.0758
# Epoch 140: Loss=115.4643
# Epoch 150: Loss=112.9752
# Epoch 160: Loss=110.5539
# Epoch 170: Loss=108.1415
# Epoch 180: Loss=106.0402
# Epoch 190: Loss=103.7090
# Epoch 200: Loss=101.4147
# Epoch 210: Loss=99.2384
# Epoch 220: Loss=97.1290
# Epoch 230: Loss=94.7465
# Epoch 240: Loss=92.1933
# Epoch 250: Loss=89.6621
# Epoch 260: Loss=87.5418
# Epoch 270: Loss=84.3927
# Epoch 280: Loss=81.9545
# Epoch 290: Loss=79.3112
# Epoch 300: Loss=77.3275
# ✅ MSE: 103.5757 | R²: 0.1884
# ▶ Training: lr=0.0001, batch=8, hidden=(128, 64, 32, 16, 8), epochs=100
# Epoch 10: Loss=140.2505
# Epoch 20: Loss=139.4961
# Epoch 30: Loss=138.0458
# Epoch 40: Loss=135.7581
# Epoch 50: Loss=132.2810
# Epoch 60: Loss=127.2326
# Epoch 70: Loss=120.8049
# Epoch 80: Loss=113.4668
# Epoch 90: Loss=106.2428
# Epoch 100: Loss=98.6406
# ✅ MSE: 108.7803 | R²: 0.1476
# ▶ Training: lr=0.0001, batch=8, hidden=(128, 64, 32, 16, 8), epochs=200
# Epoch 10: Loss=140.3802
# Epoch 20: Loss=139.6047
# Epoch 30: Loss=137.7832
# Epoch 40: Loss=135.3291
# Epoch 50: Loss=131.8563
# Epoch 60: Loss=126.8417
# Epoch 70: Loss=120.8297
# Epoch 80: Loss=113.3316
# Epoch 90: Loss=105.3465
# Epoch 100: Loss=96.6970
# Epoch 110: Loss=85.7009
# Epoch 120: Loss=77.4405
# Epoch 130: Loss=69.2591
# Epoch 140: Loss=65.2795
# Epoch 150: Loss=62.8668
# Epoch 160: Loss=60.9096
# Epoch 170: Loss=59.7096
# Epoch 180: Loss=59.6806
# Epoch 190: Loss=58.9754
# Epoch 200: Loss=57.7688
# ✅ MSE: 81.8355 | R²: 0.3587
# ▶ Training: lr=0.0001, batch=8, hidden=(128, 64, 32, 16, 8), epochs=300
# Epoch 10: Loss=140.4726
# Epoch 20: Loss=140.1167
# Epoch 30: Loss=139.8666
# Epoch 40: Loss=139.6367
# Epoch 50: Loss=139.2776
# Epoch 60: Loss=138.4329
# Epoch 70: Loss=136.4867
# Epoch 80: Loss=132.7974
# Epoch 90: Loss=127.4901
# Epoch 100: Loss=120.9688
# Epoch 110: Loss=113.9746
# Epoch 120: Loss=106.0360
# Epoch 130: Loss=98.8232
# Epoch 140: Loss=90.9880
# Epoch 150: Loss=84.4183
# Epoch 160: Loss=78.3614
# Epoch 170: Loss=73.2573
# Epoch 180: Loss=68.8069
# Epoch 190: Loss=65.1388
# Epoch 200: Loss=63.4086
# Epoch 210: Loss=60.2189
# Epoch 220: Loss=58.5420
# Epoch 230: Loss=56.9052
# Epoch 240: Loss=56.5355
# Epoch 250: Loss=55.0462
# Epoch 260: Loss=53.6335
# Epoch 270: Loss=53.2374
# Epoch 280: Loss=52.9999
# Epoch 290: Loss=52.1176
# Epoch 300: Loss=51.6937
# ✅ MSE: 82.3775 | R²: 0.3545
# ▶ Training: lr=0.0001, batch=8, hidden=(256, 128, 64, 32, 16), epochs=100
# Epoch 10: Loss=139.3090
# Epoch 20: Loss=137.3320
# Epoch 30: Loss=129.4196
# Epoch 40: Loss=116.7698
# Epoch 50: Loss=101.5901
# Epoch 60: Loss=84.7392
# Epoch 70: Loss=71.4919
# Epoch 80: Loss=64.4471
# Epoch 90: Loss=59.1368
# Epoch 100: Loss=58.9809
# ✅ MSE: 86.0768 | R²: 0.3255
# ▶ Training: lr=0.0001, batch=8, hidden=(256, 128, 64, 32, 16), epochs=200
# Epoch 10: Loss=139.2703
# Epoch 20: Loss=136.8576
# Epoch 30: Loss=125.8316
# Epoch 40: Loss=106.8254
# Epoch 50: Loss=90.5936
# Epoch 60: Loss=73.0603
# Epoch 70: Loss=63.6217
# Epoch 80: Loss=59.3221
# Epoch 90: Loss=58.7075
# Epoch 100: Loss=56.3870
# Epoch 110: Loss=54.3581
# Epoch 120: Loss=54.3775
# Epoch 130: Loss=52.4720
# Epoch 140: Loss=52.2272
# Epoch 150: Loss=52.1920
# Epoch 160: Loss=51.1276
# Epoch 170: Loss=50.5499
# Epoch 180: Loss=51.7019
# Epoch 190: Loss=48.6784
# Epoch 200: Loss=48.2672
# ✅ MSE: 83.1208 | R²: 0.3487
# ▶ Training: lr=0.0001, batch=8, hidden=(256, 128, 64, 32, 16), epochs=300
# Epoch 10: Loss=139.6788
# Epoch 20: Loss=137.1469
# Epoch 30: Loss=128.9948
# Epoch 40: Loss=115.6768
# Epoch 50: Loss=101.7532
# Epoch 60: Loss=86.4193
# Epoch 70: Loss=74.3071
# Epoch 80: Loss=64.4893
# Epoch 90: Loss=59.9035
# Epoch 100: Loss=57.5677
# Epoch 110: Loss=56.1363
# Epoch 120: Loss=54.1968
# Epoch 130: Loss=54.3795
# Epoch 140: Loss=53.1890
# Epoch 150: Loss=53.8863
# Epoch 160: Loss=50.7829
# Epoch 170: Loss=51.7680
# Epoch 180: Loss=50.7948
# Epoch 190: Loss=51.4513
# Epoch 200: Loss=49.9535
# Epoch 210: Loss=48.9714
# Epoch 220: Loss=49.2810
# Epoch 230: Loss=50.4639
# Epoch 240: Loss=48.6965
# Epoch 250: Loss=48.3119
# Epoch 260: Loss=48.5100
# Epoch 270: Loss=46.7215
# Epoch 280: Loss=45.4532
# Epoch 290: Loss=46.2704
# Epoch 300: Loss=46.0581
# ✅ MSE: 77.9234 | R²: 0.3894
# ▶ Training: lr=0.0001, batch=16, hidden=(128, 64, 32), epochs=100
# Epoch 10: Loss=139.0363
# Epoch 20: Loss=139.0046
# Epoch 30: Loss=161.2830
# Epoch 40: Loss=132.3231
# Epoch 50: Loss=129.3015
# Epoch 60: Loss=125.7370
# Epoch 70: Loss=122.1539
# Epoch 80: Loss=118.7170
# Epoch 90: Loss=115.2011
# Epoch 100: Loss=113.4994
# ✅ MSE: 114.9090 | R²: 0.0996
# ▶ Training: lr=0.0001, batch=16, hidden=(128, 64, 32), epochs=200
# Epoch 10: Loss=137.6463
# Epoch 20: Loss=136.4710
# Epoch 30: Loss=135.0923
# Epoch 40: Loss=133.0747
# Epoch 50: Loss=130.8159
# Epoch 60: Loss=126.1867
# Epoch 70: Loss=122.3627
# Epoch 80: Loss=118.2159
# Epoch 90: Loss=115.3214
# Epoch 100: Loss=111.3003
# Epoch 110: Loss=107.4911
# Epoch 120: Loss=104.1966
# Epoch 130: Loss=101.5298
# Epoch 140: Loss=98.5427
# Epoch 150: Loss=95.3598
# Epoch 160: Loss=92.2553
# Epoch 170: Loss=89.8603
# Epoch 180: Loss=86.8072
# Epoch 190: Loss=84.2813
# Epoch 200: Loss=81.3502
# ✅ MSE: 102.7765 | R²: 0.1946
# ▶ Training: lr=0.0001, batch=16, hidden=(128, 64, 32), epochs=300
# Epoch 10: Loss=138.2019
# Epoch 20: Loss=137.6959
# Epoch 30: Loss=134.9721
# Epoch 40: Loss=132.6023
# Epoch 50: Loss=129.4243
# Epoch 60: Loss=135.3717
# Epoch 70: Loss=122.6251
# Epoch 80: Loss=119.0210
# Epoch 90: Loss=116.1973
# Epoch 100: Loss=112.2632
# Epoch 110: Loss=107.8573
# Epoch 120: Loss=104.6496
# Epoch 130: Loss=102.1391
# Epoch 140: Loss=101.6454
# Epoch 150: Loss=95.9129
# Epoch 160: Loss=92.6634
# Epoch 170: Loss=88.9547
# Epoch 180: Loss=86.1230
# Epoch 190: Loss=82.9112
# Epoch 200: Loss=80.2796
# Epoch 210: Loss=77.2043
# Epoch 220: Loss=75.0197
# Epoch 230: Loss=72.6908
# Epoch 240: Loss=71.0221
# Epoch 250: Loss=68.5173
# Epoch 260: Loss=65.8494
# Epoch 270: Loss=66.6350
# Epoch 280: Loss=62.2659
# Epoch 290: Loss=60.7800
# Epoch 300: Loss=60.1184
# ✅ MSE: 96.6293 | R²: 0.2428
# ▶ Training: lr=0.0001, batch=16, hidden=(64, 32, 16), epochs=100
# Epoch 10: Loss=138.6828
# Epoch 20: Loss=137.9521
# Epoch 30: Loss=137.0437
# Epoch 40: Loss=137.0659
# Epoch 50: Loss=135.8434
# Epoch 60: Loss=161.5992
# Epoch 70: Loss=134.3191
# Epoch 80: Loss=134.1591
# Epoch 90: Loss=134.5096
# Epoch 100: Loss=131.9130
# ✅ MSE: 122.6684 | R²: 0.0388
# ▶ Training: lr=0.0001, batch=16, hidden=(64, 32, 16), epochs=200
# Epoch 10: Loss=138.1958
# Epoch 20: Loss=138.0834
# Epoch 30: Loss=137.6205
# Epoch 40: Loss=138.8401
# Epoch 50: Loss=136.1634
# Epoch 60: Loss=134.7443
# Epoch 70: Loss=135.2946
# Epoch 80: Loss=131.9913
# Epoch 90: Loss=129.8924
# Epoch 100: Loss=128.1245
# Epoch 110: Loss=126.4183
# Epoch 120: Loss=124.1431
# Epoch 130: Loss=122.9500
# Epoch 140: Loss=120.5191
# Epoch 150: Loss=118.9147
# Epoch 160: Loss=115.8016
# Epoch 170: Loss=131.8704
# Epoch 180: Loss=111.1325
# Epoch 190: Loss=110.0285
# Epoch 200: Loss=108.1990
# ✅ MSE: 113.9404 | R²: 0.1072
# ▶ Training: lr=0.0001, batch=16, hidden=(64, 32, 16), epochs=300
# Epoch 10: Loss=138.7567
# Epoch 20: Loss=138.2823
# Epoch 30: Loss=138.7247
# Epoch 40: Loss=137.9313
# Epoch 50: Loss=138.4610
# Epoch 60: Loss=136.5999
# Epoch 70: Loss=136.1664
# Epoch 80: Loss=135.0922
# Epoch 90: Loss=133.8838
# Epoch 100: Loss=133.0075
# Epoch 110: Loss=133.0081
# Epoch 120: Loss=131.0759
# Epoch 130: Loss=128.7813
# Epoch 140: Loss=126.2086
# Epoch 150: Loss=125.2405
# Epoch 160: Loss=122.8306
# Epoch 170: Loss=121.6399
# Epoch 180: Loss=119.3305
# Epoch 190: Loss=118.5672
# Epoch 200: Loss=116.0916
# Epoch 210: Loss=114.8669
# Epoch 220: Loss=112.2178
# Epoch 230: Loss=111.1863
# Epoch 240: Loss=109.8526
# Epoch 250: Loss=108.7596
# Epoch 260: Loss=106.2077
# Epoch 270: Loss=108.5805
# Epoch 280: Loss=103.6050
# Epoch 290: Loss=102.0583
# Epoch 300: Loss=101.8465
# ✅ MSE: 110.4953 | R²: 0.1341
# ▶ Training: lr=0.0001, batch=16, hidden=(64, 32, 16, 8), epochs=100
# Epoch 10: Loss=140.1306
# Epoch 20: Loss=138.4235
# Epoch 30: Loss=140.1655
# Epoch 40: Loss=143.6657
# Epoch 50: Loss=137.1761
# Epoch 60: Loss=144.2251
# Epoch 70: Loss=136.7448
# Epoch 80: Loss=135.2173
# Epoch 90: Loss=134.8213
# Epoch 100: Loss=133.6417
# ✅ MSE: 123.6577 | R²: 0.0310
# ▶ Training: lr=0.0001, batch=16, hidden=(64, 32, 16, 8), epochs=200
# Epoch 10: Loss=139.0545
# Epoch 20: Loss=140.3354
# Epoch 30: Loss=137.8410
# Epoch 40: Loss=142.8220
# Epoch 50: Loss=137.0078
# Epoch 60: Loss=136.9002
# Epoch 70: Loss=136.2874
# Epoch 80: Loss=135.3781
# Epoch 90: Loss=134.7521
# Epoch 100: Loss=133.2824
# Epoch 110: Loss=133.7234
# Epoch 120: Loss=134.2227
# Epoch 130: Loss=129.3189
# Epoch 140: Loss=128.2636
# Epoch 150: Loss=126.0419
# Epoch 160: Loss=123.4485
# Epoch 170: Loss=122.5066
# Epoch 180: Loss=119.9536
# Epoch 190: Loss=118.0427
# Epoch 200: Loss=143.8977
# ✅ MSE: 114.6215 | R²: 0.1018
# ▶ Training: lr=0.0001, batch=16, hidden=(64, 32, 16, 8), epochs=300
# Epoch 10: Loss=139.1645
# Epoch 20: Loss=138.2595
# Epoch 30: Loss=139.6749
# Epoch 40: Loss=137.2932
# Epoch 50: Loss=136.6202
# Epoch 60: Loss=134.9791
# Epoch 70: Loss=135.6628
# Epoch 80: Loss=133.9448
# Epoch 90: Loss=132.2299
# Epoch 100: Loss=130.0940
# Epoch 110: Loss=129.7632
# Epoch 120: Loss=126.5184
# Epoch 130: Loss=124.1551
# Epoch 140: Loss=122.2088
# Epoch 150: Loss=125.9250
# Epoch 160: Loss=117.8666
# Epoch 170: Loss=115.8569
# Epoch 180: Loss=113.6872
# Epoch 190: Loss=111.3056
# Epoch 200: Loss=109.6043
# Epoch 210: Loss=128.1210
# Epoch 220: Loss=102.1943
# Epoch 230: Loss=100.0489
# Epoch 240: Loss=97.6833
# Epoch 250: Loss=94.9997
# Epoch 260: Loss=90.2121
# Epoch 270: Loss=88.2039
# Epoch 280: Loss=84.4379
# Epoch 290: Loss=82.3953
# Epoch 300: Loss=78.9108
# ✅ MSE: 97.9962 | R²: 0.2321
# ▶ Training: lr=0.0001, batch=16, hidden=(128, 64, 32, 16, 8), epochs=100
# Epoch 10: Loss=138.9505
# Epoch 20: Loss=138.6005
# Epoch 30: Loss=137.4835
# Epoch 40: Loss=137.0100
# Epoch 50: Loss=132.5611
# Epoch 60: Loss=128.2096
# Epoch 70: Loss=123.1407
# Epoch 80: Loss=110.0579
# Epoch 90: Loss=98.5464
# Epoch 100: Loss=86.7921
# ✅ MSE: 101.2648 | R²: 0.2065
# ▶ Training: lr=0.0001, batch=16, hidden=(128, 64, 32, 16, 8), epochs=200
# Epoch 10: Loss=139.0508
# Epoch 20: Loss=138.4764
# Epoch 30: Loss=138.3257
# Epoch 40: Loss=135.6865
# Epoch 50: Loss=133.5374
# Epoch 60: Loss=130.7076
# Epoch 70: Loss=124.3636
# Epoch 80: Loss=125.6634
# Epoch 90: Loss=112.2092
# Epoch 100: Loss=106.3123
# Epoch 110: Loss=96.1079
# Epoch 120: Loss=89.8355
# Epoch 130: Loss=82.7337
# Epoch 140: Loss=75.4937
# Epoch 150: Loss=70.8523
# Epoch 160: Loss=66.2349
# Epoch 170: Loss=63.8504
# Epoch 180: Loss=62.6863
# Epoch 190: Loss=60.0848
# Epoch 200: Loss=59.4767
# ✅ MSE: 86.8575 | R²: 0.3194
# ▶ Training: lr=0.0001, batch=16, hidden=(128, 64, 32, 16, 8), epochs=300
# Epoch 10: Loss=138.3688
# Epoch 20: Loss=137.1612
# Epoch 30: Loss=134.9012
# Epoch 40: Loss=130.6199
# Epoch 50: Loss=124.4216
# Epoch 60: Loss=117.5193
# Epoch 70: Loss=111.4696
# Epoch 80: Loss=96.6423
# Epoch 90: Loss=86.0338
# Epoch 100: Loss=74.9844
# Epoch 110: Loss=68.6978
# Epoch 120: Loss=67.1192
# Epoch 130: Loss=60.7010
# Epoch 140: Loss=58.5633
# Epoch 150: Loss=58.1602
# Epoch 160: Loss=58.1772
# Epoch 170: Loss=55.6605
# Epoch 180: Loss=55.6982
# Epoch 190: Loss=55.5931
# Epoch 200: Loss=59.7222
# Epoch 210: Loss=55.2417
# Epoch 220: Loss=54.7136
# Epoch 230: Loss=54.1413
# Epoch 240: Loss=54.2712
# Epoch 250: Loss=53.6872
# Epoch 260: Loss=53.9293
# Epoch 270: Loss=53.7384
# Epoch 280: Loss=53.5757
# Epoch 290: Loss=53.0020
# Epoch 300: Loss=53.7692
# ✅ MSE: 80.7794 | R²: 0.3670
# ▶ Training: lr=0.0001, batch=16, hidden=(256, 128, 64, 32, 16), epochs=100
# Epoch 10: Loss=166.1350
# Epoch 20: Loss=138.5278
# Epoch 30: Loss=134.3625
# Epoch 40: Loss=123.2088
# Epoch 50: Loss=111.9116
# Epoch 60: Loss=97.0146
# Epoch 70: Loss=83.5801
# Epoch 80: Loss=73.1390
# Epoch 90: Loss=65.7319
# Epoch 100: Loss=60.8906
# ✅ MSE: 90.3554 | R²: 0.2920
# ▶ Training: lr=0.0001, batch=16, hidden=(256, 128, 64, 32, 16), epochs=200
# Epoch 10: Loss=137.5227
# Epoch 20: Loss=133.2564
# Epoch 30: Loss=123.7412
# Epoch 40: Loss=111.7332
# Epoch 50: Loss=100.4729
# Epoch 60: Loss=85.8214
# Epoch 70: Loss=72.4474
# Epoch 80: Loss=65.5826
# Epoch 90: Loss=60.4616
# Epoch 100: Loss=59.2722
# Epoch 110: Loss=58.8329
# Epoch 120: Loss=58.2523
# Epoch 130: Loss=57.4380
# Epoch 140: Loss=55.2466
# Epoch 150: Loss=54.3124
# Epoch 160: Loss=54.9986
# Epoch 170: Loss=53.6011
# Epoch 180: Loss=52.0991
# Epoch 190: Loss=51.8525
# Epoch 200: Loss=53.8253
# ✅ MSE: 81.0445 | R²: 0.3649
# ▶ Training: lr=0.0001, batch=16, hidden=(256, 128, 64, 32, 16), epochs=300
# Epoch 10: Loss=138.5263
# Epoch 20: Loss=136.1451
# Epoch 30: Loss=128.3671
# Epoch 40: Loss=117.7191
# Epoch 50: Loss=103.1293
# Epoch 60: Loss=103.2728
# Epoch 70: Loss=76.4577
# Epoch 80: Loss=67.6133
# Epoch 90: Loss=61.9220
# Epoch 100: Loss=60.6498
# Epoch 110: Loss=57.1502
# Epoch 120: Loss=57.8008
# Epoch 130: Loss=57.3031
# Epoch 140: Loss=54.6500
# Epoch 150: Loss=56.9609
# Epoch 160: Loss=54.1929
# Epoch 170: Loss=53.2462
# Epoch 180: Loss=53.2588
# Epoch 190: Loss=53.6852
# Epoch 200: Loss=51.3151
# Epoch 210: Loss=51.4073
# Epoch 220: Loss=51.0676
# Epoch 230: Loss=52.6632
# Epoch 240: Loss=50.0686
# Epoch 250: Loss=50.5853
# Epoch 260: Loss=50.4175
# Epoch 270: Loss=50.0132
# Epoch 280: Loss=51.2424
# Epoch 290: Loss=49.4893
# Epoch 300: Loss=48.9767
# ✅ MSE: 80.7340 | R²: 0.3674
# ▶ Training: lr=0.0001, batch=32, hidden=(128, 64, 32), epochs=100
# Epoch 10: Loss=134.7698
# Epoch 20: Loss=135.9948
# Epoch 30: Loss=134.3183
# Epoch 40: Loss=133.8355
# Epoch 50: Loss=134.5384
# Epoch 60: Loss=131.8888
# Epoch 70: Loss=132.5610
# Epoch 80: Loss=132.1833
# Epoch 90: Loss=128.1032
# Epoch 100: Loss=127.3441
# ✅ MSE: 121.3445 | R²: 0.0491
# ▶ Training: lr=0.0001, batch=32, hidden=(128, 64, 32), epochs=200
# Epoch 10: Loss=135.1343
# Epoch 20: Loss=135.6382
# Epoch 30: Loss=136.2265
# Epoch 40: Loss=140.8514
# Epoch 50: Loss=132.8667
# Epoch 60: Loss=131.7755
# Epoch 70: Loss=129.6728
# Epoch 80: Loss=127.3547
# Epoch 90: Loss=142.0770
# Epoch 100: Loss=125.5296
# Epoch 110: Loss=120.3021
# Epoch 120: Loss=133.2712
# Epoch 130: Loss=115.5857
# Epoch 140: Loss=112.3776
# Epoch 150: Loss=109.4585
# Epoch 160: Loss=105.8808
# Epoch 170: Loss=104.0824
# Epoch 180: Loss=102.1977
# Epoch 190: Loss=102.5609
# Epoch 200: Loss=97.2081
# ✅ MSE: 110.2773 | R²: 0.1359
# ▶ Training: lr=0.0001, batch=32, hidden=(128, 64, 32), epochs=300
# Epoch 10: Loss=139.3794
# Epoch 20: Loss=134.0887
# Epoch 30: Loss=135.3577
# Epoch 40: Loss=132.4097
# Epoch 50: Loss=136.5839
# Epoch 60: Loss=132.1846
# Epoch 70: Loss=126.8746
# Epoch 80: Loss=126.2047
# Epoch 90: Loss=120.8042
# Epoch 100: Loss=117.8506
# Epoch 110: Loss=115.1788
# Epoch 120: Loss=112.1156
# Epoch 130: Loss=108.4259
# Epoch 140: Loss=104.5243
# Epoch 150: Loss=102.5894
# Epoch 160: Loss=102.6633
# Epoch 170: Loss=98.4810
# Epoch 180: Loss=148.0457
# Epoch 190: Loss=97.0760
# Epoch 200: Loss=90.2298
# Epoch 210: Loss=88.2521
# Epoch 220: Loss=83.9010
# Epoch 230: Loss=87.1181
# Epoch 240: Loss=80.4250
# Epoch 250: Loss=78.5111
# Epoch 260: Loss=74.6546
# Epoch 270: Loss=72.6090
# Epoch 280: Loss=70.7677
# Epoch 290: Loss=72.1079
# Epoch 300: Loss=67.1712
# ✅ MSE: 92.6518 | R²: 0.2740
# ▶ Training: lr=0.0001, batch=32, hidden=(64, 32, 16), epochs=100
# Epoch 10: Loss=135.4825
# Epoch 20: Loss=135.9286
# Epoch 30: Loss=134.9369
# Epoch 40: Loss=134.7667
# Epoch 50: Loss=135.2405
# Epoch 60: Loss=137.6314
# Epoch 70: Loss=133.7313
# Epoch 80: Loss=142.5850
# Epoch 90: Loss=134.0549
# Epoch 100: Loss=134.4473
# ✅ MSE: 124.9451 | R²: 0.0209
# ▶ Training: lr=0.0001, batch=32, hidden=(64, 32, 16), epochs=200
# Epoch 10: Loss=137.1969
# Epoch 20: Loss=134.6813
# Epoch 30: Loss=135.4059
# Epoch 40: Loss=136.8153
# Epoch 50: Loss=136.7011
# Epoch 60: Loss=136.3642
# Epoch 70: Loss=133.6177
# Epoch 80: Loss=132.3694
# Epoch 90: Loss=131.7375
# Epoch 100: Loss=130.7489
# Epoch 110: Loss=132.2756
# Epoch 120: Loss=127.4489
# Epoch 130: Loss=126.8752
# Epoch 140: Loss=127.3999
# Epoch 150: Loss=127.2505
# Epoch 160: Loss=122.9010
# Epoch 170: Loss=123.7578
# Epoch 180: Loss=130.2034
# Epoch 190: Loss=120.1000
# Epoch 200: Loss=117.6898
# ✅ MSE: 117.8451 | R²: 0.0766
# ▶ Training: lr=0.0001, batch=32, hidden=(64, 32, 16), epochs=300
# Epoch 10: Loss=135.9647
# Epoch 20: Loss=136.5962
# Epoch 30: Loss=136.0822
# Epoch 40: Loss=135.2640
# Epoch 50: Loss=134.4192
# Epoch 60: Loss=135.5739
# Epoch 70: Loss=133.8489
# Epoch 80: Loss=132.6646
# Epoch 90: Loss=133.8874
# Epoch 100: Loss=135.1445
# Epoch 110: Loss=137.6449
# Epoch 120: Loss=135.6647
# Epoch 130: Loss=129.3363
# Epoch 140: Loss=158.6645
# Epoch 150: Loss=132.3256
# Epoch 160: Loss=126.2086
# Epoch 170: Loss=125.2129
# Epoch 180: Loss=124.3509
# Epoch 190: Loss=125.7559
# Epoch 200: Loss=122.7473
# Epoch 210: Loss=122.5906
# Epoch 220: Loss=120.1702
# Epoch 230: Loss=122.2435
# Epoch 240: Loss=118.4088
# Epoch 250: Loss=117.3287
# Epoch 260: Loss=119.4708
# Epoch 270: Loss=134.1568
# Epoch 280: Loss=114.7889
# Epoch 290: Loss=112.7057
# Epoch 300: Loss=113.7585
# ✅ MSE: 114.6169 | R²: 0.1018
# ▶ Training: lr=0.0001, batch=32, hidden=(64, 32, 16, 8), epochs=100
# Epoch 10: Loss=135.7217
# Epoch 20: Loss=141.7338
# Epoch 30: Loss=134.8622
# Epoch 40: Loss=134.0315
# Epoch 50: Loss=135.8780
# Epoch 60: Loss=136.6357
# Epoch 70: Loss=135.1637
# Epoch 80: Loss=133.4940
# Epoch 90: Loss=134.1670
# Epoch 100: Loss=132.5131
# ✅ MSE: 125.0427 | R²: 0.0202
# ▶ Training: lr=0.0001, batch=32, hidden=(64, 32, 16, 8), epochs=200
# Epoch 10: Loss=135.4576
# Epoch 20: Loss=137.4124
# Epoch 30: Loss=137.4975
# Epoch 40: Loss=135.8840
# Epoch 50: Loss=135.1736
# Epoch 60: Loss=141.3658
# Epoch 70: Loss=135.2897
# Epoch 80: Loss=135.2736
# Epoch 90: Loss=136.7063
# Epoch 100: Loss=137.2632
# Epoch 110: Loss=134.3670
# Epoch 120: Loss=136.6757
# Epoch 130: Loss=136.1691
# Epoch 140: Loss=134.4369
# Epoch 150: Loss=134.3308
# Epoch 160: Loss=133.5584
# Epoch 170: Loss=136.9471
# Epoch 180: Loss=132.8107
# Epoch 190: Loss=133.1882
# Epoch 200: Loss=132.0979
# ✅ MSE: 124.8151 | R²: 0.0219
# ▶ Training: lr=0.0001, batch=32, hidden=(64, 32, 16, 8), epochs=300
# Epoch 10: Loss=175.0400
# Epoch 20: Loss=135.9182
# Epoch 30: Loss=135.6293
# Epoch 40: Loss=137.5952
# Epoch 50: Loss=134.3679
# Epoch 60: Loss=135.6758
# Epoch 70: Loss=135.8871
# Epoch 80: Loss=133.5879
# Epoch 90: Loss=136.2035
# Epoch 100: Loss=133.6003
# Epoch 110: Loss=131.0963
# Epoch 120: Loss=134.9458
# Epoch 130: Loss=130.0002
# Epoch 140: Loss=128.3501
# Epoch 150: Loss=130.5925
# Epoch 160: Loss=129.6490
# Epoch 170: Loss=125.0268
# Epoch 180: Loss=196.7575
# Epoch 190: Loss=123.2800
# Epoch 200: Loss=120.8925
# ...
# Epoch 10: Loss=138.5769
# Epoch 20: Loss=139.6879
# Epoch 30: Loss=139.4401
# Epoch 40: Loss=138.5790
# Epoch 50: Loss=138.5173
# Epoch 60: Loss=138.4439
# Epoch 70: Loss=138.1939
# Epoch 80: Loss=139.2743
# Epoch 90: Loss=140.3289
# Epoch 100: Loss=138.9696
# ✅ MSE: 127.5373 | R²: 0.0006
# ▶ Training: lr=1e-05, batch=16, hidden=(64, 32, 16), epochs=200
# Epoch 10: Loss=151.3845
# Epoch 20: Loss=138.7874
# Epoch 30: Loss=151.9056
# Epoch 40: Loss=138.7571
# Epoch 50: Loss=138.3161
# Epoch 60: Loss=138.3052
# Epoch 70: Loss=138.9754
# Epoch 80: Loss=139.6130
# Epoch 90: Loss=138.4308
# Epoch 100: Loss=138.0293
# Epoch 110: Loss=137.9854
# Epoch 120: Loss=138.8455
# Epoch 130: Loss=138.5471
# Epoch 140: Loss=137.9461
# Epoch 150: Loss=138.0910
# Epoch 160: Loss=138.3005
# Epoch 170: Loss=138.7258
# Epoch 180: Loss=146.0818
# Epoch 190: Loss=138.3451
# Epoch 200: Loss=137.8427
# ✅ MSE: 127.0753 | R²: 0.0042
# ▶ Training: lr=1e-05, batch=16, hidden=(64, 32, 16), epochs=300
# Epoch 10: Loss=138.7353
# Epoch 20: Loss=139.1711
# Epoch 30: Loss=138.9171
# Epoch 40: Loss=138.6747
# Epoch 50: Loss=138.7415
# Epoch 60: Loss=150.9642
# Epoch 70: Loss=138.8888
# Epoch 80: Loss=139.4272
# Epoch 90: Loss=140.0217
# Epoch 100: Loss=138.5371
# Epoch 110: Loss=138.5679
# Epoch 120: Loss=138.3101
# Epoch 130: Loss=138.9578
# Epoch 140: Loss=138.9569
# Epoch 150: Loss=138.1039
# Epoch 160: Loss=138.0081
# Epoch 170: Loss=138.4181
# Epoch 180: Loss=138.3995
# Epoch 190: Loss=138.2458
# Epoch 200: Loss=137.7741
# Epoch 210: Loss=138.3105
# Epoch 220: Loss=138.4734
# Epoch 230: Loss=137.9177
# Epoch 240: Loss=137.6407
# Epoch 250: Loss=138.2888
# Epoch 260: Loss=137.6041
# Epoch 270: Loss=138.0167
# Epoch 280: Loss=137.8213
# Epoch 290: Loss=138.3231
# Epoch 300: Loss=138.0736
# ✅ MSE: 126.8160 | R²: 0.0063
# ▶ Training: lr=1e-05, batch=16, hidden=(64, 32, 16, 8), epochs=100
# Epoch 10: Loss=140.4916
# Epoch 20: Loss=141.0952
# Epoch 30: Loss=139.5723
# Epoch 40: Loss=138.5452
# Epoch 50: Loss=140.4242
# Epoch 60: Loss=139.6892
# Epoch 70: Loss=139.2417
# Epoch 80: Loss=138.8882
# Epoch 90: Loss=138.4398
# Epoch 100: Loss=139.1865
# ✅ MSE: 127.6087 | R²: 0.0000
# ▶ Training: lr=1e-05, batch=16, hidden=(64, 32, 16, 8), epochs=200
# Epoch 10: Loss=139.8730
# Epoch 20: Loss=139.1145
# Epoch 30: Loss=139.3048
# Epoch 40: Loss=138.5640
# Epoch 50: Loss=139.7371
# Epoch 60: Loss=138.4365
# Epoch 70: Loss=138.9549
# Epoch 80: Loss=138.5857
# Epoch 90: Loss=139.0335
# Epoch 100: Loss=140.3807
# Epoch 110: Loss=166.0107
# Epoch 120: Loss=138.7110
# Epoch 130: Loss=138.5354
# Epoch 140: Loss=138.3503
# Epoch 150: Loss=138.8565
# Epoch 160: Loss=138.2537
# Epoch 170: Loss=140.1065
# Epoch 180: Loss=174.8883
# Epoch 190: Loss=138.8098
# Epoch 200: Loss=138.4812
# ✅ MSE: 127.7072 | R²: -0.0007
# ▶ Training: lr=1e-05, batch=16, hidden=(64, 32, 16, 8), epochs=300
# Epoch 10: Loss=139.3253
# Epoch 20: Loss=138.7121
# Epoch 30: Loss=138.6680
# Epoch 40: Loss=140.5268
# Epoch 50: Loss=139.4899
# Epoch 60: Loss=142.7544
# Epoch 70: Loss=138.6607
# Epoch 80: Loss=139.5830
# Epoch 90: Loss=140.2988
# Epoch 100: Loss=138.5956
# Epoch 110: Loss=141.7137
# Epoch 120: Loss=175.4870
# Epoch 130: Loss=139.0565
# Epoch 140: Loss=139.0601
# Epoch 150: Loss=138.9375
# Epoch 160: Loss=138.6225
# Epoch 170: Loss=138.2238
# Epoch 180: Loss=138.8291
# Epoch 190: Loss=139.1358
# Epoch 200: Loss=138.3928
# Epoch 210: Loss=138.7493
# Epoch 220: Loss=139.2732
# Epoch 230: Loss=138.7505
# Epoch 240: Loss=138.0427
# Epoch 250: Loss=138.1881
# Epoch 260: Loss=137.9181
# Epoch 270: Loss=138.2920
# Epoch 280: Loss=137.9242
# Epoch 290: Loss=138.2073
# Epoch 300: Loss=138.0189
# ✅ MSE: 127.1528 | R²: 0.0036
# ▶ Training: lr=1e-05, batch=16, hidden=(128, 64, 32, 16, 8), epochs=100
# Epoch 10: Loss=138.7042
# Epoch 20: Loss=139.2003
# Epoch 30: Loss=139.2898
# Epoch 40: Loss=138.5945
# Epoch 50: Loss=139.0533
# Epoch 60: Loss=139.7359
# Epoch 70: Loss=138.4251
# Epoch 80: Loss=139.1456
# Epoch 90: Loss=138.4131
# Epoch 100: Loss=139.5324
# ✅ MSE: 127.9317 | R²: -0.0025
# ▶ Training: lr=1e-05, batch=16, hidden=(128, 64, 32, 16, 8), epochs=200
# Epoch 10: Loss=138.5284
# Epoch 20: Loss=141.6972
# Epoch 30: Loss=138.6441
# Epoch 40: Loss=139.5217
# Epoch 50: Loss=141.0941
# Epoch 60: Loss=139.0109
# Epoch 70: Loss=138.7541
# Epoch 80: Loss=139.0807
# Epoch 90: Loss=138.6336
# Epoch 100: Loss=138.4966
# Epoch 110: Loss=138.7681
# Epoch 120: Loss=139.0017
# Epoch 130: Loss=138.7162
# Epoch 140: Loss=139.2158
# Epoch 150: Loss=138.5717
# Epoch 160: Loss=139.0421
# Epoch 170: Loss=138.6762
# Epoch 180: Loss=138.9539
# Epoch 190: Loss=138.6404
# Epoch 200: Loss=138.3549
# ✅ MSE: 127.6658 | R²: -0.0004
# ▶ Training: lr=1e-05, batch=16, hidden=(128, 64, 32, 16, 8), epochs=300
# Epoch 10: Loss=138.8387
# Epoch 20: Loss=138.9302
# Epoch 30: Loss=138.6424
# Epoch 40: Loss=138.4966
# Epoch 50: Loss=138.7067
# Epoch 60: Loss=138.7830
# Epoch 70: Loss=138.9990
# Epoch 80: Loss=138.4916
# Epoch 90: Loss=138.4514
# Epoch 100: Loss=138.7025
# Epoch 110: Loss=138.8438
# Epoch 120: Loss=138.2536
# Epoch 130: Loss=138.2303
# Epoch 140: Loss=138.8242
# Epoch 150: Loss=139.0956
# Epoch 160: Loss=137.9842
# Epoch 170: Loss=137.9508
# Epoch 180: Loss=138.5035
# Epoch 190: Loss=138.3073
# Epoch 200: Loss=138.6961
# Epoch 210: Loss=137.6850
# Epoch 220: Loss=138.0251
# Epoch 230: Loss=137.6251
# Epoch 240: Loss=137.6041
# Epoch 250: Loss=138.2795
# Epoch 260: Loss=138.5946
# Epoch 270: Loss=137.9227
# Epoch 280: Loss=138.2717
# Epoch 290: Loss=137.2695
# Epoch 300: Loss=144.6625
# ✅ MSE: 126.7716 | R²: 0.0066
# ▶ Training: lr=1e-05, batch=16, hidden=(256, 128, 64, 32, 16), epochs=100
# Epoch 10: Loss=140.1221
# Epoch 20: Loss=139.0550
# Epoch 30: Loss=138.8522
# Epoch 40: Loss=139.7415
# Epoch 50: Loss=138.5619
# Epoch 60: Loss=138.3593
# Epoch 70: Loss=138.2599
# Epoch 80: Loss=138.7345
# Epoch 90: Loss=139.0191
# Epoch 100: Loss=138.2955
# ✅ MSE: 127.0369 | R²: 0.0045
# ▶ Training: lr=1e-05, batch=16, hidden=(256, 128, 64, 32, 16), epochs=200
# Epoch 10: Loss=138.9076
# Epoch 20: Loss=138.5588
# Epoch 30: Loss=140.5265
# Epoch 40: Loss=138.8879
# Epoch 50: Loss=139.1796
# Epoch 60: Loss=138.4621
# Epoch 70: Loss=138.1747
# Epoch 80: Loss=137.9286
# Epoch 90: Loss=137.9377
# Epoch 100: Loss=138.4682
# Epoch 110: Loss=142.7287
# Epoch 120: Loss=137.2172
# Epoch 130: Loss=137.6520
# Epoch 140: Loss=138.5587
# Epoch 150: Loss=136.8322
# Epoch 160: Loss=136.5162
# Epoch 170: Loss=137.9648
# Epoch 180: Loss=135.4664
# Epoch 190: Loss=135.7662
# Epoch 200: Loss=142.1735
# ✅ MSE: 124.7303 | R²: 0.0226
# ▶ Training: lr=1e-05, batch=16, hidden=(256, 128, 64, 32, 16), epochs=300
# Epoch 10: Loss=138.7874
# Epoch 20: Loss=139.8567
# Epoch 30: Loss=138.5208
# Epoch 40: Loss=139.5279
# Epoch 50: Loss=141.1799
# Epoch 60: Loss=138.4674
# Epoch 70: Loss=138.1814
# Epoch 80: Loss=139.8360
# Epoch 90: Loss=138.1297
# Epoch 100: Loss=137.8842
# Epoch 110: Loss=138.2105
# Epoch 120: Loss=142.3400
# Epoch 130: Loss=137.6727
# Epoch 140: Loss=137.9706
# Epoch 150: Loss=137.3391
# Epoch 160: Loss=138.4708
# Epoch 170: Loss=173.0448
# Epoch 180: Loss=164.8209
# Epoch 190: Loss=137.0324
# Epoch 200: Loss=136.4537
# Epoch 210: Loss=136.2814
# Epoch 220: Loss=136.2699
# Epoch 230: Loss=136.5652
# Epoch 240: Loss=135.6483
# Epoch 250: Loss=135.3146
# Epoch 260: Loss=135.3902
# Epoch 270: Loss=135.7326
# Epoch 280: Loss=134.7944
# Epoch 290: Loss=134.2982
# Epoch 300: Loss=134.0367
# ✅ MSE: 124.0515 | R²: 0.0279
# ▶ Training: lr=1e-05, batch=32, hidden=(128, 64, 32), epochs=100
# Epoch 10: Loss=135.7641
# Epoch 20: Loss=135.3861
# Epoch 30: Loss=142.9083
# Epoch 40: Loss=216.0765
# Epoch 50: Loss=138.3884
# Epoch 60: Loss=136.0943
# Epoch 70: Loss=240.9887
# Epoch 80: Loss=135.5416
# Epoch 90: Loss=146.2975
# Epoch 100: Loss=137.0573
# ✅ MSE: 127.3463 | R²: 0.0021
# ▶ Training: lr=1e-05, batch=32, hidden=(128, 64, 32), epochs=200
# Epoch 10: Loss=135.0729
# Epoch 20: Loss=135.0176
# Epoch 30: Loss=137.6185
# Epoch 40: Loss=138.9533
# Epoch 50: Loss=136.8056
# Epoch 60: Loss=136.3111
# Epoch 70: Loss=135.5055
# Epoch 80: Loss=137.7806
# Epoch 90: Loss=136.3173
# Epoch 100: Loss=138.4825
# Epoch 110: Loss=134.1982
# Epoch 120: Loss=134.1298
# Epoch 130: Loss=135.0708
# Epoch 140: Loss=137.7838
# Epoch 150: Loss=134.4316
# Epoch 160: Loss=133.7383
# Epoch 170: Loss=133.9331
# Epoch 180: Loss=134.0475
# Epoch 190: Loss=134.2807
# Epoch 200: Loss=139.2138
# ✅ MSE: 126.5226 | R²: 0.0086
# ▶ Training: lr=1e-05, batch=32, hidden=(128, 64, 32), epochs=300
# Epoch 10: Loss=136.0712
# Epoch 20: Loss=139.3424
# Epoch 30: Loss=136.6601
# Epoch 40: Loss=322.5471
# Epoch 50: Loss=135.2612
# Epoch 60: Loss=171.4595
# Epoch 70: Loss=136.4160
# Epoch 80: Loss=134.2011
# Epoch 90: Loss=134.1318
# Epoch 100: Loss=139.3375
# Epoch 110: Loss=135.2179
# Epoch 120: Loss=135.0664
# Epoch 130: Loss=136.4553
# Epoch 140: Loss=155.6437
# Epoch 150: Loss=134.3427
# Epoch 160: Loss=137.7431
# Epoch 170: Loss=134.0499
# Epoch 180: Loss=133.6491
# Epoch 190: Loss=134.1005
# Epoch 200: Loss=134.6093
# Epoch 210: Loss=133.5084
# Epoch 220: Loss=133.4225
# Epoch 230: Loss=133.8398
# Epoch 240: Loss=133.9127
# Epoch 250: Loss=137.9421
# Epoch 260: Loss=145.9313
# Epoch 270: Loss=134.7034
# Epoch 280: Loss=133.1771
# Epoch 290: Loss=132.3969
# Epoch 300: Loss=132.5401
# ✅ MSE: 125.5728 | R²: 0.0160
# ▶ Training: lr=1e-05, batch=32, hidden=(64, 32, 16), epochs=100
# Epoch 10: Loss=141.4292
# Epoch 20: Loss=137.9275
# Epoch 30: Loss=136.3767
# Epoch 40: Loss=137.0901
# Epoch 50: Loss=140.2993
# Epoch 60: Loss=135.2938
# Epoch 70: Loss=135.1959
# Epoch 80: Loss=135.4071
# Epoch 90: Loss=136.5112
# Epoch 100: Loss=241.2165
# ✅ MSE: 127.8257 | R²: -0.0017
# ▶ Training: lr=1e-05, batch=32, hidden=(64, 32, 16), epochs=200
# Epoch 10: Loss=135.3607
# Epoch 20: Loss=138.6375
# Epoch 30: Loss=137.5792
# Epoch 40: Loss=148.3565
# Epoch 50: Loss=135.6409
# Epoch 60: Loss=137.0844
# Epoch 70: Loss=135.1356
# Epoch 80: Loss=135.9945
# Epoch 90: Loss=136.3327
# Epoch 100: Loss=134.9989
# Epoch 110: Loss=137.9579
# Epoch 120: Loss=138.8581
# Epoch 130: Loss=136.2056
# Epoch 140: Loss=137.5492
# Epoch 150: Loss=135.5794
# Epoch 160: Loss=135.1592
# Epoch 170: Loss=138.1227
# Epoch 180: Loss=137.7407
# Epoch 190: Loss=170.0076
# Epoch 200: Loss=134.4425
# ✅ MSE: 127.6989 | R²: -0.0007
# ▶ Training: lr=1e-05, batch=32, hidden=(64, 32, 16), epochs=300
# Epoch 10: Loss=140.8508
# Epoch 20: Loss=134.9738
# Epoch 30: Loss=134.9994
# Epoch 40: Loss=135.9636
# Epoch 50: Loss=136.4814
# Epoch 60: Loss=135.6798
# Epoch 70: Loss=137.2205
# Epoch 80: Loss=138.3639
# Epoch 90: Loss=135.0301
# Epoch 100: Loss=137.7499
# Epoch 110: Loss=242.7561
# Epoch 120: Loss=136.5596
# Epoch 130: Loss=134.5089
# Epoch 140: Loss=134.6413
# Epoch 150: Loss=135.9581
# Epoch 160: Loss=147.6212
# Epoch 170: Loss=136.3396
# Epoch 180: Loss=137.7226
# Epoch 190: Loss=134.3812
# Epoch 200: Loss=134.7213
# Epoch 210: Loss=217.1557
# Epoch 220: Loss=135.6426
# Epoch 230: Loss=135.2514
# Epoch 240: Loss=139.0791
# Epoch 250: Loss=240.3720
# Epoch 260: Loss=134.2144
# Epoch 270: Loss=134.3432
# Epoch 280: Loss=137.2374
# Epoch 290: Loss=134.6522
# Epoch 300: Loss=136.2585
# ✅ MSE: 127.1202 | R²: 0.0039
# ▶ Training: lr=1e-05, batch=32, hidden=(64, 32, 16, 8), epochs=100
# Epoch 10: Loss=139.0572
# Epoch 20: Loss=135.8119
# Epoch 30: Loss=135.6288
# Epoch 40: Loss=138.7464
# Epoch 50: Loss=140.8863
# Epoch 60: Loss=135.7956
# Epoch 70: Loss=137.1724
# Epoch 80: Loss=138.1720
# Epoch 90: Loss=138.2581
# Epoch 100: Loss=140.7448
# ✅ MSE: 127.9187 | R²: -0.0024
# ▶ Training: lr=1e-05, batch=32, hidden=(64, 32, 16, 8), epochs=200
# Epoch 10: Loss=135.3317
# Epoch 20: Loss=135.3214
# Epoch 30: Loss=157.1985
# Epoch 40: Loss=142.6582
# Epoch 50: Loss=135.8446
# Epoch 60: Loss=136.6206
# Epoch 70: Loss=135.3159
# Epoch 80: Loss=134.8913
# Epoch 90: Loss=136.9400
# Epoch 100: Loss=135.5388
# Epoch 110: Loss=141.2636
# Epoch 120: Loss=135.6710
# Epoch 130: Loss=136.5784
# Epoch 140: Loss=135.2494
# Epoch 150: Loss=142.4779
# Epoch 160: Loss=138.0086
# Epoch 170: Loss=137.4461
# Epoch 180: Loss=137.5492
# Epoch 190: Loss=135.6685
# Epoch 200: Loss=135.4316
# ✅ MSE: 128.4635 | R²: -0.0067
# ▶ Training: lr=1e-05, batch=32, hidden=(64, 32, 16, 8), epochs=300
# Epoch 10: Loss=140.1627
# Epoch 20: Loss=136.2819
# Epoch 30: Loss=137.6564
# Epoch 40: Loss=137.5519
# Epoch 50: Loss=136.7471
# Epoch 60: Loss=137.4726
# Epoch 70: Loss=139.5375
# Epoch 80: Loss=138.9123
# Epoch 90: Loss=135.1638
# Epoch 100: Loss=172.5875
# Epoch 110: Loss=135.7694
# Epoch 120: Loss=136.3542
# Epoch 130: Loss=135.0063
# Epoch 140: Loss=135.5298
# Epoch 150: Loss=134.9753
# Epoch 160: Loss=135.2721
# Epoch 170: Loss=146.5091
# Epoch 180: Loss=135.4697
# Epoch 190: Loss=136.2015
# Epoch 200: Loss=136.0976
# Epoch 210: Loss=135.0594
# Epoch 220: Loss=134.9436
# Epoch 230: Loss=134.8643
# Epoch 240: Loss=134.5675
# Epoch 250: Loss=135.7082
# Epoch 260: Loss=135.2802
# Epoch 270: Loss=140.8048
# Epoch 280: Loss=140.8114
# Epoch 290: Loss=134.9304
# Epoch 300: Loss=135.3326
# ✅ MSE: 127.6269 | R²: -0.0001
# ▶ Training: lr=1e-05, batch=32, hidden=(128, 64, 32, 16, 8), epochs=100
# Epoch 10: Loss=148.9289
# Epoch 20: Loss=135.2220
# Epoch 30: Loss=136.4665
# Epoch 40: Loss=138.3837
# Epoch 50: Loss=137.9978
# Epoch 60: Loss=136.8061
# Epoch 70: Loss=134.9862
# Epoch 80: Loss=135.8561
# Epoch 90: Loss=135.4713
# Epoch 100: Loss=135.9173
# ✅ MSE: 128.1018 | R²: -0.0038
# ▶ Training: lr=1e-05, batch=32, hidden=(128, 64, 32, 16, 8), epochs=200
# Epoch 10: Loss=135.0689
# Epoch 20: Loss=135.3881
# Epoch 30: Loss=136.1530
# Epoch 40: Loss=137.0104
# Epoch 50: Loss=138.6174
# Epoch 60: Loss=135.4802
# Epoch 70: Loss=138.0780
# Epoch 80: Loss=172.0814
# Epoch 90: Loss=135.7016
# Epoch 100: Loss=136.6225
# Epoch 110: Loss=135.4022
# Epoch 120: Loss=135.1023
# Epoch 130: Loss=138.6507
# Epoch 140: Loss=134.8836
# Epoch 150: Loss=135.3789
# Epoch 160: Loss=137.4130
# Epoch 170: Loss=134.5874
# Epoch 180: Loss=134.7019
# Epoch 190: Loss=138.2618
# Epoch 200: Loss=138.5084
# ✅ MSE: 127.8188 | R²: -0.0016
# ▶ Training: lr=1e-05, batch=32, hidden=(128, 64, 32, 16, 8), epochs=300
# Epoch 10: Loss=136.1410
# Epoch 20: Loss=137.5744
# Epoch 30: Loss=136.1912
# Epoch 40: Loss=137.2683
# Epoch 50: Loss=141.8688
# Epoch 60: Loss=137.5573
# Epoch 70: Loss=136.2588
# Epoch 80: Loss=141.0176
# Epoch 90: Loss=135.0029
# Epoch 100: Loss=137.3542
# Epoch 110: Loss=216.1541
# Epoch 120: Loss=136.7746
# Epoch 130: Loss=135.1253
# Epoch 140: Loss=135.0001
# Epoch 150: Loss=136.7005
# Epoch 160: Loss=135.0024
# Epoch 170: Loss=135.7711
# Epoch 180: Loss=139.7225
# Epoch 190: Loss=170.3347
# Epoch 200: Loss=135.3677
# Epoch 210: Loss=135.5360
# Epoch 220: Loss=135.5825
# Epoch 230: Loss=135.5775
# Epoch 240: Loss=136.2894
# Epoch 250: Loss=136.2854
# Epoch 260: Loss=135.3848
# Epoch 270: Loss=135.1796
# Epoch 280: Loss=137.5193
# Epoch 290: Loss=137.1706
# Epoch 300: Loss=134.8268
# ✅ MSE: 128.2969 | R²: -0.0053
# ▶ Training: lr=1e-05, batch=32, hidden=(256, 128, 64, 32, 16), epochs=100
# Epoch 10: Loss=135.4169
# Epoch 20: Loss=135.5884
# Epoch 30: Loss=137.0389
# Epoch 40: Loss=135.0857
# Epoch 50: Loss=136.8734
# Epoch 60: Loss=136.6029
# Epoch 70: Loss=134.8808
# Epoch 80: Loss=136.7967
# Epoch 90: Loss=139.0820
# Epoch 100: Loss=135.7141
# ✅ MSE: 127.1966 | R²: 0.0033
# ▶ Training: lr=1e-05, batch=32, hidden=(256, 128, 64, 32, 16), epochs=200
# Epoch 10: Loss=134.9228
# Epoch 20: Loss=135.9444
# Epoch 30: Loss=134.6522
# Epoch 40: Loss=134.9918
# Epoch 50: Loss=135.5128
# Epoch 60: Loss=145.4550
# Epoch 70: Loss=134.6486
# Epoch 80: Loss=135.2681
# Epoch 90: Loss=137.5841
# Epoch 100: Loss=134.1876
# Epoch 110: Loss=136.8985
# Epoch 120: Loss=136.8724
# Epoch 130: Loss=138.9992
# Epoch 140: Loss=135.2068
# Epoch 150: Loss=135.6225
# Epoch 160: Loss=134.6488
# Epoch 170: Loss=241.5713
# Epoch 180: Loss=134.1952
# Epoch 190: Loss=137.8519
# Epoch 200: Loss=147.6151
# ✅ MSE: 126.5268 | R²: 0.0085
# ▶ Training: lr=1e-05, batch=32, hidden=(256, 128, 64, 32, 16), epochs=300
# Epoch 10: Loss=136.0109
# Epoch 20: Loss=139.8088
# Epoch 30: Loss=135.0173
# Epoch 40: Loss=137.8003
# Epoch 50: Loss=135.6228
# Epoch 60: Loss=136.0775
# Epoch 70: Loss=134.9713
# Epoch 80: Loss=136.3644
# Epoch 90: Loss=136.1285
# Epoch 100: Loss=134.9667
# Epoch 110: Loss=138.5135
# Epoch 120: Loss=134.3696
# Epoch 130: Loss=134.1399
# Epoch 140: Loss=133.8050
# Epoch 150: Loss=213.5330
# Epoch 160: Loss=136.2359
# Epoch 170: Loss=134.9165
# Epoch 180: Loss=135.5163
# Epoch 190: Loss=133.8754
# Epoch 200: Loss=136.3227
# Epoch 210: Loss=137.1543
# Epoch 220: Loss=135.2005
# Epoch 230: Loss=134.5093
# Epoch 240: Loss=136.8238
# Epoch 250: Loss=135.2426
# Epoch 260: Loss=133.3973
# Epoch 270: Loss=138.6540
# Epoch 280: Loss=132.0243
# Epoch 290: Loss=131.4140
# Epoch 300: Loss=132.0550
# ✅ MSE: 124.6854 | R²: 0.0230
# 🏆 Best config: {'lr': 0.001, 'batch_size': 32, 'hidden_sizes': (128, 64, 32), 'epochs': 200}, R²=0.4297
